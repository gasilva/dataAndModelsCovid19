# %% [markdown]
# # Optimize Initial Conditions
# ## Yabox

# %%
import numpy as np
from datetime import datetime,timedelta
import pandas as pd
from yabox import DE

# %% [markdown]
# # Initialize Ray

# %%
from environs import Env
env = Env()
env.str("CUDA_DEVICE_ORDER",'PCI_BUS_ID')
env.int("CUDA_VISIBLE_DEVICES",1)
env.int("NUMBA_ENABLE_CUDASIM",1)
env.bool("OMPI_MCA_opal_cuda_support",True)

import os
import ray
MB=1024*1024
GB=MB*1024
ray.shutdown()
ray.init(object_store_memory=1*GB,memory=220*GB,
         #lru_evict=True,
         driver_object_store_memory=500*MB,num_gpus=1,num_cpus=1,
         ignore_reinit_error=True) # , include_webui=False, ignore_reinit_error=True)

@ray.remote(num_gpus=1)
def use_gpu():
    print("ray.get_gpu_ids(): {}".format(ray.get_gpu_ids()[0]))
    print("CUDA_VISIBLE_DEVICES: {}".format(os.environ["CUDA_VISIBLE_DEVICES"]))

use_gpu.remote()
# Out:
# 2020-09-28 13:31:52,477	INFO resource_spec.py:212 -- Starting Ray with 219.97 GiB memory available for workers and up to 1.0 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-09-28 13:31:52,798	INFO services.py:1170 -- View the Ray dashboard at localhost:8265
# ObjectID(45b95b1c8bd3a9c4ffffffff010000c801000000)

# %% [markdown]
# # Load New and Process Data from website data.brasil.io

# %%
# %reload_ext autoreload
# %autoreload 2
import get_data
LoadData=True

if LoadData:
    get_data.get_data()
# Out:
# (pid=18428) ray.get_gpu_ids(): 0
# (pid=18428) CUDA_VISIBLE_DEVICES: 0

# %% [markdown]
# # Functions to Load Processed Data

# %%
def load_confirmed(country,start_date=None):
    df = pd.read_csv('data/time_series_19-covid-Confirmed-country.csv')
    country_df = df[df['Country/Region'] == country]
    if start_date==None:
        return country_df.iloc[0]
    else: 
        return country_df.iloc[0].loc[start_date:]


def load_recovered(country,start_date=None):
    df = pd.read_csv('data/time_series_19-covid-Recovered-country.csv')
    country_df = df[df['Country/Region'] == country]
    if start_date==None:
        return country_df.iloc[0]
    else: 
        return country_df.iloc[0].loc[start_date:]

def load_dead(country,start_date=None):
    df = pd.read_csv('data/time_series_19-covid-Deaths-country.csv')
    country_df = df[df['Country/Region'] == country]
    if start_date==None:
        return country_df.iloc[0]
    else: 
        return country_df.iloc[0].loc[start_date:]

# %% [markdown]
# # Load solver

# %%
# %reload_ext autoreload
# %autoreload 2
import LearnerICRayNoLoadBH as L

# %% [markdown]
# # Data for Countries

# %%
dfparam = pd.read_csv("data/param.csv")
countries=dfparam.country
popEst = pd.read_csv("data/WPP2019_TotalPopulationBySex.csv")
popEst.popTotal=pd.to_numeric(popEst.PopTotal, errors='coerce')

for country in countries:
    if country=="US":
        country2="United States of America"    
    else:
        country2=country
    dfparam.loc[dfparam.country==country,'popTotal']=popEst.loc[popEst.Location==country2].loc[popEst.Time==2020].iloc[0,8]*1000
    dfparam.loc[dfparam.country==country,'s0']=popEst.loc[popEst.Location==country2].loc[popEst.Time==2020].iloc[0,8]*1000*0.3
    
display(dfparam)
# Out:
# /home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   after removing the cwd from sys.path.
#   country start-date  prediction-range           s0      e0      a0   i0   r0  \
# 0  Brazil     3/2/20               200   63767822.7  0.0001  0.0001  200  100
# 1   China    1/28/20               200  431797132.2  0.0001  0.0001  200  100
# 2   Italy    2/28/20               200   18138548.4  0.0001  0.0001  200  100
# 3      US    2/20/20               200   99300794.1  0.0001  0.0001  200  100
# 4   India    3/10/20               200  414001315.5  0.0001  0.0001  200  100
#
#    d0  START  WCASES  WREC      popTotal
# 0  50     50    0.15  0.05  2.125594e+08
# 1  50     50    0.15  0.05  1.439324e+09
# 2  50     50    0.15  0.05  6.046183e+07
# 3  50     50    0.15  0.05  3.310026e+08
# 4  50     50    0.15  0.05  1.380004e+09

# %% [markdown]
# # Functions for Optimization

# %%
from scipy.integrate import odeint
import sys
import io
import gc

def create_f(country,e0,a0,r0,date, predict_range, version):
                
    def fobjective(point):
        
        dead=  load_dead(country,date)
        recovered = load_recovered(country,date)
        data = load_confirmed(country,date)-recovered-dead
        cleanRecovered=False
        s0, deltaDate, i0, d0, startNCases, weigthCases, weigthRecov = point
        end_date=datetime.strptime(date, "%m/%d/%y") + timedelta(days=deltaDate)
        f=L.Learner.remote(country, end_date.strftime("%m/%d/%y"), predict_range,\
                           s0, e0, a0, i0, r0, d0, startNCases, weigthCases, weigthRecov, \
                           cleanRecovered, version, data, dead, recovered, savedata=False)
        result = f.train.remote() 
        result = ray.get(result) 

        del end_date,cleanRecovered, data, dead, point,f         

        gc.collect()

        return result
    return fobjective

# %%
@ray.remote(memory=50 * 1024 * 1024, max_calls=1)
def opt(country,s0,i0,e0,a0,r0,d0,wcases,wrec,date,startNCases, 
        predict_range, version):

    bounds=[(5e3,s0),(-2,2),(0,350), (0,250), (0,150),\
              (0.1,0.35),(0.001,.2)]
    maxiterations=500
    f=create_f(country,e0,a0,r0,date, predict_range, version)
    de = DE(f, bounds, maxiters=maxiterations)
    for step in de.geniterator():
        try:
            idx = step.best_idx
            norm_vector = step.population[idx]
            best_params = de.denormalize([norm_vector])
            del norm_vector, idx
        except:
            print("error in function evaluation")
    p=best_params[0]
    del f, bounds, data, dead,best_params
    
    return p

# %% [markdown]
# # Main Code

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines){
#     return true;}

# %%
countries=dfparam.country
display(countries)
allCountries=True
version="003"
gc.enable()

optimal=[]
if allCountries:
    for country in countries:
        #remove previous history file
        strFile='./results/history_'+country+version+'.csv'
        if os.path.isfile(strFile):
            os.remove(strFile)
        query = dfparam.query('country == "{}"'.format(country)).reset_index()
        parameters = np.array(query.iloc[:, 2:])[0]
        date,predict_range,s0,e0,a0,i0,r0,d0,startNCases,wcases,wrec,pop = parameters
        optimal.append(opt.remote(country,s0,i0,e0,a0,r0,d0,wcases,wrec,date,startNCases, 
                                            predict_range, version))        
else:
    country = "Brazil" 
    #remove previous history file
    strFile='./results/history_'+country+version+'.csv'
    if os.path.isfile(strFile):
        os.remove(strFile)
    query = dfparam.query('country == "{}"'.format(country)).reset_index()
    parameters = np.array(query.iloc[:, 2:])[0]
    date,predict_range,s0,e0,a0,i0,r0,d0,startNCases,wcases,wrec,pop = parameters
    optimal.append(opt.remote(country,s0,i0,e0,a0,r0,d0,wcases,wrec,date,startNCases, 
                        predict_range, version))
# Out:
# 0    Brazil
# 1     China
# 2     Italy
# 3        US
# 4     India
# Name: country, dtype: object
# 2020-09-28 13:31:55,385	WARNING worker.py:1090 -- WARNING: 3 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.

# %%
optimal=ray.get(optimal)
# Out:
# 2020-09-28 13:31:56,259	WARNING worker.py:1090 -- WARNING: 4 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-09-28 13:31:56,625	WARNING worker.py:1090 -- WARNING: 5 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-09-28 13:31:57,515	WARNING worker.py:1090 -- WARNING: 6 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-09-28 13:31:57,909	WARNING worker.py:1090 -- WARNING: 7 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-09-28 13:31:58,829	WARNING worker.py:1090 -- WARNING: 8 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-09-28 13:31:59,244	WARNING worker.py:1090 -- WARNING: 9 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-09-28 13:32:00,147	WARNING worker.py:1090 -- WARNING: 10 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=18473) basinhopping step 0: f -7.82403e+12
# (pid=18473) basinhopping step 1: f -7.82403e+12 trial_f 3.99631e+13 accepted 0  lowest_f -7.82403e+12
# (pid=18525) basinhopping step 0: f -2.61395e+13
# (pid=18499) basinhopping step 0: f -6.62631e+15
# (pid=18577) warning: basinhopping: local minimization failure
# (pid=18577) basinhopping step 0: f 7.88185e+10
# (pid=18525) basinhopping step 1: f -4.67517e+13 trial_f -4.67517e+13 accepted 1  lowest_f -4.67517e+13
# (pid=18525) found new global minimum on step 1 with function value -4.67517e+13
# (pid=18473) basinhopping step 2: f -7.82403e+12 trial_f 3.99631e+13 accepted 0  lowest_f -7.82403e+12
# (pid=18473) basinhopping step 3: f -7.82403e+12 trial_f 3.99632e+13 accepted 0  lowest_f -7.82403e+12
# (pid=18525) basinhopping step 2: f -4.67517e+13 trial_f 2.61302e+09 accepted 0  lowest_f -4.67517e+13
# (pid=18525) warning: basinhopping: local minimization failure
# (pid=18525) basinhopping step 3: f -4.67517e+13 trial_f 3.04782e+09 accepted 0  lowest_f -4.67517e+13
# (pid=18499) basinhopping step 1: f -6.62631e+15 trial_f 1.81083e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18499) basinhopping step 2: f -6.62631e+15 trial_f 1.11163e+09 accepted 0  lowest_f -6.62631e+15
# (pid=18551) basinhopping step 0: f 5.30767e+11
# (pid=18473) basinhopping step 4: f -7.82403e+12 trial_f 1.89767e+10 accepted 0  lowest_f -7.82403e+12
# (pid=18577) basinhopping step 1: f 7.88185e+10 trial_f 2.3027e+12 accepted 0  lowest_f 7.88185e+10
# (pid=18551) basinhopping step 1: f 5.30767e+11 trial_f 1.22255e+12 accepted 0  lowest_f 5.30767e+11
# (pid=18577) basinhopping step 2: f 7.76581e+10 trial_f 7.76581e+10 accepted 1  lowest_f 7.76581e+10
# (pid=18577) found new global minimum on step 2 with function value 7.76581e+10
# (pid=18473) basinhopping step 5: f -7.82403e+12 trial_f 7.49526e+11 accepted 0  lowest_f -7.82403e+12
# (pid=18525) basinhopping step 4: f -6.9352e+13 trial_f -6.9352e+13 accepted 1  lowest_f -6.9352e+13
# (pid=18525) found new global minimum on step 4 with function value -6.9352e+13
# (pid=18473) basinhopping step 6: f -7.82403e+12 trial_f 6.17269e+11 accepted 0  lowest_f -7.82403e+12
# (pid=18577) basinhopping step 3: f 7.76581e+10 trial_f 1.49567e+13 accepted 0  lowest_f 7.76581e+10
# (pid=18577) basinhopping step 4: f 7.76581e+10 trial_f 1.44424e+13 accepted 0  lowest_f 7.76581e+10
# (pid=18473) basinhopping step 7: f -7.82403e+12 trial_f 7.86245e+11 accepted 0  lowest_f -7.82403e+12
# (pid=18525) basinhopping step 5: f -6.9352e+13 trial_f 2.4064e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18499) basinhopping step 3: f -6.62631e+15 trial_f 5.21455e+14 accepted 0  lowest_f -6.62631e+15
# (pid=18525) basinhopping step 6: f -6.9352e+13 trial_f 4.07511e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18577) basinhopping step 5: f 7.76581e+10 trial_f 1.50257e+13 accepted 0  lowest_f 7.76581e+10
# (pid=18551) basinhopping step 2: f 4.01662e+11 trial_f 4.01662e+11 accepted 1  lowest_f 4.01662e+11
# (pid=18551) found new global minimum on step 2 with function value 4.01662e+11
# (pid=18551) warning: basinhopping: local minimization failure
# (pid=18551) basinhopping step 3: f 2.48093e+10 trial_f 2.48093e+10 accepted 1  lowest_f 2.48093e+10
# (pid=18551) found new global minimum on step 3 with function value 2.48093e+10
# (pid=18499) basinhopping step 4: f -6.62631e+15 trial_f -1.53864e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18551) basinhopping step 4: f 2.48093e+10 trial_f 1.23409e+12 accepted 0  lowest_f 2.48093e+10
# (pid=18499) basinhopping step 5: f -6.62631e+15 trial_f 1.12177e+09 accepted 0  lowest_f -6.62631e+15
# (pid=18577) basinhopping step 6: f 7.76581e+10 trial_f 1.51098e+13 accepted 0  lowest_f 7.76581e+10
# (pid=18473) basinhopping step 8: f -7.82403e+12 trial_f 3.57204e+10 accepted 0  lowest_f -7.82403e+12
# (pid=18551) basinhopping step 5: f 2.48093e+10 trial_f 1.19288e+12 accepted 0  lowest_f 2.48093e+10
# (pid=18499) basinhopping step 6: f -6.62631e+15 trial_f 9.934e+08 accepted 0  lowest_f -6.62631e+15
# (pid=18525) basinhopping step 7: f -6.9352e+13 trial_f -3.33297e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 6: f -1.80427e+12 trial_f -1.80427e+12 accepted 1  lowest_f -1.80427e+12
# (pid=18551) found new global minimum on step 6 with function value -1.80427e+12
# (pid=18499) basinhopping step 7: f -6.62631e+15 trial_f 3.22952e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18551) basinhopping step 7: f -1.80427e+12 trial_f 2.80176e+13 accepted 0  lowest_f -1.80427e+12
# (pid=18525) basinhopping step 8: f -6.9352e+13 trial_f 4.07564e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18551) warning: basinhopping: local minimization failure
# (pid=18551) basinhopping step 8: f -1.80427e+12 trial_f 1.00235e+12 accepted 0  lowest_f -1.80427e+12
# (pid=18473) basinhopping step 9: f -7.82403e+12 trial_f 1.28026e+11 accepted 0  lowest_f -7.82403e+12
# (pid=18473) basinhopping step 10: f -7.82403e+12 trial_f 3.9963e+13 accepted 0  lowest_f -7.82403e+12
# (pid=18499) warning: basinhopping: local minimization failure
# (pid=18499) basinhopping step 8: f -6.62631e+15 trial_f 1.10321e+09 accepted 0  lowest_f -6.62631e+15
# (pid=18473) basinhopping step 11: f -7.82403e+12 trial_f 6.01699e+12 accepted 0  lowest_f -7.82403e+12
# (pid=18473) basinhopping step 12: f -7.82403e+12 trial_f -7.79134e+12 accepted 0  lowest_f -7.82403e+12
# (pid=18525) basinhopping step 9: f -6.9352e+13 trial_f 6.13083e+11 accepted 0  lowest_f -6.9352e+13
# (pid=18473) basinhopping step 13: f -7.82403e+12 trial_f 5.89406e+10 accepted 0  lowest_f -7.82403e+12
# (pid=18473) basinhopping step 14: f -7.82403e+12 trial_f 3.99632e+13 accepted 0  lowest_f -7.82403e+12
# (pid=18499) warning: basinhopping: local minimization failure
# (pid=18499) basinhopping step 9: f -6.62631e+15 trial_f 5.19762e+14 accepted 0  lowest_f -6.62631e+15
# (pid=18551) basinhopping step 9: f -7.16687e+12 trial_f -7.16687e+12 accepted 1  lowest_f -7.16687e+12
# (pid=18551) found new global minimum on step 9 with function value -7.16687e+12
# (pid=18525) basinhopping step 10: f -6.9352e+13 trial_f 4.36196e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18473) basinhopping step 15: f -7.82403e+12 trial_f 1.6402e+11 accepted 0  lowest_f -7.82403e+12
# (pid=18525) basinhopping step 11: f -6.9352e+13 trial_f -6.86894e+11 accepted 0  lowest_f -6.9352e+13
# (pid=18499) basinhopping step 10: f -6.62631e+15 trial_f 3.23734e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18499) basinhopping step 11: f -6.62631e+15 trial_f 3.601e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18577) basinhopping step 7: f -5.63367e+15 trial_f -5.63367e+15 accepted 1  lowest_f -5.63367e+15
# (pid=18577) found new global minimum on step 7 with function value -5.63367e+15
# (pid=18525) basinhopping step 12: f -6.9352e+13 trial_f 8.56095e+11 accepted 0  lowest_f -6.9352e+13
# (pid=18473) warning: basinhopping: local minimization failure
# (pid=18473) basinhopping step 16: f -7.82403e+12 trial_f -2.60897e+11 accepted 0  lowest_f -7.82403e+12
# (pid=18551) basinhopping step 10: f -7.16687e+12 trial_f 8.49183e+11 accepted 0  lowest_f -7.16687e+12
# (pid=18499) basinhopping step 12: f -6.62631e+15 trial_f 8.44947e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18577) basinhopping step 8: f -5.63367e+15 trial_f 2.29113e+12 accepted 0  lowest_f -5.63367e+15
# (pid=18473) basinhopping step 17: f -7.82403e+12 trial_f 7.48025e+11 accepted 0  lowest_f -7.82403e+12
# (pid=18551) basinhopping step 11: f -7.16687e+12 trial_f 8.56668e+11 accepted 0  lowest_f -7.16687e+12
# (pid=18551) basinhopping step 12: f -7.16687e+12 trial_f 2.8018e+13 accepted 0  lowest_f -7.16687e+12
# (pid=18473) warning: basinhopping: local minimization failure
# (pid=18473) basinhopping step 18: f -2.03237e+13 trial_f -2.03237e+13 accepted 1  lowest_f -2.03237e+13
# (pid=18473) found new global minimum on step 18 with function value -2.03237e+13
# (pid=18525) basinhopping step 13: f -6.9352e+13 trial_f 6.13624e+11 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 13: f -7.16687e+12 trial_f 1.23327e+12 accepted 0  lowest_f -7.16687e+12
# (pid=18577) basinhopping step 9: f -5.63367e+15 trial_f 2.29093e+12 accepted 0  lowest_f -5.63367e+15
# (pid=18525) warning: basinhopping: local minimization failure
# (pid=18525) basinhopping step 14: f -6.9352e+13 trial_f 3.04433e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18473) basinhopping step 19: f -2.03237e+13 trial_f 5.57512e+12 accepted 0  lowest_f -2.03237e+13
# (pid=18525) basinhopping step 15: f -6.9352e+13 trial_f 2.42385e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 14: f -7.16687e+12 trial_f 9.65368e+11 accepted 0  lowest_f -7.16687e+12
# (pid=18473) basinhopping step 20: f -2.03237e+13 trial_f 3.99631e+13 accepted 0  lowest_f -2.03237e+13
# (pid=18577) basinhopping step 10: f -5.63367e+15 trial_f 7.79481e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18499) basinhopping step 13: f -6.62631e+15 trial_f 5.24096e+14 accepted 0  lowest_f -6.62631e+15
# (pid=18499) basinhopping step 14: f -6.62631e+15 trial_f 1.10762e+09 accepted 0  lowest_f -6.62631e+15
# (pid=18551) basinhopping step 15: f -1.32924e+13 trial_f -1.32924e+13 accepted 1  lowest_f -1.32924e+13
# (pid=18551) found new global minimum on step 15 with function value -1.32924e+13
# (pid=18551) warning: basinhopping: local minimization failure
# (pid=18551) basinhopping step 16: f -1.32924e+13 trial_f 2.66486e+14 accepted 0  lowest_f -1.32924e+13
# (pid=18473) basinhopping step 21: f -2.03237e+13 trial_f 2.48578e+10 accepted 0  lowest_f -2.03237e+13
# (pid=18499) basinhopping step 15: f -6.62631e+15 trial_f 1.02804e+09 accepted 0  lowest_f -6.62631e+15
# (pid=18577) basinhopping step 11: f -5.63367e+15 trial_f 2.36107e+12 accepted 0  lowest_f -5.63367e+15
# (pid=18473) basinhopping step 22: f -2.03237e+13 trial_f 7.85484e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18473) basinhopping step 23: f -2.03237e+13 trial_f 3.99632e+13 accepted 0  lowest_f -2.03237e+13
# (pid=18499) warning: basinhopping: local minimization failure
# (pid=18499) basinhopping step 16: f -6.62631e+15 trial_f 8.60324e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18525) basinhopping step 16: f -6.9352e+13 trial_f -2.87032e+13 accepted 0  lowest_f -6.9352e+13
# (pid=18525) warning: basinhopping: local minimization failure
# (pid=18525) basinhopping step 17: f -6.9352e+13 trial_f 3.04391e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18473) basinhopping step 24: f -2.03237e+13 trial_f 4.3149e+12 accepted 0  lowest_f -2.03237e+13
# (pid=18551) basinhopping step 17: f -1.32924e+13 trial_f 8.17723e+11 accepted 0  lowest_f -1.32924e+13
# (pid=18473) basinhopping step 25: f -2.03237e+13 trial_f 6.27695e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18499) basinhopping step 17: f -6.62631e+15 trial_f 5.69108e+14 accepted 0  lowest_f -6.62631e+15
# (pid=18551) basinhopping step 18: f -1.32924e+13 trial_f 8.07397e+11 accepted 0  lowest_f -1.32924e+13
# (pid=18577) basinhopping step 12: f -5.63367e+15 trial_f 2.87897e+12 accepted 0  lowest_f -5.63367e+15
# (pid=18551) warning: basinhopping: local minimization failure
# (pid=18551) basinhopping step 19: f -1.32924e+13 trial_f 1.01846e+12 accepted 0  lowest_f -1.32924e+13
# (pid=18499) basinhopping step 18: f -6.62631e+15 trial_f 7.72564e+08 accepted 0  lowest_f -6.62631e+15
# (pid=18473) warning: basinhopping: local minimization failure
# (pid=18473) basinhopping step 26: f -2.03237e+13 trial_f 6.19694e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18499) basinhopping step 19: f -6.62631e+15 trial_f 4.18456e+16 accepted 0  lowest_f -6.62631e+15
# (pid=18473) warning: basinhopping: local minimization failure
# (pid=18473) basinhopping step 27: f -2.03237e+13 trial_f 5.973e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18577) basinhopping step 13: f -5.63367e+15 trial_f 1.04682e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18525) basinhopping step 18: f -6.9352e+13 trial_f -2.69246e+13 accepted 0  lowest_f -6.9352e+13
# (pid=18577) basinhopping step 14: f -5.63367e+15 trial_f 1.50189e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18577) basinhopping step 15: f -5.63367e+15 trial_f 9.01694e+15 accepted 0  lowest_f -5.63367e+15
# (pid=18551) basinhopping step 20: f -1.32924e+13 trial_f 8.59992e+11 accepted 0  lowest_f -1.32924e+13
# (pid=18525) basinhopping step 19: f -6.9352e+13 trial_f 2.42126e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18499) warning: basinhopping: local minimization failure
# (pid=18499) basinhopping step 20: f -6.62631e+15 trial_f 1.66709e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18551) basinhopping step 21: f -1.32924e+13 trial_f 1.00851e+12 accepted 0  lowest_f -1.32924e+13
# (pid=18499) basinhopping step 21: f -6.62631e+15 trial_f 3.24629e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18525) basinhopping step 20: f -6.9352e+13 trial_f 4.00358e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18473) basinhopping step 28: f -2.03237e+13 trial_f 1.28513e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18577) basinhopping step 16: f -5.63367e+15 trial_f 1.09198e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18525) basinhopping step 21: f -6.9352e+13 trial_f 2.42347e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18499) basinhopping step 22: f -6.62631e+15 trial_f 2.19834e+08 accepted 0  lowest_f -6.62631e+15
# (pid=18551) basinhopping step 22: f -1.32924e+13 trial_f 8.48567e+11 accepted 0  lowest_f -1.32924e+13
# (pid=18499) basinhopping step 23: f -6.62631e+15 trial_f 1.18401e+16 accepted 0  lowest_f -6.62631e+15
# (pid=18473) basinhopping step 29: f -2.03237e+13 trial_f 6.62504e+10 accepted 0  lowest_f -2.03237e+13
# (pid=18499) basinhopping step 24: f -6.62631e+15 trial_f 9.934e+08 accepted 0  lowest_f -6.62631e+15
# (pid=18525) basinhopping step 22: f -6.9352e+13 trial_f -2.90924e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18577) warning: basinhopping: local minimization failure
# (pid=18577) basinhopping step 17: f -5.63367e+15 trial_f 7.74832e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18551) warning: basinhopping: local minimization failure
# (pid=18551) basinhopping step 23: f -1.44444e+13 trial_f -1.44444e+13 accepted 1  lowest_f -1.44444e+13
# (pid=18551) found new global minimum on step 23 with function value -1.44444e+13
# (pid=18499) basinhopping step 25: f -6.62631e+15 trial_f 3.21192e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18577) basinhopping step 18: f -5.63367e+15 trial_f 7.79688e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18551) basinhopping step 24: f -1.44444e+13 trial_f 1.01454e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18499) basinhopping step 26: f -6.62631e+15 trial_f 3.23765e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18525) basinhopping step 23: f -6.9352e+13 trial_f 6.04551e+11 accepted 0  lowest_f -6.9352e+13
# (pid=18473) basinhopping step 30: f -2.03237e+13 trial_f 1.28495e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18551) warning: basinhopping: local minimization failure
# (pid=18551) basinhopping step 25: f -1.44444e+13 trial_f 1.01805e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18551) basinhopping step 26: f -1.44444e+13 trial_f -2.96742e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18577) warning: basinhopping: local minimization failure
# (pid=18577) basinhopping step 19: f -5.63367e+15 trial_f 1.53858e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18499) warning: basinhopping: local minimization failure
# (pid=18499) basinhopping step 27: f -6.62631e+15 trial_f 1.09125e+09 accepted 0  lowest_f -6.62631e+15
# (pid=18551) warning: basinhopping: local minimization failure
# (pid=18551) basinhopping step 27: f -1.44444e+13 trial_f 1.82486e+16 accepted 0  lowest_f -1.44444e+13
# (pid=18473) basinhopping step 31: f -2.03237e+13 trial_f 6.62414e+10 accepted 0  lowest_f -2.03237e+13
# (pid=18525) warning: basinhopping: local minimization failure
# (pid=18525) basinhopping step 24: f -6.9352e+13 trial_f -6.60048e+13 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 28: f -1.44444e+13 trial_f 1.23752e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18577) basinhopping step 20: f -5.63367e+15 trial_f 1.50656e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18473) basinhopping step 32: f -2.03237e+13 trial_f 6.27486e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18499) basinhopping step 28: f -6.62631e+15 trial_f 3.24439e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18551) basinhopping step 29: f -1.44444e+13 trial_f 1.22824e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18551) basinhopping step 30: f -1.44444e+13 trial_f 1.0073e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18551) basinhopping step 31: f -1.44444e+13 trial_f 2.80176e+13 accepted 0  lowest_f -1.44444e+13
# (pid=18499) basinhopping step 29: f -6.62631e+15 trial_f 5.64569e+14 accepted 0  lowest_f -6.62631e+15
# (pid=18577) basinhopping step 21: f -5.63367e+15 trial_f 1.49982e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18473) basinhopping step 33: f -2.03237e+13 trial_f 7.64223e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18525) basinhopping step 25: f -6.9352e+13 trial_f 1.69802e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 32: f -1.44444e+13 trial_f 1.00644e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18499) basinhopping step 30: f -6.62631e+15 trial_f 3.24406e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18577) basinhopping step 22: f -5.63367e+15 trial_f 1.51361e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18499) warning: basinhopping: local minimization failure
# (pid=18499) basinhopping step 31: f -6.62631e+15 trial_f 8.60378e+15 accepted 0  lowest_f -6.62631e+15
# (pid=18525) basinhopping step 26: f -6.9352e+13 trial_f 4.59022e+11 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 33: f -1.44444e+13 trial_f 3.63263e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18525) basinhopping step 27: f -6.9352e+13 trial_f 4.07177e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18473) basinhopping step 34: f -2.03237e+13 trial_f 7.75162e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18525) warning: basinhopping: local minimization failure
# (pid=18525) basinhopping step 28: f -6.9352e+13 trial_f 1.92738e+16 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 34: f -1.44444e+13 trial_f 8.59273e+11 accepted 0  lowest_f -1.44444e+13
# (pid=18499) basinhopping step 32: f -2.36525e+16 trial_f -2.36525e+16 accepted 1  lowest_f -2.36525e+16
# (pid=18499) found new global minimum on step 32 with function value -2.36525e+16
# (pid=18499) basinhopping step 33: f -2.36525e+16 trial_f 9.934e+08 accepted 0  lowest_f -2.36525e+16
# (pid=18551) basinhopping step 35: f -1.44444e+13 trial_f 3.62802e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18499) basinhopping step 34: f -2.36525e+16 trial_f 3.11882e+15 accepted 0  lowest_f -2.36525e+16
# (pid=18551) basinhopping step 36: f -1.44444e+13 trial_f 5.31823e+11 accepted 0  lowest_f -1.44444e+13
# (pid=18473) basinhopping step 35: f -2.03237e+13 trial_f 7.18967e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18551) basinhopping step 37: f -1.44444e+13 trial_f 2.80181e+13 accepted 0  lowest_f -1.44444e+13
# (pid=18577) basinhopping step 23: f -5.63367e+15 trial_f 2.2907e+12 accepted 0  lowest_f -5.63367e+15
# (pid=18473) warning: basinhopping: local minimization failure
# (pid=18473) basinhopping step 36: f -2.03237e+13 trial_f 1.25947e+14 accepted 0  lowest_f -2.03237e+13
# (pid=18551) warning: basinhopping: local minimization failure
# (pid=18551) basinhopping step 38: f -1.44444e+13 trial_f 1.71022e+16 accepted 0  lowest_f -1.44444e+13
# (pid=18473) basinhopping step 37: f -2.03237e+13 trial_f 3.99632e+13 accepted 0  lowest_f -2.03237e+13
# (pid=18525) basinhopping step 29: f -6.9352e+13 trial_f 2.42407e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18525) basinhopping step 30: f -6.9352e+13 trial_f 1.82014e+14 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 39: f -1.44444e+13 trial_f 3.63214e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18551) basinhopping step 40: f -1.44444e+13 trial_f 2.80181e+13 accepted 0  lowest_f -1.44444e+13
# (pid=18499) basinhopping step 35: f -2.36525e+16 trial_f 3.21744e+15 accepted 0  lowest_f -2.36525e+16
# (pid=18577) basinhopping step 24: f -5.63367e+15 trial_f 1.46235e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18525) basinhopping step 31: f -6.9352e+13 trial_f 3.98776e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18525) basinhopping step 32: f -6.9352e+13 trial_f 2.41395e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 41: f -1.44444e+13 trial_f 8.53215e+11 accepted 0  lowest_f -1.44444e+13
# (pid=18551) basinhopping step 42: f -1.44444e+13 trial_f 2.80181e+13 accepted 0  lowest_f -1.44444e+13
# (pid=18525) basinhopping step 33: f -6.9352e+13 trial_f -4.7148e+13 accepted 0  lowest_f -6.9352e+13
# (pid=18551) warning: basinhopping: local minimization failure
# (pid=18551) basinhopping step 43: f -1.44444e+13 trial_f 7.92607e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18577) basinhopping step 25: f -5.63367e+15 trial_f 1.51124e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18551) basinhopping step 44: f -1.44444e+13 trial_f 3.63192e+12 accepted 0  lowest_f -1.44444e+13
# (pid=18525) basinhopping step 34: f -6.9352e+13 trial_f 5.5924e+11 accepted 0  lowest_f -6.9352e+13
# (pid=18499) basinhopping step 36: f -2.36525e+16 trial_f 9.934e+08 accepted 0  lowest_f -2.36525e+16
# (pid=18473) basinhopping step 38: f -2.03237e+13 trial_f 1.28501e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18577) basinhopping step 26: f -5.63367e+15 trial_f 2.31293e+12 accepted 0  lowest_f -5.63367e+15
# (pid=18525) warning: basinhopping: local minimization failure
# (pid=18525) basinhopping step 35: f -6.9352e+13 trial_f 2.55551e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 45: f -1.44444e+13 trial_f 5.31468e+11 accepted 0  lowest_f -1.44444e+13
# (pid=18577) basinhopping step 27: f -5.63367e+15 trial_f 6.80106e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18473) basinhopping step 39: f -2.03237e+13 trial_f 7.86959e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18577) basinhopping step 28: f -5.63367e+15 trial_f 1.50337e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18473) warning: basinhopping: local minimization failure
# (pid=18473) basinhopping step 40: f -2.03237e+13 trial_f 6.15806e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18499) basinhopping step 37: f -2.36525e+16 trial_f 3.21464e+15 accepted 0  lowest_f -2.36525e+16
# (pid=18577) warning: basinhopping: local minimization failure
# (pid=18577) basinhopping step 29: f -5.63367e+15 trial_f 7.88185e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18525) basinhopping step 36: f -6.9352e+13 trial_f 2.40564e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18473) basinhopping step 41: f -2.03237e+13 trial_f 6.28383e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18525) basinhopping step 37: f -6.9352e+13 trial_f -2.48597e+13 accepted 0  lowest_f -6.9352e+13
# (pid=18499) basinhopping step 38: f -2.36525e+16 trial_f 5.16033e+14 accepted 0  lowest_f -2.36525e+16
# (pid=18577) basinhopping step 30: f -5.63367e+15 trial_f 1.50347e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18473) basinhopping step 42: f -2.03237e+13 trial_f 5.93817e+12 accepted 0  lowest_f -2.03237e+13
# (pid=18577) warning: basinhopping: local minimization failure
# (pid=18577) basinhopping step 31: f -5.63367e+15 trial_f 7.79484e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18525) basinhopping step 38: f -6.9352e+13 trial_f 2.42287e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 46: f -1.44444e+13 trial_f 5.31697e+11 accepted 0  lowest_f -1.44444e+13
# (pid=18499) basinhopping step 39: f -2.36525e+16 trial_f 1.13893e+16 accepted 0  lowest_f -2.36525e+16
# (pid=18577) basinhopping step 32: f -5.63367e+15 trial_f 7.66558e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18499) basinhopping step 40: f -2.36525e+16 trial_f 5.21894e+14 accepted 0  lowest_f -2.36525e+16
# (pid=18525) basinhopping step 39: f -6.9352e+13 trial_f 4.07316e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18473) basinhopping step 43: f -2.03237e+13 trial_f 7.46123e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18551) basinhopping step 47: f -1.44444e+13 trial_f 8.5591e+11 accepted 0  lowest_f -1.44444e+13
# (pid=18499) basinhopping step 41: f -2.36525e+16 trial_f 1.11937e+09 accepted 0  lowest_f -2.36525e+16
# (pid=18577) basinhopping step 33: f -5.63367e+15 trial_f 2.30364e+12 accepted 0  lowest_f -5.63367e+15
# (pid=18499) basinhopping step 42: f -2.36525e+16 trial_f 5.59658e+14 accepted 0  lowest_f -2.36525e+16
# (pid=18525) basinhopping step 40: f -6.9352e+13 trial_f 6.12159e+11 accepted 0  lowest_f -6.9352e+13
# (pid=18473) basinhopping step 44: f -2.03237e+13 trial_f 1.26984e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18473) basinhopping step 45: f -2.03237e+13 trial_f 3.99747e+13 accepted 0  lowest_f -2.03237e+13
# (pid=18551) basinhopping step 48: f -1.44444e+13 trial_f 9.13581e+11 accepted 0  lowest_f -1.44444e+13
# (pid=18499) warning: basinhopping: local minimization failure
# (pid=18499) basinhopping step 43: f -2.36525e+16 trial_f 8.60981e+15 accepted 0  lowest_f -2.36525e+16
# (pid=18577) basinhopping step 34: f -5.63367e+15 trial_f 2.29259e+12 accepted 0  lowest_f -5.63367e+15
# (pid=18525) basinhopping step 41: f -6.9352e+13 trial_f 4.07067e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18499) basinhopping step 44: f -2.36525e+16 trial_f 3.51762e+15 accepted 0  lowest_f -2.36525e+16
# (pid=18551) basinhopping step 49: f -1.44444e+13 trial_f 5.36289e+11 accepted 0  lowest_f -1.44444e+13
# (pid=18551) adaptive stepsize: acceptance rate 0.120000 target 0.500000 new stepsize 0.45 old stepsize 0.5
# (pid=18473) basinhopping step 46: f -2.03237e+13 trial_f 3.52161e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18473) basinhopping step 47: f -2.03237e+13 trial_f 3.99632e+13 accepted 0  lowest_f -2.03237e+13
# (pid=18499) warning: basinhopping: local minimization failure
# (pid=18499) basinhopping step 45: f -2.36525e+16 trial_f 7.96833e+17 accepted 0  lowest_f -2.36525e+16
# (pid=18525) basinhopping step 42: f -6.9352e+13 trial_f -5.76835e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18551) basinhopping step 50: f -1.44444e+13 trial_f 8.5244e+11 accepted 0  lowest_f -1.44444e+13
# 2020-09-28 13:40:43,250	WARNING worker.py:1090 -- WARNING: 10 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=18577) warning: basinhopping: local minimization failure
# (pid=18577) basinhopping step 35: f -5.63367e+15 trial_f 7.7087e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18525) basinhopping step 43: f -6.9352e+13 trial_f 2.64836e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18577) basinhopping step 36: f -5.63367e+15 trial_f 6.7847e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18499) basinhopping step 46: f -2.36525e+16 trial_f 5.64433e+14 accepted 0  lowest_f -2.36525e+16
# (pid=18499) basinhopping step 47: f -2.36525e+16 trial_f 9.95535e+08 accepted 0  lowest_f -2.36525e+16
# (pid=18577) basinhopping step 37: f -5.63367e+15 trial_f 7.79464e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18525) basinhopping step 44: f -6.9352e+13 trial_f 4.05957e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18964) basinhopping step 0: f -1.08394e+13
# (pid=18473) basinhopping step 48: f -2.03237e+13 trial_f 1.39967e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18525) warning: basinhopping: local minimization failure
# (pid=18525) basinhopping step 45: f -6.9352e+13 trial_f 3.0428e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18499) basinhopping step 48: f -2.36525e+16 trial_f 3.8036e+14 accepted 0  lowest_f -2.36525e+16
# (pid=18577) basinhopping step 38: f -5.63367e+15 trial_f 1.50851e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18964) basinhopping step 1: f -1.08394e+13 trial_f 1.03128e+12 accepted 0  lowest_f -1.08394e+13
# (pid=18964) basinhopping step 2: f -1.08394e+13 trial_f 7.77257e+13 accepted 0  lowest_f -1.08394e+13
# (pid=18473) basinhopping step 49: f -2.03237e+13 trial_f 1.30136e+11 accepted 0  lowest_f -2.03237e+13
# (pid=18473) adaptive stepsize: acceptance rate 0.020000 target 0.500000 new stepsize 0.45 old stepsize 0.5
# (pid=18499) basinhopping step 49: f -2.36525e+16 trial_f 3.23314e+15 accepted 0  lowest_f -2.36525e+16
# (pid=18499) adaptive stepsize: acceptance rate 0.020000 target 0.500000 new stepsize 0.45 old stepsize 0.5
# (pid=18473) basinhopping step 50: f -2.03237e+13 trial_f 1.40486e+11 accepted 0  lowest_f -2.03237e+13
# 2020-09-28 13:41:27,803	WARNING worker.py:1090 -- WARNING: 10 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=18964) basinhopping step 3: f -1.08394e+13 trial_f 1.04136e+12 accepted 0  lowest_f -1.08394e+13
# (pid=18525) basinhopping step 46: f -6.9352e+13 trial_f 2.41662e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18980) warning: basinhopping: local minimization failure
# (pid=18980) basinhopping step 0: f 2.99706e+16
# (pid=18499) basinhopping step 50: f -2.36525e+16 trial_f 5.19174e+14 accepted 0  lowest_f -2.36525e+16
# 2020-09-28 13:41:35,571	WARNING worker.py:1090 -- WARNING: 10 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=18980) basinhopping step 1: f -1.44293e+14 trial_f -1.44293e+14 accepted 1  lowest_f -1.44293e+14
# (pid=18980) found new global minimum on step 1 with function value -1.44293e+14
# (pid=18577) warning: basinhopping: local minimization failure
# (pid=18577) basinhopping step 39: f -5.63367e+15 trial_f 7.87184e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18964) basinhopping step 4: f -1.08394e+13 trial_f 1.40061e+12 accepted 0  lowest_f -1.08394e+13
# (pid=18525) warning: basinhopping: local minimization failure
# (pid=18525) basinhopping step 47: f -6.9352e+13 trial_f 2.40741e+09 accepted 0  lowest_f -6.9352e+13
# (pid=18993) basinhopping step 0: f 1.05593e+14
# (pid=18525) warning: basinhopping: local minimization failure
# (pid=18525) basinhopping step 48: f -6.9352e+13 trial_f 1.2895e+11 accepted 0  lowest_f -6.9352e+13
# (pid=18964) basinhopping step 5: f -1.08394e+13 trial_f 9.77585e+11 accepted 0  lowest_f -1.08394e+13
# (pid=18993) basinhopping step 1: f 7.17084e+08 trial_f 7.17084e+08 accepted 1  lowest_f 7.17084e+08
# (pid=18993) found new global minimum on step 1 with function value 7.17084e+08
# (pid=18525) basinhopping step 49: f -6.9352e+13 trial_f 4.04928e+12 accepted 0  lowest_f -6.9352e+13
# (pid=18525) adaptive stepsize: acceptance rate 0.040000 target 0.500000 new stepsize 0.45 old stepsize 0.5
# (pid=18993) basinhopping step 2: f 7.17084e+08 trial_f 8.87596e+14 accepted 0  lowest_f 7.17084e+08
# (pid=18993) basinhopping step 3: f 7.17084e+08 trial_f 7.25198e+08 accepted 0  lowest_f 7.17084e+08
# (pid=18980) basinhopping step 2: f -1.44293e+14 trial_f 4.43879e+11 accepted 0  lowest_f -1.44293e+14
# (pid=18525) basinhopping step 50: f -6.9352e+13 trial_f -2.48634e+13 accepted 0  lowest_f -6.9352e+13
# (pid=18964) basinhopping step 6: f -1.08394e+13 trial_f 1.03995e+12 accepted 0  lowest_f -1.08394e+13
# 2020-09-28 13:42:00,632	WARNING worker.py:1090 -- WARNING: 10 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=18980) warning: basinhopping: local minimization failure
# (pid=18980) basinhopping step 3: f -1.44293e+14 trial_f 7.14642e+16 accepted 0  lowest_f -1.44293e+14
# (pid=18577) basinhopping step 40: f -5.63367e+15 trial_f 1.51835e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18964) basinhopping step 7: f -1.08394e+13 trial_f 1.04405e+12 accepted 0  lowest_f -1.08394e+13
# (pid=18577) warning: basinhopping: local minimization failure
# (pid=18577) basinhopping step 41: f -5.63367e+15 trial_f 7.87611e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18980) warning: basinhopping: local minimization failure
# (pid=18980) basinhopping step 4: f -1.44293e+14 trial_f 4.22307e+11 accepted 0  lowest_f -1.44293e+14
# (pid=19011) warning: basinhopping: local minimization failure
# (pid=19011) basinhopping step 0: f -2.92777e+12
# (pid=18980) basinhopping step 5: f -2.03803e+14 trial_f -2.03803e+14 accepted 1  lowest_f -2.03803e+14
# (pid=18980) found new global minimum on step 5 with function value -2.03803e+14
# (pid=18964) basinhopping step 8: f -1.08394e+13 trial_f 1.40034e+12 accepted 0  lowest_f -1.08394e+13
# (pid=18993) basinhopping step 4: f 7.15895e+08 trial_f 7.15895e+08 accepted 1  lowest_f 7.15895e+08
# (pid=18993) found new global minimum on step 4 with function value 7.15895e+08
# (pid=18980) basinhopping step 6: f -2.03803e+14 trial_f 4.47568e+11 accepted 0  lowest_f -2.03803e+14
# (pid=18964) basinhopping step 9: f -1.43226e+13 trial_f -1.43226e+13 accepted 1  lowest_f -1.43226e+13
# (pid=18964) found new global minimum on step 9 with function value -1.43226e+13
# (pid=19011) basinhopping step 1: f -2.92777e+12 trial_f 1.84971e+09 accepted 0  lowest_f -2.92777e+12
# (pid=18980) warning: basinhopping: local minimization failure
# (pid=18980) basinhopping step 7: f -2.03803e+14 trial_f 4.46025e+11 accepted 0  lowest_f -2.03803e+14
# (pid=18577) basinhopping step 42: f -5.63367e+15 trial_f 1.47748e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18964) basinhopping step 10: f -1.43226e+13 trial_f -1.29257e+13 accepted 0  lowest_f -1.43226e+13
# (pid=18993) warning: basinhopping: local minimization failure
# (pid=18993) basinhopping step 5: f -5.85344e+15 trial_f -5.85344e+15 accepted 1  lowest_f -5.85344e+15
# (pid=18993) found new global minimum on step 5 with function value -5.85344e+15
# (pid=18577) basinhopping step 43: f -5.63367e+15 trial_f 6.80107e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18964) warning: basinhopping: local minimization failure
# (pid=18964) basinhopping step 11: f -1.43226e+13 trial_f 9.91185e+11 accepted 0  lowest_f -1.43226e+13
# (pid=19011) basinhopping step 2: f -8.6139e+12 trial_f -8.6139e+12 accepted 1  lowest_f -8.6139e+12
# (pid=19011) found new global minimum on step 2 with function value -8.6139e+12
# (pid=18980) basinhopping step 8: f -2.03803e+14 trial_f 2.37719e+13 accepted 0  lowest_f -2.03803e+14
# (pid=19011) basinhopping step 3: f -8.6139e+12 trial_f 4.06854e+11 accepted 0  lowest_f -8.6139e+12
# (pid=18964) basinhopping step 12: f -1.43226e+13 trial_f 9.77652e+11 accepted 0  lowest_f -1.43226e+13
# (pid=18993) basinhopping step 6: f -5.85344e+15 trial_f -5.58966e+15 accepted 0  lowest_f -5.85344e+15
# (pid=18980) basinhopping step 9: f -2.03803e+14 trial_f 4.48482e+11 accepted 0  lowest_f -2.03803e+14
# (pid=18577) basinhopping step 44: f -5.63367e+15 trial_f 1.47334e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18964) basinhopping step 13: f -1.43226e+13 trial_f -1.29257e+13 accepted 0  lowest_f -1.43226e+13
# (pid=18964) warning: basinhopping: local minimization failure
# (pid=18964) basinhopping step 14: f -1.43226e+13 trial_f 6.60067e+11 accepted 0  lowest_f -1.43226e+13
# (pid=18993) basinhopping step 7: f -5.85344e+15 trial_f 8.7993e+14 accepted 0  lowest_f -5.85344e+15
# (pid=18980) basinhopping step 10: f -2.03803e+14 trial_f 1.49384e+14 accepted 0  lowest_f -2.03803e+14
# (pid=18964) basinhopping step 15: f -1.43226e+13 trial_f 9.48231e+11 accepted 0  lowest_f -1.43226e+13
# (pid=19011) basinhopping step 4: f -8.6139e+12 trial_f 4.90502e+10 accepted 0  lowest_f -8.6139e+12
# (pid=18980) warning: basinhopping: local minimization failure
# (pid=18980) basinhopping step 11: f -2.03803e+14 trial_f 2.36233e+17 accepted 0  lowest_f -2.03803e+14
# (pid=18993) basinhopping step 8: f -5.85344e+15 trial_f 8.77521e+14 accepted 0  lowest_f -5.85344e+15
# (pid=18577) basinhopping step 45: f -5.63367e+15 trial_f 2.31126e+12 accepted 0  lowest_f -5.63367e+15
# (pid=18964) basinhopping step 16: f -1.43226e+13 trial_f 9.57984e+11 accepted 0  lowest_f -1.43226e+13
# (pid=18964) warning: basinhopping: local minimization failure
# (pid=18964) basinhopping step 17: f -1.43226e+13 trial_f 9.90356e+11 accepted 0  lowest_f -1.43226e+13
# (pid=18577) warning: basinhopping: local minimization failure
# (pid=18577) basinhopping step 46: f -5.63367e+15 trial_f 7.79468e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18964) basinhopping step 18: f -1.43226e+13 trial_f 1.02161e+12 accepted 0  lowest_f -1.43226e+13
# (pid=19011) basinhopping step 5: f -8.6139e+12 trial_f 6.0684e+10 accepted 0  lowest_f -8.6139e+12
# (pid=18993) basinhopping step 9: f -5.85344e+15 trial_f 7.10192e+08 accepted 0  lowest_f -5.85344e+15
# (pid=18964) basinhopping step 19: f -1.43226e+13 trial_f 1.04438e+12 accepted 0  lowest_f -1.43226e+13
# (pid=19011) basinhopping step 6: f -8.6139e+12 trial_f 3.34579e+09 accepted 0  lowest_f -8.6139e+12
# (pid=18577) basinhopping step 47: f -5.63367e+15 trial_f 1.49332e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18980) basinhopping step 12: f -2.03803e+14 trial_f 4.29231e+12 accepted 0  lowest_f -2.03803e+14
# (pid=19011) basinhopping step 7: f -8.6139e+12 trial_f 4.06597e+11 accepted 0  lowest_f -8.6139e+12
# (pid=18964) basinhopping step 20: f -1.43226e+13 trial_f 1.42318e+12 accepted 0  lowest_f -1.43226e+13
# (pid=19011) warning: basinhopping: local minimization failure
# (pid=19011) basinhopping step 8: f -8.6139e+12 trial_f 7.62785e+10 accepted 0  lowest_f -8.6139e+12
# (pid=18980) basinhopping step 13: f -2.03803e+14 trial_f -4.75868e+12 accepted 0  lowest_f -2.03803e+14
# (pid=18993) basinhopping step 10: f -5.85344e+15 trial_f 8.84674e+14 accepted 0  lowest_f -5.85344e+15
# (pid=18993) basinhopping step 11: f -5.85344e+15 trial_f 7.13727e+08 accepted 0  lowest_f -5.85344e+15
# (pid=18577) basinhopping step 48: f -5.63367e+15 trial_f -1.97559e+12 accepted 0  lowest_f -5.63367e+15
# (pid=18980) basinhopping step 14: f -2.03803e+14 trial_f -1.97071e+14 accepted 0  lowest_f -2.03803e+14
# (pid=18577) basinhopping step 49: f -5.63367e+15 trial_f 7.7989e+10 accepted 0  lowest_f -5.63367e+15
# (pid=18577) adaptive stepsize: acceptance rate 0.040000 target 0.500000 new stepsize 0.45 old stepsize 0.5
# (pid=18980) basinhopping step 15: f -3.22048e+14 trial_f -3.22048e+14 accepted 1  lowest_f -3.22048e+14
# (pid=18980) found new global minimum on step 15 with function value -3.22048e+14
# (pid=18980) basinhopping step 16: f -3.22048e+14 trial_f 4.48688e+11 accepted 0  lowest_f -3.22048e+14
# (pid=18993) basinhopping step 12: f -5.85344e+15 trial_f 8.76883e+14 accepted 0  lowest_f -5.85344e+15
# (pid=18577) basinhopping step 50: f -5.63367e+15 trial_f 1.50312e+13 accepted 0  lowest_f -5.63367e+15
# (pid=18980) basinhopping step 17: f -3.22048e+14 trial_f 4.4545e+11 accepted 0  lowest_f -3.22048e+14
# 2020-09-28 13:44:12,355	WARNING worker.py:1090 -- WARNING: 10 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=18980) basinhopping step 18: f -3.22048e+14 trial_f -2.02153e+14 accepted 0  lowest_f -3.22048e+14
# (pid=18964) warning: basinhopping: local minimization failure
# (pid=18964) basinhopping step 21: f -1.43226e+13 trial_f 5.46305e+11 accepted 0  lowest_f -1.43226e+13
# (pid=18980) basinhopping step 19: f -3.22048e+14 trial_f 2.17306e+13 accepted 0  lowest_f -3.22048e+14
# (pid=19078) basinhopping step 0: f -6.67112e+15
# (pid=18993) warning: basinhopping: local minimization failure
# (pid=18993) basinhopping step 13: f -5.85344e+15 trial_f 6.91105e+08 accepted 0  lowest_f -5.85344e+15
# (pid=18993) basinhopping step 14: f -5.85344e+15 trial_f 5.19705e+08 accepted 0  lowest_f -5.85344e+15
# (pid=18964) basinhopping step 22: f -1.43226e+13 trial_f 1.03896e+12 accepted 0  lowest_f -1.43226e+13
# (pid=18980) basinhopping step 20: f -3.22048e+14 trial_f 3.20688e+13 accepted 0  lowest_f -3.22048e+14
# (pid=18980) basinhopping step 21: f -3.22048e+14 trial_f 4.46934e+11 accepted 0  lowest_f -3.22048e+14
# (pid=18964) basinhopping step 23: f -1.43226e+13 trial_f 1.03572e+12 accepted 0  lowest_f -1.43226e+13
# (pid=18964) basinhopping step 24: f -1.43226e+13 trial_f 7.77257e+13 accepted 0  lowest_f -1.43226e+13
# (pid=18980) warning: basinhopping: local minimization failure
# (pid=18980) basinhopping step 22: f -3.22048e+14 trial_f 4.52384e+11 accepted 0  lowest_f -3.22048e+14
# (pid=19078) warning: basinhopping: local minimization failure
# (pid=19078) basinhopping step 1: f -6.67112e+15 trial_f 4.3231e+11 accepted 0  lowest_f -6.67112e+15
# (pid=18964) basinhopping step 25: f -1.43226e+13 trial_f 7.77259e+13 accepted 0  lowest_f -1.43226e+13
# (pid=19078) basinhopping step 2: f -6.67112e+15 trial_f 4.37309e+11 accepted 0  lowest_f -6.67112e+15
# (pid=18964) warning: basinhopping: local minimization failure
# (pid=18964) basinhopping step 26: f -1.43226e+13 trial_f 9.62191e+11 accepted 0  lowest_f -1.43226e+13
# (pid=18993) basinhopping step 15: f -5.85344e+15 trial_f 7.1268e+08 accepted 0  lowest_f -5.85344e+15
# (pid=18964) basinhopping step 27: f -1.43226e+13 trial_f 1.03884e+12 accepted 0  lowest_f -1.43226e+13
# (pid=18980) basinhopping step 23: f -3.22048e+14 trial_f 4.45243e+11 accepted 0  lowest_f -3.22048e+14
# (pid=18964) basinhopping step 28: f -1.43226e+13 trial_f 9.79095e+11 accepted 0  lowest_f -1.43226e+13
# (pid=19011) basinhopping step 9: f -8.6139e+12 trial_f 1.88661e+09 accepted 0  lowest_f -8.6139e+12
# (pid=19078) warning: basinhopping: local minimization failure
# (pid=19078) basinhopping step 3: f -6.67112e+15 trial_f 4.3744e+11 accepted 0  lowest_f -6.67112e+15
# (pid=19078) basinhopping step 4: f -6.67112e+15 trial_f 2.03004e+16 accepted 0  lowest_f -6.67112e+15
# (pid=18964) basinhopping step 29: f -1.43226e+13 trial_f 1.02286e+12 accepted 0  lowest_f -1.43226e+13
# (pid=18993) basinhopping step 16: f -5.85344e+15 trial_f 7.1252e+08 accepted 0  lowest_f -5.85344e+15
# (pid=19078) basinhopping step 5: f -6.67112e+15 trial_f 8.38015e+14 accepted 0  lowest_f -6.67112e+15
# (pid=18980) warning: basinhopping: local minimization failure
# (pid=18980) basinhopping step 24: f -3.22048e+14 trial_f 4.14132e+11 accepted 0  lowest_f -3.22048e+14
# (pid=19011) basinhopping step 10: f -8.6139e+12 trial_f -2.83237e+12 accepted 0  lowest_f -8.6139e+12
# (pid=18980) warning: basinhopping: local minimization failure
# (pid=18980) basinhopping step 25: f -3.22048e+14 trial_f 4.48778e+11 accepted 0  lowest_f -3.22048e+14
# (pid=18964) basinhopping step 30: f -1.43226e+13 trial_f 9.58423e+11 accepted 0  lowest_f -1.43226e+13
# (pid=18980) basinhopping step 26: f -3.22048e+14 trial_f 1.48938e+14 accepted 0  lowest_f -3.22048e+14
# (pid=18993) basinhopping step 17: f -5.85344e+15 trial_f 6.55072e+08 accepted 0  lowest_f -5.85344e+15
# (pid=19011) basinhopping step 11: f -8.6139e+12 trial_f 6.17973e+10 accepted 0  lowest_f -8.6139e+12
# (pid=19078) basinhopping step 6: f -6.67112e+15 trial_f 1.31394e+14 accepted 0  lowest_f -6.67112e+15
# (pid=18980) warning: basinhopping: local minimization failure
# (pid=18980) basinhopping step 27: f -3.22048e+14 trial_f 2.52513e+11 accepted 0  lowest_f -3.22048e+14
# (pid=19011) basinhopping step 12: f -8.6139e+12 trial_f 6.51918e+10 accepted 0  lowest_f -8.6139e+12
# (pid=19011) basinhopping step 13: f -8.6139e+12 trial_f 4.053e+11 accepted 0  lowest_f -8.6139e+12
# (pid=19078) warning: basinhopping: local minimization failure
# (pid=19078) basinhopping step 7: f -6.67112e+15 trial_f 5.37221e+14 accepted 0  lowest_f -6.67112e+15
# (pid=18964) basinhopping step 31: f -1.43226e+13 trial_f -1.29257e+13 accepted 0  lowest_f -1.43226e+13
# (pid=19078) basinhopping step 8: f -6.67112e+15 trial_f 3.7094e+15 accepted 0  lowest_f -6.67112e+15
# (pid=18980) basinhopping step 28: f -3.22048e+14 trial_f 2.16316e+12 accepted 0  lowest_f -3.22048e+14
# (pid=19011) basinhopping step 14: f -8.6139e+12 trial_f 1.2691e+09 accepted 0  lowest_f -8.6139e+12
# (pid=18980) basinhopping step 29: f -3.22048e+14 trial_f -2.9634e+14 accepted 0  lowest_f -3.22048e+14
# (pid=18980) basinhopping step 30: f -3.22048e+14 trial_f 1.08576e+15 accepted 0  lowest_f -3.22048e+14
# (pid=19011) basinhopping step 15: f -8.6139e+12 trial_f -4.7606e+12 accepted 0  lowest_f -8.6139e+12
# (pid=18993) basinhopping step 18: f -5.85344e+15 trial_f 1.67631e+14 accepted 0  lowest_f -5.85344e+15
# (pid=18964) warning: basinhopping: local minimization failure
# (pid=18964) basinhopping step 32: f -1.43226e+13 trial_f 7.67852e+11 accepted 0  lowest_f -1.43226e+13
# (pid=19011) basinhopping step 16: f -8.6139e+12 trial_f 4.04424e+11 accepted 0  lowest_f -8.6139e+12
# (pid=18964) warning: basinhopping: local minimization failure
# (pid=18964) basinhopping step 33: f -1.43226e+13 trial_f 9.90145e+11 accepted 0  lowest_f -1.43226e+13
# (pid=18964) basinhopping step 34: f -1.43226e+13 trial_f 9.77854e+11 accepted 0  lowest_f -1.43226e+13
# (pid=18993) basinhopping step 19: f -5.85344e+15 trial_f 7.1268e+08 accepted 0  lowest_f -5.85344e+15
# (pid=19078) basinhopping step 9: f -6.67112e+15 trial_f 1.06325e+14 accepted 0  lowest_f -6.67112e+15
# (pid=18980) basinhopping step 31: f -3.22048e+14 trial_f -2.48357e+14 accepted 0  lowest_f -3.22048e+14
# (pid=19011) basinhopping step 17: f -8.6139e+12 trial_f 3.40592e+09 accepted 0  lowest_f -8.6139e+12
# (pid=18964) basinhopping step 35: f -1.43226e+13 trial_f 9.77893e+11 accepted 0  lowest_f -1.43226e+13
# (pid=18964) basinhopping step 36: f -1.43226e+13 trial_f 7.77255e+13 accepted 0  lowest_f -1.43226e+13
# (pid=18964) basinhopping step 37: f -1.43226e+13 trial_f 7.77259e+13 accepted 0  lowest_f -1.43226e+13
# (pid=18993) basinhopping step 20: f -5.85344e+15 trial_f 8.77022e+14 accepted 0  lowest_f -5.85344e+15
# (pid=19011) basinhopping step 18: f -8.6139e+12 trial_f -2.37083e+10 accepted 0  lowest_f -8.6139e+12
# (pid=18964) basinhopping step 38: f -1.43226e+13 trial_f 1.01586e+12 accepted 0  lowest_f -1.43226e+13
# (pid=18993) warning: basinhopping: local minimization failure
# (pid=18993) basinhopping step 21: f -5.85344e+15 trial_f 3.92046e+15 accepted 0  lowest_f -5.85344e+15
# (pid=19078) basinhopping step 10: f -6.67112e+15 trial_f 1.06324e+14 accepted 0  lowest_f -6.67112e+15
# (pid=18964) basinhopping step 39: f -1.43226e+13 trial_f -6.52591e+12 accepted 0  lowest_f -1.43226e+13
# ...
# (pid=19078) warning: basinhopping: local minimization failure
# (pid=19078) basinhopping step 47: f -2.66101e+16 trial_f 4.39234e+11 accepted 0  lowest_f -2.66101e+16
# (pid=19603) basinhopping step 11: f 2.38954e+08 trial_f 9.53725e+13 accepted 0  lowest_f 2.38954e+08
# (pid=19637) basinhopping step 8: f -1.85759e+13 trial_f 2.06353e+11 accepted 0  lowest_f -1.85759e+13
# (pid=19465) warning: basinhopping: local minimization failure
# (pid=19465) basinhopping step 33: f -1.05045e+15 trial_f 5.69667e+10 accepted 0  lowest_f -1.05045e+15
# (pid=19078) warning: basinhopping: local minimization failure
# (pid=19078) basinhopping step 48: f -2.66101e+16 trial_f 4.32521e+11 accepted 0  lowest_f -2.66101e+16
# (pid=19428) basinhopping step 29: f -7.79325e+14 trial_f 2.72581e+12 accepted 0  lowest_f -7.79325e+14
# (pid=19637) basinhopping step 9: f -1.85759e+13 trial_f 2.1593e+09 accepted 0  lowest_f -1.85759e+13
# (pid=19078) basinhopping step 49: f -2.66101e+16 trial_f 8.47856e+14 accepted 0  lowest_f -2.66101e+16
# (pid=19078) adaptive stepsize: acceptance rate 0.040000 target 0.500000 new stepsize 0.45 old stepsize 0.5
# (pid=19637) warning: basinhopping: local minimization failure
# (pid=19637) basinhopping step 10: f -1.85759e+13 trial_f 2.83995e+09 accepted 0  lowest_f -1.85759e+13
# (pid=19637) basinhopping step 11: f -1.85759e+13 trial_f 1.41075e+12 accepted 0  lowest_f -1.85759e+13
# (pid=19465) basinhopping step 34: f -1.05045e+15 trial_f 4.53805e+11 accepted 0  lowest_f -1.05045e+15
# (pid=19078) basinhopping step 50: f -2.66101e+16 trial_f 8.35644e+14 accepted 0  lowest_f -2.66101e+16
# 2020-09-28 13:54:39,913	WARNING worker.py:1090 -- WARNING: 10 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=19428) basinhopping step 30: f -7.79325e+14 trial_f 3.64808e+12 accepted 0  lowest_f -7.79325e+14
# (pid=19637) basinhopping step 12: f -1.85759e+13 trial_f 1.43955e+12 accepted 0  lowest_f -1.85759e+13
# (pid=19428) basinhopping step 31: f -7.79325e+14 trial_f 5.79514e+13 accepted 0  lowest_f -7.79325e+14
# (pid=19724) warning: basinhopping: local minimization failure
# (pid=19724) basinhopping step 0: f 5.94258e+11
# (pid=19603) basinhopping step 12: f -3.53624e+13 trial_f -3.53624e+13 accepted 1  lowest_f -3.53624e+13
# (pid=19603) found new global minimum on step 12 with function value -3.53624e+13
# (pid=19724) basinhopping step 1: f 5.94258e+11 trial_f 1.26954e+14 accepted 0  lowest_f 5.94258e+11
# (pid=19465) basinhopping step 35: f -1.05045e+15 trial_f 4.63041e+11 accepted 0  lowest_f -1.05045e+15
# (pid=19603) basinhopping step 13: f -3.53624e+13 trial_f 3.44385e+08 accepted 0  lowest_f -3.53624e+13
# (pid=19724) basinhopping step 2: f 5.94258e+11 trial_f 7.01563e+14 accepted 0  lowest_f 5.94258e+11
# (pid=19465) basinhopping step 36: f -1.05045e+15 trial_f -2.71946e+14 accepted 0  lowest_f -1.05045e+15
# (pid=19603) warning: basinhopping: local minimization failure
# (pid=19603) basinhopping step 14: f -3.53624e+13 trial_f 3.53711e+08 accepted 0  lowest_f -3.53624e+13
# (pid=19637) basinhopping step 13: f -1.85759e+13 trial_f 2.00765e+11 accepted 0  lowest_f -1.85759e+13
# (pid=19724) warning: basinhopping: local minimization failure
# (pid=19724) basinhopping step 3: f 5.85709e+11 trial_f 5.85709e+11 accepted 1  lowest_f 5.85709e+11
# (pid=19724) found new global minimum on step 3 with function value 5.85709e+11
# (pid=19603) basinhopping step 15: f -3.53624e+13 trial_f 3.02563e+08 accepted 0  lowest_f -3.53624e+13
# (pid=19724) warning: basinhopping: local minimization failure
# (pid=19724) basinhopping step 4: f 5.85709e+11 trial_f 5.94258e+11 accepted 0  lowest_f 5.85709e+11
# (pid=19637) basinhopping step 14: f -1.85759e+13 trial_f -1.30764e+13 accepted 0  lowest_f -1.85759e+13
# (pid=19465) basinhopping step 37: f -1.05045e+15 trial_f 3.36854e+12 accepted 0  lowest_f -1.05045e+15
# (pid=19465) basinhopping step 38: f -1.05045e+15 trial_f 1.5338e+13 accepted 0  lowest_f -1.05045e+15
# (pid=19637) basinhopping step 15: f -1.85759e+13 trial_f -9.67873e+11 accepted 0  lowest_f -1.85759e+13
# (pid=19428) basinhopping step 32: f -7.79325e+14 trial_f 1.57313e+13 accepted 0  lowest_f -7.79325e+14
# (pid=19428) basinhopping step 33: f -7.79325e+14 trial_f 3.18969e+15 accepted 0  lowest_f -7.79325e+14
# (pid=19428) basinhopping step 34: f -7.79325e+14 trial_f 1.70911e+12 accepted 0  lowest_f -7.79325e+14
# (pid=19603) warning: basinhopping: local minimization failure
# (pid=19603) basinhopping step 16: f -3.53624e+13 trial_f 3.53287e+08 accepted 0  lowest_f -3.53624e+13
# (pid=19724) basinhopping step 5: f 5.85709e+11 trial_f 5.92296e+11 accepted 0  lowest_f 5.85709e+11
# (pid=19603) warning: basinhopping: local minimization failure
# (pid=19603) basinhopping step 17: f -3.53624e+13 trial_f 3.70087e+08 accepted 0  lowest_f -3.53624e+13
# (pid=19465) basinhopping step 39: f -1.05045e+15 trial_f 3.37629e+12 accepted 0  lowest_f -1.05045e+15
# (pid=19724) warning: basinhopping: local minimization failure
# (pid=19724) basinhopping step 6: f 5.85709e+11 trial_f 5.85709e+11 accepted 1  lowest_f 5.85709e+11
# (pid=19428) basinhopping step 35: f -7.79325e+14 trial_f 5.35774e+13 accepted 0  lowest_f -7.79325e+14
# (pid=19603) warning: basinhopping: local minimization failure
# (pid=19603) basinhopping step 18: f -3.53624e+13 trial_f 3.54208e+08 accepted 0  lowest_f -3.53624e+13
# (pid=19637) basinhopping step 16: f -6.88715e+13 trial_f -6.88715e+13 accepted 1  lowest_f -6.88715e+13
# (pid=19637) found new global minimum on step 16 with function value -6.88715e+13
# (pid=19428) basinhopping step 36: f -7.79325e+14 trial_f 1.5864e+13 accepted 0  lowest_f -7.79325e+14
# (pid=19428) basinhopping step 37: f -7.79325e+14 trial_f 3.18972e+15 accepted 0  lowest_f -7.79325e+14
# (pid=19465) basinhopping step 40: f -1.05045e+15 trial_f 3.29245e+12 accepted 0  lowest_f -1.05045e+15
# (pid=19637) basinhopping step 17: f -6.88715e+13 trial_f 1.98207e+11 accepted 0  lowest_f -6.88715e+13
# (pid=19465) basinhopping step 41: f -1.05045e+15 trial_f 1.00751e+12 accepted 0  lowest_f -1.05045e+15
# (pid=19428) warning: basinhopping: local minimization failure
# (pid=19428) basinhopping step 38: f -7.79325e+14 trial_f 1.7193e+12 accepted 0  lowest_f -7.79325e+14
# (pid=19637) basinhopping step 18: f -6.88715e+13 trial_f 1.36811e+12 accepted 0  lowest_f -6.88715e+13
# (pid=19637) warning: basinhopping: local minimization failure
# (pid=19637) basinhopping step 19: f -6.88715e+13 trial_f 2.83572e+09 accepted 0  lowest_f -6.88715e+13
# (pid=19724) basinhopping step 7: f 5.85709e+11 trial_f 1.0816e+14 accepted 0  lowest_f 5.85709e+11
# (pid=19637) basinhopping step 20: f -6.88715e+13 trial_f 1.39429e+12 accepted 0  lowest_f -6.88715e+13
# (pid=19603) basinhopping step 19: f -3.53624e+13 trial_f 3.44385e+08 accepted 0  lowest_f -3.53624e+13
# (pid=19465) basinhopping step 42: f -1.05045e+15 trial_f 1.46333e+13 accepted 0  lowest_f -1.05045e+15
# (pid=19428) basinhopping step 39: f -7.79325e+14 trial_f 1.65397e+12 accepted 0  lowest_f -7.79325e+14
# (pid=19637) basinhopping step 21: f -6.88715e+13 trial_f 1.9541e+11 accepted 0  lowest_f -6.88715e+13
# (pid=19428) warning: basinhopping: local minimization failure
# (pid=19428) basinhopping step 40: f -7.79325e+14 trial_f -7.79325e+14 accepted 1  lowest_f -7.79325e+14
# (pid=19465) warning: basinhopping: local minimization failure
# (pid=19465) basinhopping step 43: f -1.05045e+15 trial_f 7.05672e+10 accepted 0  lowest_f -1.05045e+15
# (pid=19603) basinhopping step 20: f -1.89951e+15 trial_f -1.89951e+15 accepted 1  lowest_f -1.89951e+15
# (pid=19603) found new global minimum on step 20 with function value -1.89951e+15
# (pid=19637) warning: basinhopping: local minimization failure
# (pid=19637) basinhopping step 22: f -6.88715e+13 trial_f 2.92407e+09 accepted 0  lowest_f -6.88715e+13
# (pid=19428) warning: basinhopping: local minimization failure
# (pid=19428) basinhopping step 41: f -7.79325e+14 trial_f -7.79325e+14 accepted 1  lowest_f -7.79325e+14
# (pid=19428) basinhopping step 42: f -7.79325e+14 trial_f 3.18972e+15 accepted 0  lowest_f -7.79325e+14
# (pid=19428) warning: basinhopping: local minimization failure
# (pid=19428) basinhopping step 43: f -2.7297e+15 trial_f -2.7297e+15 accepted 1  lowest_f -2.7297e+15
# (pid=19428) found new global minimum on step 43 with function value -2.7297e+15
# (pid=19465) basinhopping step 44: f -1.05045e+15 trial_f 4.67428e+11 accepted 0  lowest_f -1.05045e+15
# (pid=19603) basinhopping step 21: f -1.89951e+15 trial_f 3.43416e+08 accepted 0  lowest_f -1.89951e+15
# (pid=19428) basinhopping step 44: f -2.7297e+15 trial_f 5.74961e+13 accepted 0  lowest_f -2.7297e+15
# (pid=19428) basinhopping step 45: f -2.7297e+15 trial_f 1.70911e+12 accepted 0  lowest_f -2.7297e+15
# (pid=19724) basinhopping step 8: f 5.85709e+11 trial_f 7.04133e+13 accepted 0  lowest_f 5.85709e+11
# (pid=19724) basinhopping step 9: f -3.27896e+15 trial_f -3.27896e+15 accepted 1  lowest_f -3.27896e+15
# (pid=19724) found new global minimum on step 9 with function value -3.27896e+15
# (pid=19603) basinhopping step 22: f -1.89951e+15 trial_f 5.86697e+14 accepted 0  lowest_f -1.89951e+15
# (pid=19724) basinhopping step 10: f -3.27896e+15 trial_f 1.30602e+16 accepted 0  lowest_f -3.27896e+15
# (pid=19465) basinhopping step 45: f -1.05045e+15 trial_f 6.69207e+10 accepted 0  lowest_f -1.05045e+15
# (pid=19465) basinhopping step 46: f -1.05045e+15 trial_f 1.40703e+15 accepted 0  lowest_f -1.05045e+15
# (pid=19637) basinhopping step 23: f -6.88715e+13 trial_f 2.01387e+11 accepted 0  lowest_f -6.88715e+13
# (pid=19724) basinhopping step 11: f -3.27896e+15 trial_f 7.02631e+14 accepted 0  lowest_f -3.27896e+15
# (pid=19465) basinhopping step 47: f -1.05045e+15 trial_f 6.25683e+10 accepted 0  lowest_f -1.05045e+15
# (pid=19603) basinhopping step 23: f -1.89951e+15 trial_f 1.50521e+14 accepted 0  lowest_f -1.89951e+15
# (pid=19637) warning: basinhopping: local minimization failure
# (pid=19637) basinhopping step 24: f -6.88715e+13 trial_f -9.30039e+08 accepted 0  lowest_f -6.88715e+13
# (pid=19465) basinhopping step 48: f -1.05045e+15 trial_f 1.51339e+13 accepted 0  lowest_f -1.05045e+15
# (pid=19428) warning: basinhopping: local minimization failure
# (pid=19428) basinhopping step 46: f -2.7297e+15 trial_f -7.75481e+13 accepted 0  lowest_f -2.7297e+15
# (pid=19724) basinhopping step 12: f -3.27896e+15 trial_f 1.07065e+14 accepted 0  lowest_f -3.27896e+15
# (pid=19465) basinhopping step 49: f -1.05045e+15 trial_f 2.55611e+14 accepted 0  lowest_f -1.05045e+15
# (pid=19465) adaptive stepsize: acceptance rate 0.040000 target 0.500000 new stepsize 0.45 old stepsize 0.5
# (pid=19637) basinhopping step 25: f -6.88715e+13 trial_f 2.01344e+11 accepted 0  lowest_f -6.88715e+13
# (pid=19637) warning: basinhopping: local minimization failure
# (pid=19637) basinhopping step 26: f -6.88715e+13 trial_f 2.92407e+09 accepted 0  lowest_f -6.88715e+13
# (pid=19428) warning: basinhopping: local minimization failure
# (pid=19428) basinhopping step 47: f -2.7297e+15 trial_f 1.7192e+12 accepted 0  lowest_f -2.7297e+15
# (pid=19428) basinhopping step 48: f -2.7297e+15 trial_f 5.80815e+13 accepted 0  lowest_f -2.7297e+15
# (pid=19428) basinhopping step 49: f -2.7297e+15 trial_f 3.18971e+15 accepted 0  lowest_f -2.7297e+15
# (pid=19428) adaptive stepsize: acceptance rate 0.160000 target 0.500000 new stepsize 0.45 old stepsize 0.5
# (pid=19428) basinhopping step 50: f -2.7297e+15 trial_f 3.18969e+15 accepted 0  lowest_f -2.7297e+15
# 2020-09-28 13:57:26,659	WARNING worker.py:1090 -- WARNING: 10 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-09-28 13:57:27,217	WARNING worker.py:1090 -- Failed to unpickle the remote function '__main__.opt' with function ID 4e26af89b060b367c16ee58c13a41794ab777a2a. Traceback:
# Traceback (most recent call last):
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/function_manager.py", line 177, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/cloudpickle/cloudpickle.py", line 1136, in subimport
#     __import__(name)
# ModuleNotFoundError: No module named 'LearnerICRayNoLoadBH'
#
# 2020-09-28 13:57:27,218	WARNING worker.py:1090 -- Failed to unpickle actor class 'Learner' for actor ID fbd96f920100. Traceback:
# Traceback (most recent call last):
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/function_manager.py", line 494, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/cloudpickle/cloudpickle.py", line 1136, in subimport
#     __import__(name)
# ModuleNotFoundError: No module named 'sigmoidOnly'
# (pid=19787) 2020-09-28 13:57:27,216	ERROR function_manager.py:496 -- Failed to load actor class Learner.
# (pid=19787) Traceback (most recent call last):
# (pid=19787)   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/function_manager.py", line 494, in _load_actor_class_from_gcs
# (pid=19787)     actor_class = pickle.loads(pickled_class)
# (pid=19787)   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/cloudpickle/cloudpickle.py", line 1136, in subimport
# (pid=19787)     __import__(name)
# (pid=19787) ModuleNotFoundError: No module named 'sigmoidOnly'
# ---------------------------------------------------------------------------
# RayTaskError(RuntimeError)                Traceback (most recent call last)
# <ipython-input-11-65179efefafc> in <module>
# ----> 1 optimal=ray.get(optimal)
#
# ~/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/worker.py in get(object_ids, timeout)
#    1513                     worker.core_worker.dump_object_store_memory_usage()
#    1514                 if isinstance(value, RayTaskError):
# -> 1515                     raise value.as_instanceof_cause()
#    1516                 else:
#    1517                     raise value
#
# RayTaskError(RuntimeError): ray::__main__.opt() (pid=18534, ip=192.168.0.104)
#   File "python/ray/_raylet.pyx", line 463, in ray._raylet.execute_task
#   File "<ipython-input-8-130f350c2250>", line 10, in opt
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/yabox/algorithms/de.py", line 170, in geniterator
#     it = self.iterator()
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/yabox/algorithms/de.py", line 167, in iterator
#     return iter(DEIterator(self))
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/yabox/algorithms/de.py", line 9, in __init__
#     self.fitness = de.evaluate(self.population)
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/yabox/algorithms/de.py", line 161, in evaluate
#     return self.evaluate_denormalized(PD)
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/yabox/algorithms/de.py", line 164, in evaluate_denormalized
#     return [self.fobj(ind) for ind in PD]
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/yabox/algorithms/de.py", line 164, in <listcomp>
#     return [self.fobj(ind) for ind in PD]
#   File "<ipython-input-7-338aec0b06d9>", line 20, in fobjective
# ray.exceptions.RayTaskError(RuntimeError): ray::TemporaryActor.train() (pid=19787, ip=192.168.0.104)
#   File "python/ray/_raylet.pyx", line 424, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 459, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 462, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 463, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 417, in ray._raylet.execute_task.function_executor
# RuntimeError: The actor with name Learner failed to be imported, and so cannot execute this method.

# %%
for i in range(0,len(countries)):    

    country=countries[i]
    query = dfparam.query('country == "{}"'.format(country)).reset_index()
    parameters = np.array(query.iloc[:, 2:])[0]
    startdate,predict_range,s0,e0,a0,i0,r0,d0,startNCases,wcases,wrec = parameters
    Date = datetime.strptime(startdate, "%m/%d/%y")
    end_date = Date + timedelta(days=+int(optimal[i][1]))
    dateStr=end_date.strftime("%m/%d/%y")

    j = query['index'].values[0]
    dfparam.at[j, "s0"] = optimal[i][0]
    dfparam.at[j, "start-date"] = dateStr
    dfparam.at[j, "i0"] = optimal[i][2]
    dfparam.at[j, "WCASES"] = optimal[i][3]
    dfparam.at[j, "WREC"] = optimal[i][4]

    dfparam.to_csv("data/param_optimized_Yabox.csv", sep=",", index=False)
    dfparam
# Out:
# (pid=19637) basinhopping step 27: f -6.88715e+13 trial_f 6.96953e+11 accepted 0  lowest_f -6.88715e+13
# (pid=19465) basinhopping step 50: f -1.05045e+15 trial_f 2.29439e+12 accepted 0  lowest_f -1.05045e+15
# 2020-09-28 13:57:30,572	WARNING worker.py:1090 -- WARNING: 8 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-09-28 13:57:31,140	WARNING worker.py:1090 -- Failed to unpickle the remote function '__main__.opt' with function ID 4e26af89b060b367c16ee58c13a41794ab777a2a. Traceback:
# Traceback (most recent call last):
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/function_manager.py", line 177, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/cloudpickle/cloudpickle.py", line 1136, in subimport
#     __import__(name)
# ModuleNotFoundError: No module named 'LearnerICRayNoLoadBH'
#
# 2020-09-28 13:57:31,231	WARNING worker.py:1090 -- Failed to unpickle actor class 'Learner' for actor ID 873e0fd10100. Traceback:
# Traceback (most recent call last):
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/function_manager.py", line 494, in _load_actor_class_from_gcs
#     actor_class = pickle.loads(pickled_class)
#   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/cloudpickle/cloudpickle.py", line 1136, in subimport
#     __import__(name)
# ModuleNotFoundError: No module named 'sigmoidOnly'
# (pid=19799) 2020-09-28 13:57:31,230	ERROR function_manager.py:496 -- Failed to load actor class Learner.
# (pid=19799) Traceback (most recent call last):
# (pid=19799)   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/function_manager.py", line 494, in _load_actor_class_from_gcs
# (pid=19799)     actor_class = pickle.loads(pickled_class)
# (pid=19799)   File "/home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/ray/cloudpickle/cloudpickle.py", line 1136, in subimport
# (pid=19799)     __import__(name)
# (pid=19799) ModuleNotFoundError: No module named 'sigmoidOnly'
# (pid=19724) warning: basinhopping: local minimization failure
# (pid=19724) basinhopping step 13: f -3.27896e+15 trial_f 8.06132e+11 accepted 0  lowest_f -3.27896e+15
# (pid=19724) basinhopping step 14: f -3.27896e+15 trial_f 5.93673e+11 accepted 0  lowest_f -3.27896e+15
# (pid=19603) warning: basinhopping: local minimization failure
# (pid=19603) basinhopping step 24: f -1.89951e+15 trial_f -3.06601e+14 accepted 0  lowest_f -1.89951e+15
# (pid=19603) warning: basinhopping: local minimization failure
# (pid=19603) basinhopping step 25: f -1.89951e+15 trial_f -1.8774e+10 accepted 0  lowest_f -1.89951e+15
# (pid=19637) basinhopping step 28: f -6.88715e+13 trial_f -1.91351e+13 accepted 0  lowest_f -6.88715e+13
# (pid=19724) basinhopping step 15: f -3.27896e+15 trial_f 7.00825e+14 accepted 0  lowest_f -3.27896e+15
# (pid=19724) warning: basinhopping: local minimization failure
# (pid=19724) basinhopping step 16: f -3.27896e+15 trial_f 5.94293e+11 accepted 0  lowest_f -3.27896e+15
# (pid=19603) basinhopping step 26: f -1.89951e+15 trial_f 3.45593e+08 accepted 0  lowest_f -1.89951e+15
# (pid=19637) basinhopping step 29: f -6.88715e+13 trial_f 1.29596e+11 accepted 0  lowest_f -6.88715e+13
# (pid=19724) basinhopping step 17: f -3.43138e+15 trial_f -3.43138e+15 accepted 1  lowest_f -3.43138e+15
# (pid=19724) found new global minimum on step 17 with function value -3.43138e+15
# (pid=19603) basinhopping step 27: f -1.89951e+15 trial_f 5.83012e+14 accepted 0  lowest_f -1.89951e+15
# (pid=19603) basinhopping step 28: f -1.89951e+15 trial_f 3.09477e+16 accepted 0  lowest_f -1.89951e+15
# (pid=19603) basinhopping step 29: f -1.89951e+15 trial_f 3.09438e+16 accepted 0  lowest_f -1.89951e+15
# (pid=19724) basinhopping step 18: f -3.43138e+15 trial_f -1.01688e+15 accepted 0  lowest_f -3.43138e+15
# (pid=19603) basinhopping step 30: f -1.89951e+15 trial_f 9.59521e+13 accepted 0  lowest_f -1.89951e+15
# (pid=19724) warning: basinhopping: local minimization failure
# (pid=19724) basinhopping step 19: f -3.43138e+15 trial_f 5.93463e+11 accepted 0  lowest_f -3.43138e+15
# (pid=19637) basinhopping step 30: f -6.88715e+13 trial_f 1.9726e+11 accepted 0  lowest_f -6.88715e+13
# (pid=19603) basinhopping step 31: f -1.89951e+15 trial_f 3.44385e+08 accepted 0  lowest_f -1.89951e+15
# (pid=19724) warning: basinhopping: local minimization failure
# (pid=19724) basinhopping step 20: f -3.43138e+15 trial_f 5.94258e+11 accepted 0  lowest_f -3.43138e+15
# (pid=19724) basinhopping step 21: f -3.43138e+15 trial_f 6.89982e+14 accepted 0  lowest_f -3.43138e+15
# (pid=19724) basinhopping step 22: f -3.43138e+15 trial_f 1.30601e+16 accepted 0  lowest_f -3.43138e+15
# (pid=19724) basinhopping step 23: f -3.43138e+15 trial_f 1.30602e+16 accepted 0  lowest_f -3.43138e+15
# (pid=19603) basinhopping step 32: f -1.89951e+15 trial_f 2.10611e+08 accepted 0  lowest_f -1.89951e+15
# (pid=19603) basinhopping step 33: f -1.89951e+15 trial_f 2.07034e+15 accepted 0  lowest_f -1.89951e+15
# (pid=19724) basinhopping step 24: f -3.43138e+15 trial_f 7.03969e+14 accepted 0  lowest_f -3.43138e+15
# (pid=19637) basinhopping step 31: f -6.88715e+13 trial_f -2.67723e+13 accepted 0  lowest_f -6.88715e+13
# (pid=19637) basinhopping step 32: f -6.88715e+13 trial_f 1.39072e+12 accepted 0  lowest_f -6.88715e+13
# (pid=19724) basinhopping step 25: f -3.43138e+15 trial_f 7.04559e+13 accepted 0  lowest_f -3.43138e+15
