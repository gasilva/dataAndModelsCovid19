# %% [markdown]
# # COVID19 - District Region

# %% [markdown]
# Install necessary packages for parallel computation:
#
# ```
# pip install ipyparallel
# ipcluster nbextension enable
# pip install parallel-execute
# ```
#
# To install for all users on JupyterHub, as root:
# ```
# jupyter nbextension install --sys-prefix --py ipyparallel
# jupyter nbextension enable --sys-prefix --py ipyparallel
# jupyter serverextension enable --sys-prefix --py ipyparallel
# ```
#
# start cluster at jupyter notebook interface

# %%
import urllib.request
import pandas as pd
import numpy as np

# %%
# Download data
import get_data
LoadData=False

if LoadData:
    get_data.get_data()

# %%
dfSP = pd.read_csv("data/dados_municipios_SP.csv")
dfSP
# Out:
#             date state                city place_type  confirmed  deaths  \
# 0     2020-04-19    SP               TOTAL      state      14267    1015
# 1     2020-04-18    SP               TOTAL      state      13894     991
# 2     2020-04-17    SP               TOTAL      state      12841     928
# 3     2020-04-16    SP               TOTAL      state      11568     853
# 4     2020-04-15    SP               TOTAL      state      11043     778
# ...          ...   ...                 ...        ...        ...     ...
# 3263  2020-04-14    SP  Águas de São Pedro       city          1       0
# 3264  2020-04-13    SP  Águas de São Pedro       city          1       0
# 3265  2020-04-12    SP  Águas de São Pedro       city          1       0
# 3266  2020-04-11    SP  Águas de São Pedro       city          1       0
# 3267  2020-04-10    SP  Águas de São Pedro       city          1       0
#
#       order_for_place  is_last      popEst  city_ibge_code  \
# 0                  53     True  45919049.0            35.0
# 1                  52    False  45919049.0            35.0
# 2                  51    False  45919049.0            35.0
# 3                  50    False  45919049.0            35.0
# 4                  49    False  45919049.0            35.0
# ...               ...      ...         ...             ...
# 3263                5    False      3451.0       3500600.0
# 3264                4    False      3451.0       3500600.0
# 3265                3    False      3451.0       3500600.0
# 3266                2    False      3451.0       3500600.0
# 3267                1    False      3451.0       3500600.0
#
#       confirmed_per_100k_inhabitants  death_rate                  DRS
# 0                           31.06989      0.0711           Indefinido
# 1                           30.25760      0.0713           Indefinido
# 2                           27.96443      0.0723           Indefinido
# 3                           25.19216      0.0737           Indefinido
# 4                           24.04884      0.0705           Indefinido
# ...                              ...         ...                  ...
# 3263                        28.97711         NaN  DRS 10 - Piracicaba
# 3264                        28.97711         NaN  DRS 10 - Piracicaba
# 3265                        28.97711         NaN  DRS 10 - Piracicaba
# 3266                        28.97711         NaN  DRS 10 - Piracicaba
# 3267                        28.97711         NaN  DRS 10 - Piracicaba
#
# [3268 rows x 13 columns]

# %%
# Model

# %%
# lista DRSs
DRS = list(dfSP["DRS"].unique())
DRS.remove("Indefinido")
DRS
# Out:
# ['DRS 09 - Marília',
#  'DRS 06 - Bauru',
#  'DRS 16 - Sorocaba',
#  'DRS 07 - Campinas',
#  'DRS 03 - Araraquara',
#  'DRS 02 - Araçatuba',
#  'DRS 17 - Taubaté',
#  'DRS 10 - Piracicaba',
#  'DRS 01 - Grande São Paulo',
#  'DRS 15 - São José do Rio Preto',
#  'DRS 12 - Registro',
#  'DRS 05 - Barretos',
#  'DRS 13 - Ribeirão Preto',
#  'DRS 11 - Presidente Prudente',
#  'DRS 04 - Baixada Santista',
#  'DRS 14 - São João da Boa Vista',
#  'DRS 08 - Franca']

# %% [markdown]
# # SEAIR-D Model Equations
#
# $$\begin{array}{l}\frac{d s}{d t}=-[\beta i(t) + \beta_2 a(t)-\mu] \cdot s(t)\\
# \frac{d e}{d t}=[\beta i(t) + \beta_2 a(t)] \cdot s(t) -(\sigma+\mu) \cdot e(t)\\
# \frac{d a}{d t}=\sigma e(t) \cdot (1-p)-(\gamma+\mu) \cdot a(t) \\
# \frac{d i}{d t}=\sigma e(t) \cdot p - (\gamma + \sigma_2 + \sigma_3 + \mu) \cdot i(t)\\
# \frac{d r}{d t}=(b + \sigma_2) \cdot i(t) + \gamma \cdot a(t) - \mu \cdot r(t)\\
# \frac{d k}{d t}=(a + \sigma_3 - \mu) \cdot d(t)
# \end{array}$$
#
# The last equation does not need to be solve because:
#
# $$\frac{d k}{d t}=-(\frac{d e}{d t}+\frac{d a}{d t}+\frac{d i}{d t}+\frac{d r}{d t})$$
#
# The sum of all rates are equal to zero! The importance of this equation is that it conservates the rates.

# %% [markdown]
# ## Parameters

# %% [markdown]
# $\beta$: Effective contact rate [1/min]
#
# $\gamma$: Recovery(+Mortality) rate $\gamma=(a+b)$ [1/min]
#
# $a$: mortality of healed  [1/min]
#
# $b$: recovery rate  [1/min]
#
# $\sigma$: is the rate at which individuals move from the exposed to the infectious classes. Its reciprocal ($1/\sigma$) is the average latent (exposed) period.
#
# $\sigma_2$: is the rate at which individuals move from the infectious to the healed classes. Its reciprocal ($1/\sigma_2$) is the average latent (exposed) period
#
# $\sigma_3$: is the rate at which individuals move from the infectious to the dead classes. Its reciprocal ($1/\sigma_3$) is the average latent (exposed) period
#
# $p$: is the fraction of the exposed which become symptomatic infectious sub-population.
#
# $(1-p)$: is the fraction of the exposed which becomes asymptomatic infectious sub-population.

# %%
#objective function Odeint solver
from scipy.integrate import odeint

#objective function Odeint solver
def lossOdeint(point, data, death, s_0, e_0, a_0, i_0, r_0, d_0, startNCases, ratioRecovered, weigthCases, weigthRecov):
    size = len(data)
    beta, beta2, sigma, sigma2, sigma3, gamma, b, mu = point
    def SEAIRD(y,t):
        S = y[0]
        E = y[1]
        A = y[2]
        I = y[3]
        R = y[4]
        D = y[5]
        p=0.2
        # beta2=beta
        y0=-(beta2*A+beta*I)*S+mu*S #S
        y1=(beta2*A+beta*I)*S-sigma*E-mu*E #E
        y2=sigma*E*(1-p)-gamma*A-mu*A #A
        y3=sigma*E*p-gamma*I-sigma2*I-sigma3*I-mu*I#I
        y4=b*I+gamma*A+sigma2*I-mu*R #R
        y5=(-(y0+y1+y2+y3+y4)) #D
        return [y0,y1,y2,y3,y4,y5]

    y0=[s_0,e_0,a_0,i_0,r_0,d_0]
    tspan=np.arange(0, size, 1)
    res=odeint(SEAIRD,y0,tspan,hmax=0.01)

    l1=0
    l2=0
    l3=0
    tot=0

    for i in range(0,len(data.values)):
        if data.values[i]>startNCases:
            l1 = l1+(res[i,3] - data.values[i])**2
            l2 = l2+(res[i,5] - death.values[i])**2
            newRecovered=min(1e6,data.values[i]*ratioRecovered)
            l3 = l3+(res[i,4] - newRecovered)**2
            tot+=1
    l1=np.sqrt(l1/max(1,tot))
    l2=np.sqrt(l2/max(1,tot))
    l3=np.sqrt(l3/max(1,tot))
    
    #weight for cases
    u = weigthCases  #Brazil US 0.1
    w = weigthRecov
    #weight for deaths
    v = max(0,1. - u - w)
    
    return u*l1 + v*l2 + w*l3

# %%
# Initial parameters
dfparam = pd.read_csv("data/param.csv")
dfparam
# Out:
#                                DRS  start-date  prediction-range        s0  \
# 0        DRS 01 - Grande São Paulo  2020-03-15                60  280000.0
# 1               DRS 02 - Araçatuba  2020-04-01                60     500.0
# 2              DRS 03 - Araraquara  2020-04-01                60    2000.0
# 3        DRS 04 - Baixada Santista  2020-04-01                60    8000.0
# 4                DRS 05 - Barretos  2020-04-01                60    1000.0
# 5                   DRS 06 - Bauru  2020-04-01                60   10000.0
# 6                DRS 07 - Campinas  2020-04-01                60   20000.0
# 7                  DRS 08 - Franca  2020-04-01                60    1000.0
# 8                 DRS 09 - Marília  2020-04-01                60    5000.0
# 9              DRS 10 - Piracicaba  2020-04-01                60   10000.0
# 10    DRS 11 - Presidente Prudente  2020-04-01                60    5000.0
# 11               DRS 12 - Registro  2020-04-01                60    1000.0
# 12         DRS 13 - Ribeirão Preto  2020-04-01                60    5000.0
# 13  DRS 14 - São João da Boa Vista  2020-04-01                60    5000.0
# 14  DRS 15 - São José do Rio Preto  2020-04-01                60   10000.0
# 15               DRS 16 - Sorocaba  2020-04-01                60    1000.0
# 16                DRS 17 - Taubaté  2020-04-01                60   10000.0
#
#         e0      a0       i0      r0       d0  START  RATIO  WCASES  WREC
# 0   0.0001  0.0001   0.0001  0.0001  80.0000   1500    0.1     0.6   0.1
# 1   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 2   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 3   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 4   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 5   0.0001  0.0001   4.0000  0.0001   0.0001      0    0.1     0.4   0.1
# 6   0.0001  0.0001  40.0000  0.0001   0.0001      0    0.1     0.4   0.1
# 7   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 8   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 9   0.0001  0.0001   0.0001  0.0001   1.0000      0    0.1     0.4   0.1
# 10  0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 11  0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 12  0.0001  0.0001   0.0001  0.0001   0.0001      5    0.1     0.4   0.1
# 13  0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 14  0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 15  0.0001  0.0001   2.0000  0.0001   0.0001      0    0.1     0.4   0.1
# 16  0.0001  0.0001  17.0000  0.0001   2.0000      0    0.1     0.4   0.1

# %%
# Initial parameter optimization

# %%
# Load solver
GlobalOptimization=True
import ray

if GlobalOptimization:
    import LearnerGlobalOpt as Learner  # basinhopping global optimization (several times minimize)
else:
    import Learner #minimize

# %%
allDistricts=True

results=[]
if allDistricts:
    for districtRegion in DRS:
        query = dfparam.query('DRS == "{}"'.format(districtRegion)).reset_index()
        parameters = np.array(query.iloc[:, 2:])[0]
        learner = Learner.Learner.remote(districtRegion, lossOdeint, *parameters)
        #learner.train()
        #add function evaluation to the queue
        results.append(learner.train.remote())
else:
    districtRegion="DRS 01 - Grande São Paulo"
    query = dfparam.query('DRS == "{}"'.format(districtRegion)).reset_index()
    parameters = np.array(query.iloc[:, 2:])[0]
    learner = Learner.Learner(districtRegion, lossOdeint, *parameters)
    # learner.train()
    # add function evaluation to the queue
    results.append(learner.train.remote())

# #execute all the queue with max_runner_cap at a time    
results = ray.get(results)
# Out:
# (pid=3798) rodando DRS 16 - Sorocaba
# (pid=3792) rodando DRS 06 - Bauru
# (pid=3807) rodando DRS 09 - Marília
# (pid=4875) rodando DRS 03 - Araraquara
# (pid=4877) rodando DRS 02 - Araçatuba
# (pid=4876) rodando DRS 07 - Campinas
# (pid=4885) rodando DRS 17 - Taubaté
# (pid=4880) rodando DRS 10 - Piracicaba
# (pid=4882) rodando DRS 15 - São José do Rio Preto
# (pid=4888) rodando DRS 01 - Grande São Paulo
# (pid=4881) rodando DRS 12 - Registro
# (pid=4883) rodando DRS 05 - Barretos
# (pid=4884) rodando DRS 14 - São João da Boa Vista
# (pid=4886) rodando DRS 13 - Ribeirão Preto
# (pid=4887) rodando DRS 04 - Baixada Santista
# (pid=4890) rodando DRS 11 - Presidente Prudente
# (pid=4892) rodando DRS 08 - Franca
# (pid=4883) basinhopping step 0: f 4.49001
# (pid=4877) basinhopping step 0: f 4.0353
# (pid=4875) basinhopping step 0: f 3.08224
# (pid=3798) basinhopping step 0: f 4.37707
# (pid=4886) basinhopping step 0: f 6.44474
# (pid=4881) basinhopping step 0: f 1.56437
# (pid=4885) basinhopping step 0: f 5.49798
# (pid=4887) basinhopping step 0: f 18.9005
# (pid=3792) basinhopping step 0: f 4.89315
# (pid=4884) basinhopping step 0: f 1.5624
# (pid=4881) basinhopping step 1: f 1.56437 trial_f 6.03569 accepted 0  lowest_f 1.56437
# (pid=4886) basinhopping step 1: f 6.44474 trial_f 27.7002 accepted 0  lowest_f 6.44474
# (pid=4888) basinhopping step 0: f 347.457
# (pid=4882) basinhopping step 0: f 2.75891
# (pid=4876) basinhopping step 0: f 11.0947
# (pid=4883) basinhopping step 1: f 4.49008 trial_f 4.49008 accepted 1  lowest_f 4.49001
# (pid=4882) basinhopping step 1: f 2.75891 trial_f 30.2479 accepted 0  lowest_f 2.75891
# (pid=4890) basinhopping step 0: f 1.98275
# (pid=4892) basinhopping step 0: f 1.17754
# (pid=4887) basinhopping step 1: f 18.9005 trial_f 91.0216 accepted 0  lowest_f 18.9005
# (pid=4883) basinhopping step 2: f 4.49009 trial_f 4.49009 accepted 1  lowest_f 4.49001
# (pid=4883)
# (pid=4883)                          fun: array([4.4900067])
# (pid=4883)  lowest_optimization_result:       fun: array([4.4900067])
# (pid=4883)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4883)       jac: array([-3.61035646e-03, -5.50919310e-03, -3.33497674e-02,  6.59472477e-04,
# (pid=4883)         1.53734803e-03,  1.36735068e-03, -8.77786732e-04,  2.51078472e+01])
# (pid=4883)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4883)      nfev: 189
# (pid=4883)       nit: 3
# (pid=4883)    status: 0
# (pid=4883)   success: True
# (pid=4883)         x: array([1.00017930e-02, 1.03210017e-02, 2.77705298e-03, 6.19152180e-04,
# (pid=4883)        1.08473153e-03, 1.16022609e-03, 5.33887742e-04, 3.16138009e-09])
# (pid=4883)                     message: ['success condition satisfied']
# (pid=4883)       minimization_failures: 0
# (pid=4883)                        nfev: 1485
# (pid=4883)                         nit: 2
# (pid=4883)                           x: array([1.00017930e-02, 1.03210017e-02, 2.77705298e-03, 6.19152180e-04,
# (pid=4883)        1.08473153e-03, 1.16022609e-03, 5.33887742e-04, 3.16138009e-09])
# (pid=3798) basinhopping step 1: f 4.03596 trial_f 4.03596 accepted 1  lowest_f 4.03596
# (pid=3798) found new global minimum on step 1 with function value 4.03596
# (pid=4877) basinhopping step 1: f 3.07156 trial_f 3.07156 accepted 1  lowest_f 3.07156
# (pid=4877) found new global minimum on step 1 with function value 3.07156
# (pid=4880) basinhopping step 0: f 3.03218
# (pid=4890) basinhopping step 1: f 1.98275 trial_f 6.57394 accepted 0  lowest_f 1.98275
# (pid=3792) basinhopping step 1: f 4.89315 trial_f 5.7458 accepted 0  lowest_f 4.89315
# (pid=3807) basinhopping step 0: f 1.32674
# (pid=4875) basinhopping step 1: f 3.07139 trial_f 3.07139 accepted 1  lowest_f 3.07139
# (pid=4875) found new global minimum on step 1 with function value 3.07139
# (pid=4882) basinhopping step 2: f 2.75891 trial_f 2.75891 accepted 1  lowest_f 2.75891
# (pid=4882)
# (pid=4882)                          fun: array([2.75890749])
# (pid=4882)  lowest_optimization_result:       fun: array([2.75890749])
# (pid=4882)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4882)       jac: array([-5.07673459e-01, -1.53182671e+00, -2.38166455e+00,  3.32943895e-02,
# (pid=4882)         4.76243045e-02,  5.81304788e+01, -1.28506983e-02,  1.18463424e+01])
# (pid=4882)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4882)      nfev: 837
# (pid=4882)       nit: 72
# (pid=4882)    status: 0
# (pid=4882)   success: True
# (pid=4882)         x: array([4.00000000e-01, 4.00000000e-01, 4.81362053e-03, 9.99999996e-13,
# (pid=4882)        2.28279818e-02, 1.00000000e-12, 1.62261294e-02, 1.24205283e-05])
# (pid=4882)                     message: ['success condition satisfied']
# (pid=4882)       minimization_failures: 0
# (pid=4882)                        nfev: 1701
# (pid=4882)                         nit: 2
# (pid=4882)                           x: array([4.00000000e-01, 4.00000000e-01, 4.81362053e-03, 9.99999996e-13,
# (pid=4882)        2.28279818e-02, 1.00000000e-12, 1.62261294e-02, 1.24205283e-05])
# (pid=4892) basinhopping step 1: f 1.17754 trial_f 1.17754 accepted 1  lowest_f 1.17754
# (pid=4886) basinhopping step 2: f 6.44474 trial_f 6.44474 accepted 1  lowest_f 6.44474
# (pid=4886)
# (pid=4886)                          fun: array([6.44474437])
# (pid=4886)  lowest_optimization_result:       fun: array([6.44474437])
# (pid=4886)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4886)       jac: array([-8.07669220e-01, -2.42891049e+00,  2.26485497e-05, -3.30313554e-04,
# (pid=4886)         1.19015908e-05,  1.22213351e-04,  1.49213975e-05,  7.09832193e-04])
# (pid=4886)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4886)      nfev: 711
# (pid=4886)       nit: 73
# (pid=4886)    status: 0
# (pid=4886)   success: True
# (pid=4886)         x: array([4.00000000e-01, 4.00000000e-01, 9.38382499e-03, 4.84809729e-11,
# (pid=4886)        7.02813035e-03, 2.88477796e-03, 3.29954190e-03, 1.08604116e-04])
# (pid=4886)                     message: ['success condition satisfied']
# (pid=4886)       minimization_failures: 0
# (pid=4886)                        nfev: 1656
# (pid=4886)                         nit: 2
# (pid=4886)                           x: array([4.00000000e-01, 4.00000000e-01, 9.38382499e-03, 4.84809729e-11,
# (pid=4886)        7.02813035e-03, 2.88477796e-03, 3.29954190e-03, 1.08604116e-04])
# (pid=3807) basinhopping step 1: f 1.32674 trial_f 296.244 accepted 0  lowest_f 1.32674
# (pid=4885) basinhopping step 1: f 5.53839 trial_f 5.53839 accepted 1  lowest_f 5.49798
# (pid=4890) basinhopping step 2: f 1.98275 trial_f 4.21892 accepted 0  lowest_f 1.98275
# (pid=4890)
# (pid=4890)                          fun: array([1.9827475])
# (pid=4890)  lowest_optimization_result:       fun: array([1.9827475])
# (pid=4890)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4890)       jac: array([-1.57226543e-01, -4.71393991e-01, -5.09812215e+01,  5.12716025e-01,
# (pid=4890)        -3.39937500e-01, -1.82002127e+00,  8.52660431e-01,  3.21392035e+03])
# (pid=4890)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4890)      nfev: 1170
# (pid=4890)       nit: 77
# (pid=4890)    status: 0
# (pid=4890)   success: True
# (pid=4890)         x: array([4.00000000e-01, 4.00000000e-01, 2.29157293e-03, 1.07533769e-03,
# (pid=4890)        7.11031092e-02, 3.02184294e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4890)                     message: ['success condition satisfied']
# (pid=4890)       minimization_failures: 0
# (pid=4890)                        nfev: 2214
# (pid=4890)                         nit: 2
# (pid=4890)                           x: array([4.00000000e-01, 4.00000000e-01, 2.29157293e-03, 1.07533769e-03,
# (pid=4890)        7.11031092e-02, 3.02184294e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4877) basinhopping step 2: f 3.11097 trial_f 3.11097 accepted 1  lowest_f 3.07156
# (pid=4881) basinhopping step 2: f 1.56597 trial_f 1.56597 accepted 1  lowest_f 1.56437
# (pid=4881)
# (pid=4881)                          fun: array([1.56437384])
# (pid=4881)  lowest_optimization_result:       fun: array([1.56437384])
# (pid=4881)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4881)       jac: array([-2.08756656e-01, -6.26053343e-01,  1.36246570e-04, -1.12621024e-04,
# (pid=4881)         3.34177130e-05,  7.00229381e+00, -1.56763491e-05,  8.17013124e-04])
# (pid=4881)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4881)      nfev: 603
# (pid=4881)       nit: 37
# (pid=4881)    status: 0
# (pid=4881)   success: True
# (pid=4881)         x: array([4.00000000e-01, 4.00000000e-01, 1.20313930e-02, 5.07815786e-03,
# (pid=4881)        2.53909125e-02, 1.00000000e-12, 1.30859500e-02, 8.15843357e-06])
# (pid=4881)                     message: ['success condition satisfied']
# (pid=4881)       minimization_failures: 0
# (pid=4881)                        nfev: 2043
# (pid=4881)                         nit: 2
# (pid=4881)                           x: array([4.00000000e-01, 4.00000000e-01, 1.20313930e-02, 5.07815786e-03,
# (pid=4881)        2.53909125e-02, 1.00000000e-12, 1.30859500e-02, 8.15843357e-06])
# (pid=4885) basinhopping step 2: f 5.53839 trial_f 6.75156 accepted 0  lowest_f 5.49798
# (pid=4885)
# (pid=4885)                          fun: array([5.49798016])
# (pid=4885)  lowest_optimization_result:       fun: array([5.49798016])
# (pid=4885)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4885)       jac: array([ 0.06963727, -0.05997762,  0.22675541,  6.98487677,  7.02886478,
# (pid=4885)         0.05668834, -0.04067324,  4.35347864])
# (pid=4885)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4885)      nfev: 774
# (pid=4885)       nit: 62
# (pid=4885)    status: 0
# (pid=4885)   success: True
# (pid=4885)         x: array([1.39534280e-02, 1.32952833e-02, 6.23559068e-03, 1.00000000e-12,
# (pid=4885)        1.00000000e-12, 3.48709342e-03, 1.97265279e-03, 3.82133020e-05])
# (pid=4885)                     message: ['success condition satisfied']
# (pid=4885)       minimization_failures: 0
# (pid=4885)                        nfev: 2538
# (pid=4885)                         nit: 2
# (pid=4885)                           x: array([1.39534280e-02, 1.32952833e-02, 6.23559068e-03, 1.00000000e-12,
# (pid=4885)        1.00000000e-12, 3.48709342e-03, 1.97265279e-03, 3.82133020e-05])
# (pid=3807) basinhopping step 2: f 1.32674 trial_f 7.1819 accepted 0  lowest_f 1.32674
# (pid=3807)
# (pid=3807)                          fun: array([1.32674245])
# (pid=3807)  lowest_optimization_result:       fun: array([1.32674245])
# (pid=3807)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=3807)       jac: array([-2.45072851e-03,  2.00961470e-03, -4.06562783e-02,  2.79588717e+00,
# (pid=3807)        -1.09230403e-03,  1.26434418e-03,  2.79707550e+00,  7.60384487e+02])
# (pid=3807)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=3807)      nfev: 1305
# (pid=3807)       nit: 96
# (pid=3807)    status: 0
# (pid=3807)   success: True
# (pid=3807)         x: array([3.05415038e-01, 3.61610225e-01, 2.67825206e-03, 1.00000000e-12,
# (pid=3807)        7.78458576e-03, 4.43342168e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=3807)                     message: ['success condition satisfied']
# (pid=3807)       minimization_failures: 0
# (pid=3807)                        nfev: 2448
# (pid=3807)                         nit: 2
# (pid=3807)                           x: array([3.05415038e-01, 3.61610225e-01, 2.67825206e-03, 1.00000000e-12,
# (pid=3807)        7.78458576e-03, 4.43342168e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4887) basinhopping step 2: f 18.9004 trial_f 18.9004 accepted 1  lowest_f 18.9004
# (pid=4887) found new global minimum on step 2 with function value 18.9004
# (pid=4880) basinhopping step 1: f 3.03218 trial_f 3.03218 accepted 1  lowest_f 3.03218
# (pid=4884) basinhopping step 1: f 1.563 trial_f 1.563 accepted 1  lowest_f 1.5624
# (pid=3798) basinhopping step 2: f 4.03596 trial_f 23.3795 accepted 0  lowest_f 4.03596
# (pid=3792) basinhopping step 2: f 4.89315 trial_f 26.4034 accepted 0  lowest_f 4.89315
# (pid=3792)
# (pid=3792)                          fun: array([4.89315399])
# (pid=3792)  lowest_optimization_result:       fun: array([4.89315399])
# (pid=3792)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=3792)       jac: array([ 5.41877654e-03,  5.69810270e+02,  2.83186807e-03,  1.48322847e+00,
# (pid=3792)        -1.85629290e-05,  3.20632410e-05,  1.48345283e+00,  1.57206363e+04])
# (pid=3792)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=3792)      nfev: 990
# (pid=3792)       nit: 88
# (pid=3792)    status: 0
# (pid=3792)   success: True
# (pid=3792)         x: array([4.71842448e-03, 1.00000000e-12, 1.08690204e-02, 1.00000000e-12,
# (pid=3792)        1.80702953e-02, 5.32835843e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=3792)                     message: ['success condition satisfied']
# (pid=3792)       minimization_failures: 0
# (pid=3792)                        nfev: 2907
# (pid=3792)                         nit: 2
# (pid=3792)                           x: array([4.71842448e-03, 1.00000000e-12, 1.08690204e-02, 1.00000000e-12,
# (pid=3792)        1.80702953e-02, 5.32835843e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4877) basinhopping step 3: f 3.07156 trial_f 3.07156 accepted 1  lowest_f 3.07156
# (pid=4877)
# (pid=4877)                          fun: array([3.07156075])
# (pid=4877)  lowest_optimization_result:       fun: array([3.07156075])
# (pid=4877)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4877)       jac: array([-2.11043627e-02, -3.83395538e-02,  6.57416344e-03,  1.03105783e+01,
# (pid=4877)         1.03111113e+01, -2.46842546e-03, -2.85060864e-04,  1.73343646e+02])
# (pid=4877)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4877)      nfev: 1044
# (pid=4877)       nit: 72
# (pid=4877)    status: 0
# (pid=4877)   success: True
# (pid=4877)         x: array([4.00000000e-01, 4.00000000e-01, 4.87497128e-02, 1.00000000e-12,
# (pid=4877)        1.00000000e-12, 3.83415520e-03, 1.09671520e-04, 1.00000000e-12])
# (pid=4877)                     message: ['success condition satisfied']
# (pid=4877)       minimization_failures: 0
# (pid=4877)                        nfev: 2916
# (pid=4877)                         nit: 3
# (pid=4877)                           x: array([4.00000000e-01, 4.00000000e-01, 4.87497128e-02, 1.00000000e-12,
# (pid=4877)        1.00000000e-12, 3.83415520e-03, 1.09671520e-04, 1.00000000e-12])
# (pid=4880) basinhopping step 2: f 3.03218 trial_f 3.03218 accepted 1  lowest_f 3.03218
# (pid=4880) found new global minimum on step 2 with function value 3.03218
# (pid=3798) basinhopping step 3: f 4.03596 trial_f 24.1716 accepted 0  lowest_f 4.03596
# (pid=3798)
# (pid=3798)                          fun: array([4.03595734])
# (pid=3798)  lowest_optimization_result:       fun: array([4.03595734])
# (pid=3798)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=3798)       jac: array([ 1.63424829e-05,  3.71734997e+01, -3.93463040e-05,  1.87571735e+01,
# (pid=3798)         4.13002965e-04,  1.03490549e-03,  1.87571914e+01,  5.12908897e+02])
# (pid=3798)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=3798)      nfev: 1089
# (pid=3798)       nit: 76
# (pid=3798)    status: 0
# (pid=3798)   success: True
# (pid=3798)         x: array([2.45196056e-02, 1.00000000e-12, 6.37236805e-02, 1.00000000e-12,
# (pid=3798)        9.12954513e-03, 4.07129246e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=3798)                     message: ['success condition satisfied']
# (pid=3798)       minimization_failures: 0
# (pid=3798)                        nfev: 3537
# (pid=3798)                         nit: 3
# (pid=3798)                           x: array([2.45196056e-02, 1.00000000e-12, 6.37236805e-02, 1.00000000e-12,
# (pid=3798)        9.12954513e-03, 4.07129246e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4880) warning: basinhopping: local minimization failure
# (pid=4880) basinhopping step 3: f 3.03218 trial_f 14.8651 accepted 0  lowest_f 3.03218
# (pid=4892) basinhopping step 2: f 1.17754 trial_f 1.17754 accepted 1  lowest_f 1.17754
# (pid=4892)
# (pid=4892)                          fun: array([1.17753946])
# (pid=4892)  lowest_optimization_result:       fun: array([1.17753946])
# (pid=4892)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4892)       jac: array([-1.25018884e-02, -3.77819331e-02,  4.94166930e-03,  7.64139996e-01,
# (pid=4892)         7.64223174e-01, -8.51119175e-04, -6.43485265e-05,  9.17588659e+01])
# (pid=4892)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4892)      nfev: 1080
# (pid=4892)       nit: 81
# (pid=4892)    status: 0
# (pid=4892)   success: True
# (pid=4892)         x: array([4.00000000e-01, 4.00000000e-01, 6.88554250e-03, 1.00000000e-12,
# (pid=4892)        1.00000000e-12, 4.96840006e-03, 8.06683323e-05, 1.00000000e-12])
# (pid=4892)                     message: ['success condition satisfied']
# (pid=4892)       minimization_failures: 0
# (pid=4892)                        nfev: 3546
# (pid=4892)                         nit: 2
# (pid=4892)                           x: array([4.00000000e-01, 4.00000000e-01, 6.88554250e-03, 1.00000000e-12,
# (pid=4892)        1.00000000e-12, 4.96840006e-03, 8.06683323e-05, 1.00000000e-12])
# (pid=4876) basinhopping step 1: f 11.0947 trial_f 11.0947 accepted 1  lowest_f 11.0947
# (pid=4888) basinhopping step 1: f 347.457 trial_f 934.142 accepted 0  lowest_f 347.457
# (pid=4875) basinhopping step 2: f 3.07041 trial_f 3.07041 accepted 1  lowest_f 3.07041
# (pid=4875) found new global minimum on step 2 with function value 3.07041
# (pid=4888) basinhopping step 2: f 347.457 trial_f 4483.32 accepted 0  lowest_f 347.457
# (pid=4888)
# (pid=4888)                          fun: array([347.45659006])
# (pid=4888)  lowest_optimization_result:       fun: array([347.45659006])
# (pid=4888)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4888)       jac: array([-7.86971725e+01, -4.68967130e+01, -4.11722112e+01,  4.87194715e+03,
# (pid=4888)         1.86770308e+01, -3.28520173e+01,  4.85348683e+03,  2.24001680e+05])
# (pid=4888)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4888)      nfev: 639
# (pid=4888)       nit: 52
# (pid=4888)    status: 0
# (pid=4888)   success: True
# (pid=4888)         x: array([1.23084129e-03, 4.00513702e-04, 1.13024977e-02, 1.00000000e-12,
# (pid=4888)        3.76786946e-03, 2.63236121e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4888)                     message: ['success condition satisfied']
# (pid=4888)       minimization_failures: 0
# (pid=4888)                        nfev: 2097
# (pid=4888)                         nit: 2
# (pid=4888)                           x: array([1.23084129e-03, 4.00513702e-04, 1.13024977e-02, 1.00000000e-12,
# (pid=4888)        3.76786946e-03, 2.63236121e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4887) basinhopping step 3: f 18.9005 trial_f 18.9005 accepted 1  lowest_f 18.9004
# (pid=4884) basinhopping step 2: f 1.56218 trial_f 1.56218 accepted 1  lowest_f 1.56218
# (pid=4884) found new global minimum on step 2 with function value 1.56218
# (pid=4875) basinhopping step 3: f 3.07783 trial_f 3.07783 accepted 1  lowest_f 3.07041
# (pid=4887) basinhopping step 4: f 18.9055 trial_f 18.9055 accepted 1  lowest_f 18.9004
# (pid=4887)
# (pid=4887)                          fun: array([18.90040128])
# (pid=4887)  lowest_optimization_result:       fun: array([18.90040128])
# (pid=4887)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4887)       jac: array([-5.63815661e-04,  4.26325641e-06,  7.69517783e-04,  1.14115922e+02,
# (pid=4887)         1.52263340e+00,  5.74829073e-04,  1.12597148e+02,  5.28324051e-03])
# (pid=4887)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4887)      nfev: 1395
# (pid=4887)       nit: 95
# (pid=4887)    status: 0
# (pid=4887)   success: True
# (pid=4887)         x: array([3.99989943e-01, 3.50966585e-01, 1.87277915e-02, 1.00000000e-12,
# (pid=4887)        1.00000000e-12, 3.66571933e-03, 1.00000000e-12, 1.21616177e-04])
# (pid=4887)                     message: ['success condition satisfied']
# (pid=4887)       minimization_failures: 0
# (pid=4887)                        nfev: 5022
# (pid=4887)                         nit: 4
# (pid=4887)                           x: array([3.99989943e-01, 3.50966585e-01, 1.87277915e-02, 1.00000000e-12,
# (pid=4887)        1.00000000e-12, 3.66571933e-03, 1.00000000e-12, 1.21616177e-04])
# (pid=4880) basinhopping step 4: f 3.03218 trial_f 3.03218 accepted 1  lowest_f 3.03218
# (pid=4880) found new global minimum on step 4 with function value 3.03218
# (pid=4884) basinhopping step 3: f 1.56218 trial_f 5.32601 accepted 0  lowest_f 1.56218
# (pid=4876) basinhopping step 2: f 11.0947 trial_f 11.0947 accepted 1  lowest_f 11.0947
# (pid=4876)
# (pid=4876)                          fun: array([11.09468498])
# (pid=4876)  lowest_optimization_result:       fun: array([11.09468498])
# (pid=4876)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4876)       jac: array([2.24101626e-02, 9.56812960e+02, 9.08091380e-03, 4.07315444e+00,
# (pid=4876)        4.37676562e-03, 2.30908626e-03, 4.07097644e+00, 1.83137249e+04])
# (pid=4876)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4876)      nfev: 828
# (pid=4876)       nit: 73
# (pid=4876)    status: 0
# (pid=4876)   success: True
# (pid=4876)         x: array([2.44448026e-03, 1.00000000e-12, 8.29634774e-03, 1.00000000e-12,
# (pid=4876)        6.50867206e-03, 4.72796247e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4876)                     message: ['success condition satisfied']
# (pid=4876)       minimization_failures: 0
# (pid=4876)                        nfev: 5985
# (pid=4876)                         nit: 2
# (pid=4876)                           x: array([2.44448026e-03, 1.00000000e-12, 8.29634774e-03, 1.00000000e-12,
# (pid=4876)        6.50867206e-03, 4.72796247e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4875) basinhopping step 4: f 3.08152 trial_f 3.08152 accepted 1  lowest_f 3.07041
# (pid=4875)
# (pid=4875)                          fun: array([3.07040596])
# (pid=4875)  lowest_optimization_result:       fun: array([3.07040596])
# (pid=4875)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4875)       jac: array([-5.02828890e-03,  1.23178667e-01,  6.01607653e-04,  5.77792263e+00,
# (pid=4875)        -1.94580796e-02,  2.87525559e-03,  5.79747259e+00,  1.93367338e+03])
# (pid=4875)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4875)      nfev: 2187
# (pid=4875)       nit: 150
# (pid=4875)    status: 0
# (pid=4875)   success: True
# (pid=4875)         x: array([3.28453601e-01, 1.00000000e-12, 1.82257073e-02, 1.00000000e-12,
# (pid=4875)        1.37825397e-02, 5.13040597e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4875)                     message: ['success condition satisfied']
# (pid=4875)       minimization_failures: 0
# (pid=4875)                        nfev: 6147
# (pid=4875)                         nit: 4
# (pid=4875)                           x: array([3.28453601e-01, 1.00000000e-12, 1.82257073e-02, 1.00000000e-12,
# (pid=4875)        1.37825397e-02, 5.13040597e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4880) basinhopping step 5: f 3.03218 trial_f 3.03218 accepted 1  lowest_f 3.03218
# (pid=4880) found new global minimum on step 5 with function value 3.03218
# (pid=4884) basinhopping step 4: f 1.56366 trial_f 1.56366 accepted 1  lowest_f 1.56218
# (pid=4884)
# (pid=4884)                          fun: array([1.5621835])
# (pid=4884)  lowest_optimization_result:       fun: array([1.5621835])
# (pid=4884)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4884)       jac: array([-4.31112923e-03,  3.38555850e-03, -3.52688989e-03,  3.33696668e+00,
# (pid=4884)        -3.57491814e-06,  9.87099291e-04,  3.33701211e+00,  2.83410221e+03])
# (pid=4884)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4884)      nfev: 1764
# (pid=4884)       nit: 155
# (pid=4884)    status: 0
# (pid=4884)   success: True
# (pid=4884)         x: array([2.48212965e-01, 2.34399360e-01, 3.08858428e-03, 1.00000000e-12,
# (pid=4884)        2.35625234e-02, 4.38785592e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4884)                     message: ['success condition satisfied']
# (pid=4884)       minimization_failures: 0
# (pid=4884)                        nfev: 6390
# (pid=4884)                         nit: 4
# (pid=4884)                           x: array([2.48212965e-01, 2.34399360e-01, 3.08858428e-03, 1.00000000e-12,
# (pid=4884)        2.35625234e-02, 4.38785592e-03, 1.00000000e-12, 1.00000000e-12])
# (pid=4880) basinhopping step 6: f 3.03218 trial_f 3.03218 accepted 1  lowest_f 3.03218
# (pid=4880) basinhopping step 7: f 3.03218 trial_f 14.8651 accepted 0  lowest_f 3.03218
# (pid=4880)
# (pid=4880)                          fun: array([3.03218118])
# (pid=4880)  lowest_optimization_result:       fun: array([3.03218118])
# (pid=4880)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=4880)       jac: array([-1.83801996e-01, -5.53163915e-01, -3.28998695e-01, -5.80460124e-03,
# (pid=4880)         4.02254674e-02,  8.04889129e+00, -4.58501237e-02,  1.23657005e+01])
# (pid=4880)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=4880)      nfev: 1179
# (pid=4880)       nit: 94
# (pid=4880)    status: 0
# (pid=4880)   success: True
# (pid=4880)         x: array([4.00000000e-01, 4.00000000e-01, 2.38124481e-03, 1.33302716e-08,
# (pid=4880)        2.44995263e-02, 1.00000000e-12, 1.63770910e-02, 3.41682254e-05])
# (pid=4880)                     message: ['success condition satisfied']
# (pid=4880)       minimization_failures: 1
# (pid=4880)                        nfev: 7542
# (pid=4880)                         nit: 7
# (pid=4880)                           x: array([4.00000000e-01, 4.00000000e-01, 2.38124481e-03, 1.33302716e-08,
# (pid=4880)        2.44995263e-02, 1.00000000e-12, 1.63770910e-02, 3.41682254e-05])

# %% [markdown]
# # Plots

# %%
import matplotlib.pyplot as plt
import covid_plots

# %%
def loadDataFrame(filename):
    df= pd.read_pickle(filename)
    df.columns = [c.lower().replace(' ', '_') for c in df.columns]
    df.columns = [c.lower().replace('(', '') for c in df.columns]
    df.columns = [c.lower().replace(')', '') for c in df.columns]
    return df

# %%
#DRS 01 - Grande São Paulo
#DRS 02 - Araçatuba
#DRS 03 - Araraquara
#DRS 04 - Baixada Santista
#DRS 05 - Barretos
#DRS 06 - Bauru
#DRS 07 - Campinas
#DRS 08 - Franca
#DRS 09 - Marília
#DRS 10 - Piracicaba
#DRS 11 - Presidente Prudente
#DRS 12 - Registro
#DRS 13 - Ribeirão Preto
#DRS 14 - São João da Boa Vista
#DRS 15 - São José do Rio Preto
#DRS 16 - Sorocaba
#DRS 17 - Taubaté

#select districts for plotting
districts4Plot=['DRS 01 - Grande São Paulo',
               'DRS 04 - Baixada Santista',
               'DRS 07 - Campinas',
               'DRS 05 - Barretos',
               'DRS 15 - São José do Rio Preto']

#main district region for analysis
districtRegion = "DRS 01 - Grande São Paulo"

#Choose here your options
#opt=0 all plots
#opt=1 corona log plot
#opt=2 logistic model prediction
#opt=3 bar plot with growth rate
#opt=4 log plot + bar plot
#opt=5 SEAIR-D Model
opt = 0

#versio'n to identify the png file result
version = "1"

#parameters for plotting
query = dfparam.query('DRS == "{}"'.format(districtRegion)).reset_index()
startdate = query['start-date'][0]
predict_range = query['prediction-range'][0]

# %%
#do not allow the scrolling of the plots

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines){
#     return false;
# }

# %%
#number of cases to start plotting model in log graph - real data = 100
startCase=1

# %%
covid_plots.covid_plots(districtRegion, districts4Plot, startdate,predict_range, startCase, opt, version, show=True)
