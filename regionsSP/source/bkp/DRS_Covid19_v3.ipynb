# %% [markdown]
# # COVID19 - District Region

# %% [markdown]
# Install necessary packages for parallel computation:
#
# ```
# pip install ipyparallel
# ipcluster nbextension enable
# pip install parallel-execute
# ```
#
# To install for all users on JupyterHub, as root:
# ```
# jupyter nbextension install --sys-prefix --py ipyparallel
# jupyter nbextension enable --sys-prefix --py ipyparallel
# jupyter serverextension enable --sys-prefix --py ipyparallel
# ```
#
# start cluster at jupyter notebook interface

# %%
import urllib.request
import pandas as pd
import numpy as np

# %%
# Download data
import get_data
LoadData=False

if LoadData:
    get_data.get_data()

# %%
dfSP = pd.read_csv("data/dados_municipios_SP.csv")
dfSP
# Out:
#             date state                city place_type  confirmed  deaths  \
# 0     2020-04-19    SP               TOTAL      state      14267    1015
# 1     2020-04-18    SP               TOTAL      state      13894     991
# 2     2020-04-17    SP               TOTAL      state      12841     928
# 3     2020-04-16    SP               TOTAL      state      11568     853
# 4     2020-04-15    SP               TOTAL      state      11043     778
# ...          ...   ...                 ...        ...        ...     ...
# 3263  2020-04-14    SP  Águas de São Pedro       city          1       0
# 3264  2020-04-13    SP  Águas de São Pedro       city          1       0
# 3265  2020-04-12    SP  Águas de São Pedro       city          1       0
# 3266  2020-04-11    SP  Águas de São Pedro       city          1       0
# 3267  2020-04-10    SP  Águas de São Pedro       city          1       0
#
#       order_for_place  is_last      popEst  city_ibge_code  \
# 0                  53     True  45919049.0            35.0
# 1                  52    False  45919049.0            35.0
# 2                  51    False  45919049.0            35.0
# 3                  50    False  45919049.0            35.0
# 4                  49    False  45919049.0            35.0
# ...               ...      ...         ...             ...
# 3263                5    False      3451.0       3500600.0
# 3264                4    False      3451.0       3500600.0
# 3265                3    False      3451.0       3500600.0
# 3266                2    False      3451.0       3500600.0
# 3267                1    False      3451.0       3500600.0
#
#       confirmed_per_100k_inhabitants  death_rate                  DRS
# 0                           31.06989      0.0711           Indefinido
# 1                           30.25760      0.0713           Indefinido
# 2                           27.96443      0.0723           Indefinido
# 3                           25.19216      0.0737           Indefinido
# 4                           24.04884      0.0705           Indefinido
# ...                              ...         ...                  ...
# 3263                        28.97711         NaN  DRS 10 - Piracicaba
# 3264                        28.97711         NaN  DRS 10 - Piracicaba
# 3265                        28.97711         NaN  DRS 10 - Piracicaba
# 3266                        28.97711         NaN  DRS 10 - Piracicaba
# 3267                        28.97711         NaN  DRS 10 - Piracicaba
#
# [3268 rows x 13 columns]

# %%
# Model

# %%
# lista DRSs
DRS = list(dfSP["DRS"].unique())
DRS.remove("Indefinido")
DRS
# Out:
# ['DRS 09 - Marília',
#  'DRS 06 - Bauru',
#  'DRS 16 - Sorocaba',
#  'DRS 07 - Campinas',
#  'DRS 03 - Araraquara',
#  'DRS 02 - Araçatuba',
#  'DRS 17 - Taubaté',
#  'DRS 10 - Piracicaba',
#  'DRS 01 - Grande São Paulo',
#  'DRS 15 - São José do Rio Preto',
#  'DRS 12 - Registro',
#  'DRS 05 - Barretos',
#  'DRS 13 - Ribeirão Preto',
#  'DRS 11 - Presidente Prudente',
#  'DRS 04 - Baixada Santista',
#  'DRS 14 - São João da Boa Vista',
#  'DRS 08 - Franca']

# %% [markdown]
# # SEAIR-D Model Equations
#
# $$\begin{array}{l}\frac{d s}{d t}=-[\beta i(t) + \beta_2 a(t)-\mu] \cdot s(t)\\
# \frac{d e}{d t}=[\beta i(t) + \beta_2 a(t)] \cdot s(t) -(\sigma+\mu) \cdot e(t)\\
# \frac{d a}{d t}=\sigma e(t) \cdot (1-p)-(\gamma+\mu) \cdot a(t) \\
# \frac{d i}{d t}=\sigma e(t) \cdot p - (\gamma + \sigma_2 + \sigma_3 + \mu) \cdot i(t)\\
# \frac{d r}{d t}=(b + \sigma_2) \cdot i(t) + \gamma \cdot a(t) - \mu \cdot r(t)\\
# \frac{d k}{d t}=(a + \sigma_3 - \mu) \cdot d(t)
# \end{array}$$
#
# The last equation does not need to be solve because:
#
# $$\frac{d k}{d t}=-(\frac{d e}{d t}+\frac{d a}{d t}+\frac{d i}{d t}+\frac{d r}{d t})$$
#
# The sum of all rates are equal to zero! The importance of this equation is that it conservates the rates.

# %% [markdown]
# ## Parameters

# %% [markdown]
# $\beta$: Effective contact rate [1/min]
#
# $\gamma$: Recovery(+Mortality) rate $\gamma=(a+b)$ [1/min]
#
# $a$: mortality of healed  [1/min]
#
# $b$: recovery rate  [1/min]
#
# $\sigma$: is the rate at which individuals move from the exposed to the infectious classes. Its reciprocal ($1/\sigma$) is the average latent (exposed) period.
#
# $\sigma_2$: is the rate at which individuals move from the infectious to the healed classes. Its reciprocal ($1/\sigma_2$) is the average latent (exposed) period
#
# $\sigma_3$: is the rate at which individuals move from the infectious to the dead classes. Its reciprocal ($1/\sigma_3$) is the average latent (exposed) period
#
# $p$: is the fraction of the exposed which become symptomatic infectious sub-population.
#
# $(1-p)$: is the fraction of the exposed which becomes asymptomatic infectious sub-population.

# %%
#objective function Odeint solver
from scipy.integrate import odeint
import math

#objective function Odeint solver
def lossOdeint(point, data, death, s_0, e_0, a_0, i_0, r_0, d_0, startNCases, ratioRecovered, weigthCases, weigthRecov):
    size = len(data)
    beta, beta2, sigma, sigma2, sigma3, gamma, b, mu = point
    def SEAIRD(y,t):
        S = y[0]
        E = y[1]
        A = y[2]
        I = y[3]
        R = y[4]
        D = y[5]
        p=0.2
        # beta2=beta
        y0=-(beta2*A+beta*I)*S+mu*S #S
        y1=(beta2*A+beta*I)*S-sigma*E-mu*E #E
        y2=sigma*E*(1-p)-gamma*A-mu*A #A
        y3=sigma*E*p-gamma*I-sigma2*I-sigma3*I-mu*I#I
        y4=b*I+gamma*A+sigma2*I-mu*R #R
        y5=(-(y0+y1+y2+y3+y4)) #D
        return [y0,y1,y2,y3,y4,y5]

    y0=[s_0,e_0,a_0,i_0,r_0,d_0]
    tspan=np.arange(0, size, 1)
    res=odeint(SEAIRD,y0,tspan,hmax=0.01)

    l1=0
    l2=0
    l3=0
    tot=0

    for i in range(0,len(data.values)):
        if data.values[i]>startNCases:
            l1 = l1+(math.log10(max(res[i,3]+1,1e-12)) - math.log10(max(data.values[i]+1,1e-12)))**2
            l2 = l2+(math.log10(max(res[i,5]+1,1e-12)) - math.log10(max(death.values[i]+1,1e-12)))**2
            newRecovered=min(1e6,data.values[i]*ratioRecovered)
            l3 = l3+(math.log10(max(res[i,4]+1,1e-12)) - math.log10(max(newRecovered+1,1e-12)))**2
            tot+=1
    l1=np.sqrt(l1/max(1,tot))
    l2=np.sqrt(l2/max(1,tot))
    l3=np.sqrt(l3/max(1,tot))
    
    #weight for cases
    u = weigthCases  #Brazil US 0.1
    w = weigthRecov
    #weight for deaths
    v = max(0,1. - u - w)
    
    return u*l1 + v*l2 + w*l3

# %%
# Initial parameters
dfparam = pd.read_csv("data/param.csv")
dfparam
# Out:
#                                DRS  start-date  prediction-range        s0  \
# 0        DRS 01 - Grande São Paulo  2020-03-15                60  280000.0
# 1               DRS 02 - Araçatuba  2020-04-15                60     200.0
# 2              DRS 03 - Araraquara  2020-04-15                60     600.0
# 3        DRS 04 - Baixada Santista  2020-04-15                60    2000.0
# 4                DRS 05 - Barretos  2020-04-22                60     300.0
# 5                   DRS 06 - Bauru  2020-04-15                60    4000.0
# 6                DRS 07 - Campinas  2020-04-09                60    5000.0
# 7                  DRS 08 - Franca  2020-04-17                60     300.0
# 8                 DRS 09 - Marília  2020-04-17                60    2000.0
# 9              DRS 10 - Piracicaba  2020-04-09                60    1000.0
# 10    DRS 11 - Presidente Prudente  2020-04-17                60    1000.0
# 11               DRS 12 - Registro  2020-04-19                60     300.0
# 12         DRS 13 - Ribeirão Preto  2020-04-10                60    1000.0
# 13  DRS 14 - São João da Boa Vista  2020-04-15                60    1000.0
# 14  DRS 15 - São José do Rio Preto  2020-04-15                60    2000.0
# 15               DRS 16 - Sorocaba  2020-04-09                60     300.0
# 16                DRS 17 - Taubaté  2020-04-09                60    4000.0
#
#         e0      a0       i0      r0       d0  START  RATIO  WCASES  WREC
# 0   0.0001  0.0001   0.0001  0.0001  80.0000   1500    0.1     0.6   0.1
# 1   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 2   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 3   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 4   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 5   0.0001  0.0001   4.0000  0.0001   0.0001      0    0.1     0.4   0.1
# 6   0.0001  0.0001  40.0000  0.0001   0.0001      0    0.1     0.4   0.1
# 7   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 8   0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 9   0.0001  0.0001   0.0001  0.0001   1.0000      0    0.1     0.4   0.1
# 10  0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 11  0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 12  0.0001  0.0001   0.0001  0.0001   0.0001      5    0.1     0.4   0.1
# 13  0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 14  0.0001  0.0001   0.0001  0.0001   0.0001      0    0.1     0.4   0.1
# 15  0.0001  0.0001   2.0000  0.0001   0.0001      0    0.1     0.4   0.1
# 16  0.0001  0.0001  17.0000  0.0001   2.0000      0    0.1     0.4   0.1

# %%
# Initial parameter optimization

# %%
# Load solver
GlobalOptimization=False
import ray

if GlobalOptimization:
    import ray
    import LearnerGlobalOpt as Learner  # basinhopping global optimization (max 100 times minimize)
else:
    import Learner #minimize
# Out:
# 2020-04-24 02:29:41,439	WARNING resource_spec.py:163 -- Warning: Capping object memory store to 20.0GB. To increase this further, specify `object_store_memory` when calling ray.init() or ray start.
# 2020-04-24 02:29:41,441	INFO resource_spec.py:205 -- Starting Ray with 127.59 GiB memory available for workers and up to 18.63 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).

# %%
allDistricts=True

results=[]
if allDistricts:
    for districtRegion in DRS:
        query = dfparam.query('DRS == "{}"'.format(districtRegion)).reset_index()
        parameters = np.array(query.iloc[:, 2:])[0]
        learner = Learner.Learner.remote(districtRegion, lossOdeint, *parameters)
        #learner.train()
        #add function evaluation to the queue
        results.append(learner.train.remote())
else:
    districtRegion="DRS 01 - Grande São Paulo"
    query = dfparam.query('DRS == "{}"'.format(districtRegion)).reset_index()
    parameters = np.array(query.iloc[:, 2:])[0]
    learner = Learner.Learner(districtRegion, lossOdeint, *parameters)
    learner.train()

# #execute all the queue with max_runner_cap at a time    
results = ray.get(results)
# Out:
# (pid=38119)
# (pid=38119)  running model for DRS 09 - Marília
# (pid=38119)
# (pid=38119)        fun: 5.756753475988391
# (pid=38119)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=38119)       jac: array([-3.57935903e-05, -3.63264974e-05, -1.52766688e-05,  1.28785871e-05,
# (pid=38119)         1.72306613e-05,  1.27897692e-05, -4.26325641e-06,  2.15827356e-05])
# (pid=38119)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=38119)      nfev: 18
# (pid=38119)       nit: 1
# (pid=38119)    status: 0
# (pid=38119)   success: True
# (pid=38119)         x: array([0.00103579, 0.00103633, 0.00626492, 0.00625   , 0.00625   ,
# (pid=38119)        0.0009873 , 0.00100426, 0.00097851])
# (pid=38120)
# (pid=38120)  running model for DRS 07 - Campinas
# (pid=38121)
# (pid=38121)  running model for DRS 16 - Sorocaba
# (pid=38118)
# (pid=38118)  running model for DRS 06 - Bauru
# (pid=38176)
# (pid=38176)  running model for DRS 03 - Araraquara
# 2020-04-24 02:29:43,470	WARNING worker.py:1779 -- WARNING: 12 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-04-24 02:29:43,471	WARNING worker.py:1779 -- WARNING: 13 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-04-24 02:29:43,472	WARNING worker.py:1779 -- WARNING: 14 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-04-24 02:29:43,473	WARNING worker.py:1779 -- WARNING: 15 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-04-24 02:29:44,030	WARNING worker.py:1779 -- WARNING: 16 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-04-24 02:29:44,031	WARNING worker.py:1779 -- WARNING: 17 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-04-24 02:29:44,144	WARNING worker.py:1779 -- WARNING: 18 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2020-04-24 02:29:44,146	WARNING worker.py:1779 -- WARNING: 19 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=38118)
# (pid=38118)        fun: 0.5020253151167708
# (pid=38118)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=38118)       jac: array([ 0.00067187,  0.00069189, -0.00463799,  0.03446556,  0.0383808 ,
# (pid=38118)         0.26803528, -0.00390946,  0.17469218])
# (pid=38118)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=38118)      nfev: 1098
# (pid=38118)       nit: 51
# (pid=38118)    status: 0
# (pid=38118)   success: True
# (pid=38118)         x: array([1.61119850e+01, 3.90456479e-01, 7.15660919e-02, 6.25000000e-03,
# (pid=38118)        6.25000000e-03, 1.00000000e-16, 8.63895600e-02, 3.01895172e-03])
# (pid=38178)
# (pid=38178)  running model for DRS 02 - Araçatuba
# (pid=38121)
# (pid=38121)        fun: 0.31370728114295043
# (pid=38121)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=38121)       jac: array([-7.79376563e-06,  7.77156117e-08, -3.03568487e-01,  2.51108245e-01,
# (pid=38121)         2.51643445e-01,  1.02336473e-03, -5.33706412e-04,  1.95282679e-03])
# (pid=38121)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=38121)      nfev: 612
# (pid=38121)       nit: 54
# (pid=38121)    status: 0
# (pid=38121)   success: True
# (pid=38121)         x: array([5.00000000e+01, 4.05037069e-01, 2.00000000e-01, 6.25000000e-03,
# (pid=38121)        6.25000000e-03, 4.72196063e-03, 2.60751466e-02, 4.65529526e-03])
# (pid=38176)
# (pid=38176)        fun: 0.5275977877676715
# (pid=38176)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=38176)       jac: array([ 6.69797551e-05,  8.97171226e-05, -1.64667369e-01,  6.11944162e-02,
# (pid=38176)         6.13518680e-02,  2.22527952e-01,  2.27928787e-05, -4.69889683e-03])
# (pid=38176)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=38176)      nfev: 1071
# (pid=38176)       nit: 59
# (pid=38176)    status: 0
# (pid=38176)   success: True
# (pid=38176)         x: array([1.41919679e+01, 5.00000000e+01, 2.00000000e-01, 6.25000000e-03,
# (pid=38176)        6.25000000e-03, 1.00000000e-16, 1.30432624e-01, 9.73432219e-03])
# (pid=38175)
# (pid=38175)  running model for DRS 17 - Taubaté
# (pid=38177)
# (pid=38177)  running model for DRS 10 - Piracicaba
# (pid=38120)
# (pid=38120)        fun: 0.31806619699064004
# (pid=38120)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=38120)       jac: array([-2.11797246e-04,  1.24925070e-03, -6.94527769e-04,  1.19112498e-03,
# (pid=38120)        -2.33846276e-04,  6.39239017e-01,  1.43159928e-03, -5.06443110e-02])
# (pid=38120)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=38120)      nfev: 819
# (pid=38120)       nit: 50
# (pid=38120)    status: 0
# (pid=38120)   success: True
# (pid=38120)         x: array([2.27236599e+00, 2.56482360e-01, 5.68485711e-02, 8.80323050e-03,
# (pid=38120)        6.25003173e-03, 1.00000000e-16, 2.81919622e-02, 1.65253280e-03])
# (pid=38217)
# (pid=38217)  running model for DRS 15 - São José do Rio Preto
# (pid=38178)
# (pid=38178)        fun: 0.48512849013760045
# (pid=38178)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=38178)       jac: array([ 7.82707232e-06, -2.16177076e-04, -3.97473476e-01,  6.56053822e-02,
# (pid=38178)         6.56404431e-02, -2.50087728e-03,  5.01987341e-05,  1.28552335e-02])
# (pid=38178)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=38178)      nfev: 1008
# (pid=38178)       nit: 44
# (pid=38178)    status: 0
# (pid=38178)   success: True
# (pid=38178)         x: array([3.09044327e+01, 5.00000000e+01, 2.00000000e-01, 6.25000000e-03,
# (pid=38178)        6.25000000e-03, 2.12487201e-02, 1.34050234e-01, 7.58034781e-03])
# (pid=38218)
# (pid=38218)  running model for DRS 01 - Grande São Paulo
# (pid=38218) /home/ats4i/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
# (pid=38218)   warnings.warn(warning_msg, ODEintWarning)
# (pid=38218)
# (pid=38218)        fun: 0.48588771849054563
# (pid=38218)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=38218)       jac: array([0., 0., 0., 0., 0., 0., 0., 0.])
# (pid=38218)   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
# (pid=38218)      nfev: 81
# (pid=38218)       nit: 2
# (pid=38218)    status: 0
# (pid=38218)   success: True
# (pid=38218)         x: array([5.55890884e+00, 5.55886984e+00, 1.63680938e-02, 5.26926479e-02,
# (pid=38218)        6.25000000e-03, 3.34980297e-02, 5.22693961e-02, 4.17975298e-04])
# (pid=38220)
# (pid=38220)  running model for DRS 12 - Registro
# (pid=38220)
# (pid=38220)        fun: 0.8814547589042321
# (pid=38220)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=38220)       jac: array([0., 0., 0., 0., 0., 0., 0., 0.])
# (pid=38220)   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
# (pid=38220)      nfev: 9
# (pid=38220)       nit: 0
# (pid=38220)    status: 0
# (pid=38220)   success: True
# (pid=38220)         x: array([0.001  , 0.001  , 0.00625, 0.00625, 0.00625, 0.001  , 0.001  ,
# (pid=38220)        0.001  ])
# (pid=38219)
# (pid=38219)  running model for DRS 05 - Barretos
# (pid=38219)
# (pid=38219)        fun: 0.0
# (pid=38219)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=38219)       jac: array([0., 0., 0., 0., 0., 0., 0., 0.])
# (pid=38219)   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
# (pid=38219)      nfev: 9
# (pid=38219)       nit: 0
# (pid=38219)    status: 0
# (pid=38219)   success: True
# (pid=38219)         x: array([0.001  , 0.001  , 0.00625, 0.00625, 0.00625, 0.001  , 0.001  ,
# (pid=38219)        0.001  ])
# (pid=38250)
# (pid=38250)  running model for DRS 13 - Ribeirão Preto
# (pid=38217)
# (pid=38217)        fun: 0.6048648549359547
# (pid=38217)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=38217)       jac: array([ 4.05298017e-04,  3.70914410e-04,  3.23214899e-02,  6.63984756e-02,
# (pid=38217)         5.90863025e-02,  4.90781693e-01,  7.88719090e-03, -1.54856927e-01])
# (pid=38217)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=38217)      nfev: 927
# (pid=38217)       nit: 53
# (pid=38217)    status: 0
# (pid=38217)   success: True
# (pid=38217)         x: array([5.17591571e+00, 1.53428057e+01, 1.99960995e-01, 1.75944626e-01,
# (pid=38217)        6.25000000e-03, 1.00000000e-16, 5.84096355e-02, 3.61039759e-03])
# (pid=38252)
# (pid=38252)  running model for DRS 11 - Presidente Prudente
# 2020-04-24 02:30:04,956	ERROR worker.py:1719 -- Possible unhandled error from worker: ray_Learner:train() (pid=38219, host=jedha)
#   File "/home/ats4i/Desktop/corona/dataAndModelsCovid19/regionsSP/Learner.py", line 139, in train
#     self.death, self.districtRegion, self.s_0, self.e_0, self.a_0, self.i_0, self.r_0, self.d_0)
#   File "/home/ats4i/Desktop/corona/dataAndModelsCovid19/regionsSP/Learner.py", line 86, in predict
#     new_index = self.extend_index(data.index, self.predict_range)
#   File "/home/ats4i/Desktop/corona/dataAndModelsCovid19/regionsSP/Learner.py", line 77, in extend_index
#     current = datetime.strptime(index[-1], '%Y-%m-%d')
#   File "/home/ats4i/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 3930, in __getitem__
#     return getitem(key)
# IndexError: index -1 is out of bounds for axis 0 with size 0
# (pid=38175)
# (pid=38175)        fun: 0.19217082280785514
# (pid=38175)  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# (pid=38175)       jac: array([ 9.74257341e-03, -3.47244455e-04,  1.63091954e-01, -7.20009774e-02,
# (pid=38175)        -8.53523113e-02,  3.88751212e-01,  2.25457708e-02, -6.63316346e+00])
# (pid=38175)   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# (pid=38175)      nfev: 1044
# (pid=38175)       nit: 36
# (pid=38175)    status: 0
# (pid=38175)   success: True
# (pid=38175)         x: array([3.90291955e+01, 3.81265709e+01, 4.08777352e-02, 1.21637405e-02,
# (pid=38175)        6.25524779e-03, 3.25072278e-03, 9.43678893e-03, 2.25152059e-04])
# (pid=38251)
# (pid=38251)  running model for DRS 04 - Baixada Santista

# %%
# Save data as csv
import glob
import os

path = './results/data'
files = glob.glob(os.path.join(path, "*.csv"))

df = (pd.read_csv(f).assign(DRS = f.split(" - ")[-1].split(".")[0]) for f in files)
df_all_drs = pd.concat(df, ignore_index=True)
df_all_drs.index.name = 'index'
df_all_drs.to_csv('./data/SEAIRD_sigmaOpt_AllDRS'+'.csv', sep=",")

# %% [markdown]
# # Plots

# %%
import matplotlib.pyplot as plt
import covid_plots

# %%
def loadDataFrame(filename):
    df= pd.read_pickle(filename)
    df.columns = [c.lower().replace(' ', '_') for c in df.columns]
    df.columns = [c.lower().replace('(', '') for c in df.columns]
    df.columns = [c.lower().replace(')', '') for c in df.columns]
    return df

# %%
#DRS 01 - Grande São Paulo
#DRS 02 - Araçatuba
#DRS 03 - Araraquara
#DRS 04 - Baixada Santista
#DRS 05 - Barretos
#DRS 06 - Bauru
#DRS 07 - Campinas
#DRS 08 - Franca
#DRS 09 - Marília
#DRS 10 - Piracicaba
#DRS 11 - Presidente Prudente
#DRS 12 - Registro
#DRS 13 - Ribeirão Preto
#DRS 14 - São João da Boa Vista
#DRS 15 - São José do Rio Preto
#DRS 16 - Sorocaba
#DRS 17 - Taubaté

#select districts for plotting
districts4Plot=['DRS 01 - Grande São Paulo',
               'DRS 04 - Baixada Santista',
               'DRS 07 - Campinas',
               'DRS 05 - Barretos',
               'DRS 15 - São José do Rio Preto']

#main district region for analysis
districtRegion = "DRS 01 - Grande São Paulo"

#Choose here your options
#opt=0 all plots
#opt=1 corona log plot
#opt=2 logistic model prediction
#opt=3 bar plot with growth rate
#opt=4 log plot + bar plot
#opt=5 SEAIR-D Model
opt = 0

#versio'n to identify the png file result
version = "1"

#parameters for plotting
query = dfparam.query('DRS == "{}"'.format(districtRegion)).reset_index()
startdate = query['start-date'][0]
predict_range = query['prediction-range'][0]

# %%
#do not allow the scrolling of the plots

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines){
#     return false;
# }

# %%
#number of cases to start plotting model in log graph - real data = 100
startCase=1

# %%
#make plots for every region in DRS
for districtRegion in DRS:
    covid_plots.covid_plots(districtRegion, districts4Plot, startdate,predict_range, 1, 5, 1, show=True)

# %%
#make plots for selected DRS
covid_plots.covid_plots(districtRegion, districts4Plot, startdate,predict_range, startCase, opt, version, show=True)
