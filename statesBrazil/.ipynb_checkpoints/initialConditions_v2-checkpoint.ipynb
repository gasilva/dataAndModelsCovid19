# %% [markdown]
# # Optimize Initial Conditions
# ## Yabox

# %%
from scipy.optimize import brute
import numpy as np
from datetime import datetime,timedelta
import pandas as pd
from yabox import DE

# %% [markdown]
# # Initialize Ray

# %%
from environs import Env
env = Env()
env.str("CUDA_DEVICE_ORDER",'PCI_BUS_ID')
env.int("CUDA_VISIBLE_DEVICES",1)
env.int("NUMBA_ENABLE_CUDASIM",1)
env.bool("OMPI_MCA_opal_cuda_support",True)

import os
import ray
MB=1024*1024
GB=MB*1024
ray.shutdown()
ray.init(object_store_memory=1*GB,memory=1*GB,
         #lru_evict=True,
         driver_object_store_memory=500*MB,num_gpus=4,num_cpus=10,
         ignore_reinit_error=True) # , include_webui=False, ignore_reinit_error=True)

@ray.remote(num_gpus=1)
def use_gpu():
    print("ray.get_gpu_ids(): {}".format(ray.get_gpu_ids()[0]))
    print("CUDA_VISIBLE_DEVICES: {}".format(os.environ["CUDA_VISIBLE_DEVICES"]))

use_gpu.remote()
# Out:
# 2020-07-18 18:55:22,985	INFO resource_spec.py:212 -- Starting Ray with 0.98 GiB memory available for workers and up to 1.0 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-07-18 18:55:23,449	INFO services.py:1170 -- View the Ray dashboard at localhost:8265
# ObjectID(45b95b1c8bd3a9c4ffffffff010000c801000000)

# %% [markdown]
# # Load New and Process Data from website data.brasil.io

# %%
import get_data
LoadData=True

if LoadData:
    get_data.get_data()
# Out:
# Baixando arquivos brasil.io...
# (pid=5665) ray.get_gpu_ids(): 3
# (pid=5665) CUDA_VISIBLE_DEVICES: 3

# %% [markdown]
# # Functions to Load Processed Data

# %%
def load_confirmed(state, start_date):
    dateparse = lambda x: datetime.strptime(x, '%Y-%m-%d')
    df = pd.read_csv('./data/confirmados.csv',delimiter=',',parse_dates=True, date_parser=dateparse)
    y=[]
    x=[]
    for i in range(0,len(df.date)):
        y.append(df[state].values[i])
        x.append(df.date.values[i])
    df2=pd.DataFrame(data=y,index=x,columns=[""])
    df2=df2[start_date:]
    del x,y,df,dateparse
    return df2

def load_dead(state, start_date):
    dateparse = lambda x: datetime.strptime(x, '%Y-%m-%d')
    df = pd.read_csv('./data/mortes.csv',delimiter=',',parse_dates=True, date_parser=dateparse)
    y=[]
    x=[]
    for i in range(0,len(df.date)):
        y.append(df[state].values[i])
        x.append(df.date.values[i])
    df2=pd.DataFrame(data=y,index=x,columns=[""])
    df2=df2[start_date:]
    del x,y,df,dateparse
    return df2

# %% [markdown]
# # Load solver

# %%
LoadBH=True
if LoadBH:
    import LearnerICRayNoLoadBH as L 
else:
    import LearnerICRayNoLoad as L

# %% [markdown]
# # Data for States

# %%
dfparam = pd.read_csv("data/param_optimized_Yabox_HistMin.csv")
dfparam
# Out:
#    state  start-date  prediction-range       s0  e0  a0   i0   r0   d0  START  \
# 0     SP  2020-03-16               200  9133723   0   0  714  300   74      3
# 1     ES  2020-04-09               200   553381   0   0   55  250   79     10
# 2     MG  2020-04-01               200  1223239   0   0  224  250    5      6
# 3     RJ  2020-03-14               200   797669   0   0  830  250   20     32
# 4     CE  2020-03-19               200   674642   0   0  740  250  151     16
# 5     PE  2020-03-20               200   825113   0   0  667  250  133     97
# 6     AM  2020-03-24               200   793195   0   0  737  250   48     22
# 7     PA  2020-03-26               200   780715   0   0  903  250  165     79
# 8     PI  2020-03-25               200   825140   0   0  941  250   28     69
# 9     RR  2020-03-20               200   808620   0   0  769  250   42      4
# 10    AP  2020-03-14               200   776418   0   0  859  250   18     39
#
#     RATIO  WCASES    WREC
# 0    0.15  0.4385  0.0048
# 1    0.15  0.4462  0.0192
# 2    0.15  0.3014  0.0098
# 3    0.15  0.6667  0.0318
# 4    0.15  0.5523  0.0230
# 5    0.15  0.4353  0.0187
# 6    0.15  0.5826  0.0033
# 7    0.15  0.5310  0.0342
# 8    0.15  0.3187  0.0289
# 9    0.15  0.3927  0.0399
# 10   0.15  0.6030  0.0191

# %%
df = pd.read_csv("data/dados_total_estados.csv")
df
# Out:
#        index        date state   city place_type  confirmed  deaths  \
# 0          0  2020-07-17    AP  TOTAL      state      33436     499
# 1          1  2020-07-16    AP  TOTAL      state      33004     493
# 2          2  2020-07-15    AP  TOTAL      state      32408     488
# 3          3  2020-07-14    AP  TOTAL      state      31885     483
# 4          4  2020-07-13    AP  TOTAL      state      31552     478
# ...      ...         ...   ...    ...        ...        ...     ...
# 3353  323304  2020-02-29    SP  TOTAL      state          2       0
# 3354  323305  2020-02-28    SP  TOTAL      state          2       0
# 3355  323306  2020-02-27    SP  TOTAL      state          1       0
# 3356  323307  2020-02-26    SP  TOTAL      state          1       0
# 3357  323308  2020-02-25    SP  TOTAL      state          1       0
#
#       order_for_place  is_last      popEst  city_ibge_code  \
# 0                 119     True    845731.0            16.0
# 1                 118    False    845731.0            16.0
# 2                 117    False    845731.0            16.0
# 3                 116    False    845731.0            16.0
# 4                 115    False    845731.0            16.0
# ...               ...      ...         ...             ...
# 3353                5    False  45919049.0            35.0
# 3354                4    False  45919049.0            35.0
# 3355                3    False  45919049.0            35.0
# 3356                2    False  45919049.0            35.0
# 3357                1    False  45919049.0            35.0
#
#       confirmed_per_100k_inhabitants  death_rate
# 0                         3953.50295      0.0149
# 1                         3902.42287      0.0149
# 2                         3831.95129      0.0151
# 3                         3770.11130      0.0151
# 4                         3730.73708      0.0151
# ...                              ...         ...
# 3353                         0.00436      0.0000
# 3354                         0.00436      0.0000
# 3355                         0.00218      0.0000
# 3356                         0.00218      0.0000
# 3357                         0.00218      0.0000
#
# [3358 rows x 13 columns]

# %% [markdown]
# # Functions for Optimization

# %%
from scipy.integrate import odeint
import sys
import io
import gc

def create_f(state,e0,a0,r0,date, ratio, predict_range, version):
                
    def fobjective(point):
        
        dead=  load_dead(state,date)
        data = load_confirmed(state,date)*(1-ratio)-dead
        cleanRecovered=False
        s0, deltaDate, i0, d0, startNCases, weigthCases, weigthRecov = point
        end_date=datetime.strptime(date, "%Y-%m-%d") + timedelta(days=deltaDate)
        f=L.Learner.remote(state, end_date.strftime("%Y-%m-%d"), predict_range,\
                           s0, e0, a0, i0, r0, d0, startNCases, ratio, weigthCases, weigthRecov, \
                           cleanRecovered, version, data, dead, savedata=False)
        result = f.train.remote() 
        result = ray.get(result) 

        del end_date,cleanRecovered, data, dead, point,f         

        gc.collect()

        return result
    return fobjective

# %%
@ray.remote(memory=50 * 1024 * 1024, max_calls=1)
def opt(state,s0,i0,e0,a0,r0,d0,wcases,date,startNCases, ratio, predict_range, version):

    bounds=[(s0*0.8,s0*1.5),(-2,2),(i0/2,i0*2), (0,d0*1.2), (0,startNCases*1.2),\
              (0.3,0.8),(0.02,0.08)]
    maxiterations=500
    f=create_f(state,e0,a0,r0,date, ratio, predict_range, version)
    de = DE(f, bounds, maxiters=maxiterations)
    for step in de.geniterator():
        try:
            idx = step.best_idx
            norm_vector = step.population[idx]
            best_params = de.denormalize([norm_vector])
            del norm_vector, idx
        except:
            print("error in function evaluation")
    p=best_params[0]
    del f, bounds, data, dead,best_params
    
    return p

# %% [markdown]
# # Main Code

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines){
#     return true;}

# %%
states=dfparam.state
display(states)
allStates=True
version="105"
gc.enable()

optimal=[]
if allStates:
    for state in states:
        #remove previous history file
        strFile='./results/history_'+state+version+'.csv'
        if os.path.isfile(strFile):
            os.remove(strFile)
        query = dfparam.query('state == "{}"'.format(state)).reset_index()
        parameters = np.array(query.iloc[:, 2:])[0]
        date,predict_range,s0,e0,a0,i0,r0,d0,startNCases,ratio,wcases,wrec = parameters
        optimal.append(opt.remote(state,s0,i0,e0,a0,r0,d0,wcases,date,startNCases, ratio, predict_range, version))        
else:
    state = "ES" 
    #remove previous history file
    strFile='./results/history_'+state+version+'.csv'
    if os.path.isfile(strFile):
        os.remove(strFile)
    query = dfparam.query('state == "{}"'.format(state)).reset_index()
    parameters = np.array(query.iloc[:, 2:])[0]
    start_date,predict_range,s0,e0,a0,i0,r0,d0,startNCases,ratio,wcases,wrec = parameters
    optimal.append(opt.remote(state,s0,i0,e0,a0,r0,d0,wcasesdate,startNCases, ratio, predict_range, version))
# Out:
# 0     SP
# 1     ES
# 2     MG
# 3     RJ
# 4     CE
# 5     PE
# 6     AM
# 7     PA
# 8     PI
# 9     RR
# 10    AP
# Name: state, dtype: object

# %%
optimal=ray.get(optimal)
# Out:
# 2020-07-18 18:55:36,811	WARNING worker.py:1090 -- WARNING: 30 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=5829) basinhopping step 0: f 1.47627e+09
# (pid=5832) basinhopping step 0: f 2.7137e+08
# (pid=5832) basinhopping step 1: f 2.68011e+08 trial_f 2.68011e+08 accepted 1  lowest_f 2.68011e+08
# (pid=5832) found new global minimum on step 1 with function value 2.68011e+08
# (pid=5934) basinhopping step 0: f 8.7781e+07
# (pid=5836) warning: basinhopping: local minimization failure
# (pid=5836) basinhopping step 0: f 2.02186e+07
# (pid=5829) basinhopping step 1: f 1.46607e+09 trial_f 1.46607e+09 accepted 1  lowest_f 1.46607e+09
# (pid=5829) found new global minimum on step 1 with function value 1.46607e+09
# (pid=5832) basinhopping step 2: f 1.77724e+08 trial_f 1.77724e+08 accepted 1  lowest_f 1.77724e+08
# (pid=5832) found new global minimum on step 2 with function value 1.77724e+08
# (pid=5833) basinhopping step 0: f -3.07893e+11
# (pid=5828) basinhopping step 0: f -3.89322e+13
# (pid=5831) basinhopping step 0: f -5.35304e+11
# (pid=5829) basinhopping step 2: f 1.46607e+09 trial_f 1.87557e+09 accepted 0  lowest_f 1.46607e+09
# (pid=5828) basinhopping step 1: f -3.89322e+13 trial_f 1.04559e+10 accepted 0  lowest_f -3.89322e+13
# (pid=5831) basinhopping step 1: f -5.35304e+11 trial_f 5.33261e+08 accepted 0  lowest_f -5.35304e+11
# (pid=5828) basinhopping step 2: f -3.89322e+13 trial_f 1.09584e+10 accepted 0  lowest_f -3.89322e+13
# (pid=5836) warning: basinhopping: local minimization failure
# (pid=5836) basinhopping step 1: f 2.02186e+07 trial_f 2.27792e+07 accepted 0  lowest_f 2.02186e+07
# (pid=5831) basinhopping step 2: f -5.35304e+11 trial_f 9.47141e+09 accepted 0  lowest_f -5.35304e+11
# (pid=5829) basinhopping step 3: f 6.18079e+08 trial_f 6.18079e+08 accepted 1  lowest_f 6.18079e+08
# (pid=5829) found new global minimum on step 3 with function value 6.18079e+08
# (pid=5934) basinhopping step 1: f 8.7781e+07 trial_f 3.38457e+08 accepted 0  lowest_f 8.7781e+07
# (pid=5830) basinhopping step 0: f -8.18251e+11
# (pid=5827) basinhopping step 0: f -9.88506e+10
# (pid=5934) basinhopping step 2: f 8.7781e+07 trial_f 6.48358e+09 accepted 0  lowest_f 8.7781e+07
# (pid=5835) basinhopping step 0: f -3.7939e+11
# (pid=5934) basinhopping step 3: f 8.7781e+07 trial_f 2.351e+11 accepted 0  lowest_f 8.7781e+07
# (pid=5834) basinhopping step 0: f -5.65018e+11
# (pid=5830) basinhopping step 1: f -8.18251e+11 trial_f 1.77447e+10 accepted 0  lowest_f -8.18251e+11
# (pid=5828) basinhopping step 3: f -4.28285e+13 trial_f -4.28285e+13 accepted 1  lowest_f -4.28285e+13
# (pid=5828) found new global minimum on step 3 with function value -4.28285e+13
# (pid=5827) basinhopping step 1: f -1.11673e+11 trial_f -1.11673e+11 accepted 1  lowest_f -1.11673e+11
# (pid=5827) found new global minimum on step 1 with function value -1.11673e+11
# (pid=5831) warning: basinhopping: local minimization failure
# (pid=5831) basinhopping step 3: f -5.35304e+11 trial_f 5.33172e+08 accepted 0  lowest_f -5.35304e+11
# (pid=5836) basinhopping step 2: f 2.02186e+07 trial_f 1.20314e+09 accepted 0  lowest_f 2.02186e+07
# (pid=5830) basinhopping step 2: f -8.18251e+11 trial_f 8.45547e+09 accepted 0  lowest_f -8.18251e+11
# (pid=5828) basinhopping step 4: f -4.28285e+13 trial_f 5.81667e+11 accepted 0  lowest_f -4.28285e+13
# (pid=5827) basinhopping step 2: f -1.11673e+11 trial_f 1.44918e+08 accepted 0  lowest_f -1.11673e+11
# (pid=5829) basinhopping step 4: f 6.17754e+08 trial_f 6.17754e+08 accepted 1  lowest_f 6.17754e+08
# (pid=5829) found new global minimum on step 4 with function value 6.17754e+08
# (pid=5834) basinhopping step 1: f -5.65018e+11 trial_f 2.04021e+09 accepted 0  lowest_f -5.65018e+11
# (pid=5835) basinhopping step 1: f -3.7939e+11 trial_f 1.87355e+10 accepted 0  lowest_f -3.7939e+11
# (pid=5831) basinhopping step 4: f -5.35304e+11 trial_f 3.41296e+08 accepted 0  lowest_f -5.35304e+11
# (pid=5828) basinhopping step 5: f -4.28285e+13 trial_f 1.09203e+10 accepted 0  lowest_f -4.28285e+13
# (pid=5832) basinhopping step 3: f 1.77724e+08 trial_f 2.86498e+08 accepted 0  lowest_f 1.77724e+08
# (pid=5832) basinhopping step 4: f 1.77724e+08 trial_f 8.04225e+11 accepted 0  lowest_f 1.77724e+08
# (pid=5827) basinhopping step 3: f -1.11673e+11 trial_f 2.56835e+10 accepted 0  lowest_f -1.11673e+11
# (pid=5833) basinhopping step 1: f -7.18683e+11 trial_f -7.18683e+11 accepted 1  lowest_f -7.18683e+11
# (pid=5833) found new global minimum on step 1 with function value -7.18683e+11
# (pid=5834) basinhopping step 2: f -5.65018e+11 trial_f 3.13073e+09 accepted 0  lowest_f -5.65018e+11
# (pid=5829) basinhopping step 5: f 6.17754e+08 trial_f 9.2746e+09 accepted 0  lowest_f 6.17754e+08
# (pid=5829) basinhopping step 6: f 6.17754e+08 trial_f 1.47627e+09 accepted 0  lowest_f 6.17754e+08
# (pid=5830) basinhopping step 3: f -8.18251e+11 trial_f -6.8629e+09 accepted 0  lowest_f -8.18251e+11
# (pid=5831) basinhopping step 5: f -5.35304e+11 trial_f 3.42548e+08 accepted 0  lowest_f -5.35304e+11
# (pid=5934) basinhopping step 4: f 4.70876e+06 trial_f 4.70876e+06 accepted 1  lowest_f 4.70876e+06
# (pid=5934) found new global minimum on step 4 with function value 4.70876e+06
# (pid=5835) basinhopping step 2: f -3.7939e+11 trial_f 9.40882e+07 accepted 0  lowest_f -3.7939e+11
# (pid=5934) basinhopping step 5: f -1.99568e+11 trial_f -1.99568e+11 accepted 1  lowest_f -1.99568e+11
# (pid=5934) found new global minimum on step 5 with function value -1.99568e+11
# (pid=5934) basinhopping step 6: f -1.99568e+11 trial_f 6.4528e+09 accepted 0  lowest_f -1.99568e+11
# (pid=5828) basinhopping step 6: f -4.28285e+13 trial_f 3.28253e+10 accepted 0  lowest_f -4.28285e+13
# (pid=5827) basinhopping step 4: f -1.12213e+11 trial_f -1.12213e+11 accepted 1  lowest_f -1.12213e+11
# (pid=5827) found new global minimum on step 4 with function value -1.12213e+11
# (pid=5835) basinhopping step 3: f -3.7939e+11 trial_f 8.27332e+09 accepted 0  lowest_f -3.7939e+11
# (pid=5831) basinhopping step 6: f -5.35304e+11 trial_f 3.68407e+07 accepted 0  lowest_f -5.35304e+11
# (pid=5827) basinhopping step 5: f -1.12213e+11 trial_f 1.86779e+09 accepted 0  lowest_f -1.12213e+11
# (pid=5833) basinhopping step 2: f -7.18683e+11 trial_f 5.31495e+09 accepted 0  lowest_f -7.18683e+11
# (pid=5836) basinhopping step 3: f -1.53104e+09 trial_f -1.53104e+09 accepted 1  lowest_f -1.53104e+09
# (pid=5836) found new global minimum on step 3 with function value -1.53104e+09
# (pid=5833) basinhopping step 3: f -7.18683e+11 trial_f 1.35429e+09 accepted 0  lowest_f -7.18683e+11
# (pid=5834) basinhopping step 3: f -7.19078e+11 trial_f -7.19078e+11 accepted 1  lowest_f -7.19078e+11
# (pid=5834) found new global minimum on step 3 with function value -7.19078e+11
# (pid=5836) basinhopping step 4: f -1.53104e+09 trial_f 2.0105e+07 accepted 0  lowest_f -1.53104e+09
# (pid=5827) basinhopping step 6: f -1.12213e+11 trial_f 4.87074e+08 accepted 0  lowest_f -1.12213e+11
# (pid=5831) basinhopping step 7: f -5.35304e+11 trial_f 8.29635e+09 accepted 0  lowest_f -5.35304e+11
# (pid=5832) basinhopping step 5: f 1.77724e+08 trial_f 5.73536e+08 accepted 0  lowest_f 1.77724e+08
# (pid=5832) basinhopping step 6: f 1.77724e+08 trial_f 2.81033e+08 accepted 0  lowest_f 1.77724e+08
# (pid=5833) basinhopping step 4: f -7.18683e+11 trial_f 7.54249e+09 accepted 0  lowest_f -7.18683e+11
# (pid=5836) basinhopping step 5: f -1.53104e+09 trial_f 2.95781e+11 accepted 0  lowest_f -1.53104e+09
# (pid=5830) basinhopping step 4: f -8.18251e+11 trial_f 5.52266e+08 accepted 0  lowest_f -8.18251e+11
# (pid=5827) basinhopping step 7: f -1.12213e+11 trial_f 4.48749e+08 accepted 0  lowest_f -1.12213e+11
# (pid=5832) basinhopping step 7: f 1.77724e+08 trial_f 7.55876e+08 accepted 0  lowest_f 1.77724e+08
# (pid=5827) basinhopping step 8: f -1.12213e+11 trial_f -2.52117e+08 accepted 0  lowest_f -1.12213e+11
# (pid=5835) basinhopping step 4: f -3.7939e+11 trial_f 1.92357e+09 accepted 0  lowest_f -3.7939e+11
# (pid=5835) basinhopping step 5: f -3.7939e+11 trial_f 1.89079e+11 accepted 0  lowest_f -3.7939e+11
# (pid=5832) warning: basinhopping: local minimization failure
# (pid=5832) basinhopping step 8: f 1.77724e+08 trial_f 2.7137e+08 accepted 0  lowest_f 1.77724e+08
# (pid=5834) basinhopping step 4: f -7.19078e+11 trial_f -3.45192e+11 accepted 0  lowest_f -7.19078e+11
# (pid=5831) basinhopping step 8: f -5.35304e+11 trial_f 9.44599e+09 accepted 0  lowest_f -5.35304e+11
# (pid=5829) basinhopping step 7: f 3.24229e+08 trial_f 3.24229e+08 accepted 1  lowest_f 3.24229e+08
# (pid=5829) found new global minimum on step 7 with function value 3.24229e+08
# (pid=5832) /home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
# (pid=5832)   warnings.warn(warning_msg, ODEintWarning)
# (pid=5833) basinhopping step 5: f -7.18683e+11 trial_f 1.53133e+09 accepted 0  lowest_f -7.18683e+11
# (pid=5831) basinhopping step 9: f -5.35304e+11 trial_f 5.33251e+08 accepted 0  lowest_f -5.35304e+11
# (pid=5831) basinhopping step 10: f -5.35304e+11 trial_f 5.41312e+08 accepted 0  lowest_f -5.35304e+11
# (pid=5829) basinhopping step 8: f -1.3157e+11 trial_f -1.3157e+11 accepted 1  lowest_f -1.3157e+11
# (pid=5829) found new global minimum on step 8 with function value -1.3157e+11
# (pid=5835) basinhopping step 6: f -3.7939e+11 trial_f 4.55827e+10 accepted 0  lowest_f -3.7939e+11
# (pid=5836) basinhopping step 6: f -1.53104e+09 trial_f 1.98939e+08 accepted 0  lowest_f -1.53104e+09
# (pid=5828) basinhopping step 7: f -4.28285e+13 trial_f -7.64114e+11 accepted 0  lowest_f -4.28285e+13
# (pid=5835) basinhopping step 7: f -3.7939e+11 trial_f 4.44975e+08 accepted 0  lowest_f -3.7939e+11
# (pid=5934) basinhopping step 7: f -1.99568e+11 trial_f -1.9556e+11 accepted 0  lowest_f -1.99568e+11
# (pid=5832) basinhopping step 9: f 1.77724e+08 trial_f 5.20334e+10 accepted 0  lowest_f 1.77724e+08
# (pid=5833) basinhopping step 6: f -7.18683e+11 trial_f 1.35952e+09 accepted 0  lowest_f -7.18683e+11
# (pid=5936) basinhopping step 0: f 3.18571e+07
# (pid=5832) basinhopping step 10: f 1.77724e+08 trial_f 2.77237e+08 accepted 0  lowest_f 1.77724e+08
# (pid=5828) basinhopping step 8: f -4.28285e+13 trial_f 5.95886e+11 accepted 0  lowest_f -4.28285e+13
# (pid=5828) basinhopping step 9: f -4.28285e+13 trial_f 1.09158e+10 accepted 0  lowest_f -4.28285e+13
# (pid=5828) /home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
# (pid=5828)   warnings.warn(warning_msg, ODEintWarning)
# (pid=5834) basinhopping step 5: f -7.19078e+11 trial_f -2.94848e+11 accepted 0  lowest_f -7.19078e+11
# (pid=5835) basinhopping step 8: f -3.7939e+11 trial_f 8.1395e+09 accepted 0  lowest_f -3.7939e+11
# (pid=5834) basinhopping step 6: f -7.19078e+11 trial_f -5.4099e+11 accepted 0  lowest_f -7.19078e+11
# (pid=5827) basinhopping step 9: f -1.12213e+11 trial_f -1.01263e+11 accepted 0  lowest_f -1.12213e+11
# (pid=5829) basinhopping step 9: f -1.3157e+11 trial_f 1.66364e+09 accepted 0  lowest_f -1.3157e+11
# (pid=5835) basinhopping step 9: f -3.7939e+11 trial_f 1.14549e+08 accepted 0  lowest_f -3.7939e+11
# (pid=5828) basinhopping step 10: f -4.28285e+13 trial_f 7.05125e+11 accepted 0  lowest_f -4.28285e+13
# (pid=5833) basinhopping step 7: f -7.18683e+11 trial_f 9.77587e+09 accepted 0  lowest_f -7.18683e+11
# (pid=5934) basinhopping step 8: f -1.99568e+11 trial_f -1.52357e+09 accepted 0  lowest_f -1.99568e+11
# (pid=5936) basinhopping step 1: f 3.18571e+07 trial_f 9.97279e+09 accepted 0  lowest_f 3.18571e+07
# (pid=5829) warning: basinhopping: local minimization failure
# (pid=5829) basinhopping step 10: f -4.80813e+11 trial_f -4.80813e+11 accepted 1  lowest_f -4.80813e+11
# (pid=5829) found new global minimum on step 10 with function value -4.80813e+11
# (pid=5834) basinhopping step 7: f -7.19078e+11 trial_f 6.64776e+09 accepted 0  lowest_f -7.19078e+11
# (pid=5833) basinhopping step 8: f -7.18683e+11 trial_f 1.56886e+09 accepted 0  lowest_f -7.18683e+11
# (pid=5894) basinhopping step 0: f -7.04051e+13
# (pid=5835) basinhopping step 10: f -3.7939e+11 trial_f 4.55931e+10 accepted 0  lowest_f -3.7939e+11
# (pid=5934) basinhopping step 9: f -1.99568e+11 trial_f 6.42697e+09 accepted 0  lowest_f -1.99568e+11
# (pid=5884) basinhopping step 0: f 1.07358e+08
# (pid=5884) basinhopping step 1: f 1.07358e+08 trial_f 1.41769e+08 accepted 0  lowest_f 1.07358e+08
# (pid=5834) basinhopping step 8: f -7.19078e+11 trial_f 6.89059e+09 accepted 0  lowest_f -7.19078e+11
# (pid=5836) warning: basinhopping: local minimization failure
# (pid=5836) basinhopping step 7: f -1.53104e+09 trial_f 1.96023e+07 accepted 0  lowest_f -1.53104e+09
# (pid=5836) basinhopping step 8: f -1.53104e+09 trial_f 2.01018e+07 accepted 0  lowest_f -1.53104e+09
# (pid=5888) basinhopping step 0: f -3.07869e+11
# (pid=5830) basinhopping step 5: f -8.18251e+11 trial_f 4.05048e+08 accepted 0  lowest_f -8.18251e+11
# (pid=5936) basinhopping step 2: f 3.18571e+07 trial_f 7.39347e+08 accepted 0  lowest_f 3.18571e+07
# (pid=5931) basinhopping step 0: f -6.16079e+11
# (pid=5884) basinhopping step 2: f 1.0705e+08 trial_f 1.0705e+08 accepted 1  lowest_f 1.0705e+08
# (pid=5884) found new global minimum on step 2 with function value 1.0705e+08
# (pid=5834) basinhopping step 9: f -7.19078e+11 trial_f -4.40257e+11 accepted 0  lowest_f -7.19078e+11
# (pid=5934) basinhopping step 10: f -1.99568e+11 trial_f 6.44647e+09 accepted 0  lowest_f -1.99568e+11
# (pid=5834) basinhopping step 10: f -7.19078e+11 trial_f 7.56016e+08 accepted 0  lowest_f -7.19078e+11
# (pid=5833) basinhopping step 9: f -7.18683e+11 trial_f 1.53947e+09 accepted 0  lowest_f -7.18683e+11
# (pid=5836) basinhopping step 9: f -1.53104e+09 trial_f 1.99851e+07 accepted 0  lowest_f -1.53104e+09
# (pid=5896) basinhopping step 0: f 1.45676e+08
# (pid=5884) basinhopping step 3: f 1.0705e+08 trial_f 3.43787e+10 accepted 0  lowest_f 1.0705e+08
# (pid=5830) basinhopping step 6: f -8.18251e+11 trial_f 8.29814e+09 accepted 0  lowest_f -8.18251e+11
# (pid=5830) basinhopping step 7: f -8.18251e+11 trial_f 4.36591e+08 accepted 0  lowest_f -8.18251e+11
# (pid=5827) warning: basinhopping: local minimization failure
# (pid=5827) basinhopping step 10: f -1.70317e+11 trial_f -1.70317e+11 accepted 1  lowest_f -1.70317e+11
# (pid=5827) found new global minimum on step 10 with function value -1.70317e+11
# (pid=5931) basinhopping step 1: f -6.16079e+11 trial_f 1.39722e+10 accepted 0  lowest_f -6.16079e+11
# (pid=5884) basinhopping step 4: f 1.07013e+08 trial_f 1.07013e+08 accepted 1  lowest_f 1.07013e+08
# (pid=5884) found new global minimum on step 4 with function value 1.07013e+08
# (pid=5931) basinhopping step 2: f -6.16079e+11 trial_f 5.43681e+11 accepted 0  lowest_f -6.16079e+11
# (pid=5888) basinhopping step 1: f -3.07869e+11 trial_f 7.67971e+08 accepted 0  lowest_f -3.07869e+11
# (pid=5936) basinhopping step 3: f 3.18571e+07 trial_f 9.58196e+09 accepted 0  lowest_f 3.18571e+07
# (pid=5836) basinhopping step 10: f -1.53104e+09 trial_f 2.02186e+07 accepted 0  lowest_f -1.53104e+09
# (pid=5884) basinhopping step 5: f 1.05968e+08 trial_f 1.05968e+08 accepted 1  lowest_f 1.05968e+08
# (pid=5884) found new global minimum on step 5 with function value 1.05968e+08
# (pid=6089) basinhopping step 0: f 3.85454e+07
# (pid=5833) basinhopping step 10: f -7.18683e+11 trial_f 4.23714e+10 accepted 0  lowest_f -7.18683e+11
# (pid=5931) basinhopping step 3: f -6.16079e+11 trial_f 1.36624e+10 accepted 0  lowest_f -6.16079e+11
# (pid=5896) basinhopping step 1: f 1.45676e+08 trial_f 3.88559e+09 accepted 0  lowest_f 1.45676e+08
# (pid=5936) basinhopping step 4: f 3.18571e+07 trial_f 5.63172e+08 accepted 0  lowest_f 3.18571e+07
# (pid=5896) basinhopping step 2: f 1.45676e+08 trial_f 1.26915e+11 accepted 0  lowest_f 1.45676e+08
# (pid=5931) basinhopping step 4: f -6.16079e+11 trial_f 1.17211e+09 accepted 0  lowest_f -6.16079e+11
# (pid=5884) basinhopping step 6: f 1.05968e+08 trial_f 1.4818e+09 accepted 0  lowest_f 1.05968e+08
# (pid=5894) basinhopping step 1: f -7.04051e+13 trial_f 5.53404e+09 accepted 0  lowest_f -7.04051e+13
# (pid=5936) basinhopping step 5: f 3.18571e+07 trial_f 5.62938e+08 accepted 0  lowest_f 3.18571e+07
# (pid=5896) basinhopping step 3: f 1.45676e+08 trial_f 5.0934e+08 accepted 0  lowest_f 1.45676e+08
# (pid=6089) basinhopping step 1: f 3.85454e+07 trial_f 8.54446e+09 accepted 0  lowest_f 3.85454e+07
# (pid=5891) basinhopping step 0: f -1.85279e+11
# (pid=5888) basinhopping step 2: f -3.07869e+11 trial_f 7.64095e+08 accepted 0  lowest_f -3.07869e+11
# (pid=5896) basinhopping step 4: f 1.45676e+08 trial_f 1.83273e+10 accepted 0  lowest_f 1.45676e+08
# (pid=5888) basinhopping step 3: f -3.07869e+11 trial_f 6.21362e+08 accepted 0  lowest_f -3.07869e+11
# (pid=5937) basinhopping step 0: f 4.67735e+08
# (pid=5891) basinhopping step 1: f -1.85279e+11 trial_f 1.91131e+08 accepted 0  lowest_f -1.85279e+11
# (pid=6089) basinhopping step 2: f 3.85454e+07 trial_f 8.67526e+09 accepted 0  lowest_f 3.85454e+07
# (pid=5931) warning: basinhopping: local minimization failure
# (pid=5931) basinhopping step 5: f -6.16079e+11 trial_f 6.18389e+08 accepted 0  lowest_f -6.16079e+11
# (pid=5894) basinhopping step 2: f -7.04051e+13 trial_f 6.41446e+11 accepted 0  lowest_f -7.04051e+13
# (pid=5936) basinhopping step 6: f 3.18571e+07 trial_f 7.74976e+09 accepted 0  lowest_f 3.18571e+07
# (pid=5894) /home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
# (pid=5894)   warnings.warn(warning_msg, ODEintWarning)
# (pid=6102) basinhopping step 0: f 4.00848e+08
# (pid=6089) basinhopping step 3: f 3.84512e+07 trial_f 3.84512e+07 accepted 1  lowest_f 3.84512e+07
# (pid=6089) found new global minimum on step 3 with function value 3.84512e+07
# (pid=6102) basinhopping step 1: f 4.00848e+08 trial_f 1.41386e+11 accepted 0  lowest_f 4.00848e+08
# (pid=5888) basinhopping step 4: f -3.07869e+11 trial_f 1.13055e+11 accepted 0  lowest_f -3.07869e+11
# (pid=5891) basinhopping step 2: f -1.85279e+11 trial_f 2.29914e+08 accepted 0  lowest_f -1.85279e+11
# (pid=5830) basinhopping step 8: f -8.18251e+11 trial_f 5.3558e+08 accepted 0  lowest_f -8.18251e+11
# (pid=5888) /home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
# (pid=5888)   warnings.warn(warning_msg, ODEintWarning)
# (pid=5936) basinhopping step 7: f 3.18571e+07 trial_f 9.5793e+09 accepted 0  lowest_f 3.18571e+07
# (pid=5891) basinhopping step 3: f -1.85279e+11 trial_f 1.90358e+08 accepted 0  lowest_f -1.85279e+11
# (pid=5896) basinhopping step 5: f 1.42402e+08 trial_f 1.42402e+08 accepted 1  lowest_f 1.42402e+08
# (pid=5896) found new global minimum on step 5 with function value 1.42402e+08
# (pid=5884) basinhopping step 7: f 1.05968e+08 trial_f 3.52847e+08 accepted 0  lowest_f 1.05968e+08
# (pid=5936) basinhopping step 8: f 3.18571e+07 trial_f 9.90765e+09 accepted 0  lowest_f 3.18571e+07
# (pid=5884) basinhopping step 8: f 1.05968e+08 trial_f 1.07358e+08 accepted 0  lowest_f 1.05968e+08
# (pid=5937) basinhopping step 1: f 4.67735e+08 trial_f 1.30695e+09 accepted 0  lowest_f 4.67735e+08
# (pid=5894) basinhopping step 3: f -7.04051e+13 trial_f -1.79998e+11 accepted 0  lowest_f -7.04051e+13
# (pid=6102) basinhopping step 2: f 4.00848e+08 trial_f 1.69384e+09 accepted 0  lowest_f 4.00848e+08
# (pid=5937) basinhopping step 2: f 4.67735e+08 trial_f 1.96189e+11 accepted 0  lowest_f 4.67735e+08
# (pid=5888) basinhopping step 5: f -3.07869e+11 trial_f 5.42777e+09 accepted 0  lowest_f -3.07869e+11
# (pid=6089) basinhopping step 4: f 3.84068e+07 trial_f 3.84068e+07 accepted 1  lowest_f 3.84068e+07
# (pid=6089) found new global minimum on step 4 with function value 3.84068e+07
# (pid=5931) basinhopping step 6: f -6.16079e+11 trial_f 1.20962e+09 accepted 0  lowest_f -6.16079e+11
# (pid=5891) basinhopping step 4: f -1.85279e+11 trial_f -8.4953e+10 accepted 0  lowest_f -1.85279e+11
# (pid=5937) basinhopping step 3: f 4.67735e+08 trial_f 6.63119e+09 accepted 0  lowest_f 4.67735e+08
# (pid=6102) basinhopping step 3: f 4.00848e+08 trial_f 4.87978e+09 accepted 0  lowest_f 4.00848e+08
# (pid=5896) basinhopping step 6: f 1.42402e+08 trial_f 2.91874e+08 accepted 0  lowest_f 1.42402e+08
# (pid=5894) basinhopping step 4: f -7.04051e+13 trial_f 6.68411e+11 accepted 0  lowest_f -7.04051e+13
# (pid=6089) basinhopping step 5: f 3.84068e+07 trial_f 2.02398e+10 accepted 0  lowest_f 3.84068e+07
# (pid=5884) basinhopping step 9: f 1.05968e+08 trial_f 4.08479e+08 accepted 0  lowest_f 1.05968e+08
# (pid=5830) basinhopping step 9: f -1.26481e+12 trial_f -1.26481e+12 accepted 1  lowest_f -1.26481e+12
# (pid=5830) found new global minimum on step 9 with function value -1.26481e+12
# (pid=5894) warning: basinhopping: local minimization failure
# (pid=5894) basinhopping step 5: f -7.04051e+13 trial_f 4.85006e+13 accepted 0  lowest_f -7.04051e+13
# (pid=5937) basinhopping step 4: f 4.67735e+08 trial_f 6.36794e+09 accepted 0  lowest_f 4.67735e+08
# (pid=5888) basinhopping step 6: f -3.07869e+11 trial_f 6.14084e+08 accepted 0  lowest_f -3.07869e+11
# (pid=5931) basinhopping step 7: f -6.16079e+11 trial_f 1.39464e+10 accepted 0  lowest_f -6.16079e+11
# (pid=5884) basinhopping step 10: f 1.05968e+08 trial_f 1.46735e+09 accepted 0  lowest_f 1.05968e+08
# (pid=5937) basinhopping step 5: f 4.67735e+08 trial_f 1.96194e+11 accepted 0  lowest_f 4.67735e+08
# (pid=5936) basinhopping step 9: f 3.18571e+07 trial_f 3.09994e+08 accepted 0  lowest_f 3.18571e+07
# (pid=5937) basinhopping step 6: f 4.67735e+08 trial_f 1.79747e+09 accepted 0  lowest_f 4.67735e+08
# (pid=5894) basinhopping step 6: f -7.04051e+13 trial_f 6.80591e+11 accepted 0  lowest_f -7.04051e+13
# (pid=6102) basinhopping step 4: f 4.00848e+08 trial_f 1.75937e+09 accepted 0  lowest_f 4.00848e+08
# (pid=5896) basinhopping step 7: f -2.22445e+11 trial_f -2.22445e+11 accepted 1  lowest_f -2.22445e+11
# (pid=5896) found new global minimum on step 7 with function value -2.22445e+11
# (pid=6115) basinhopping step 0: f 6.73116e+07
# (pid=6115) basinhopping step 1: f 6.72515e+07 trial_f 6.72515e+07 accepted 1  lowest_f 6.72515e+07
# (pid=6115) found new global minimum on step 1 with function value 6.72515e+07
# (pid=5937) basinhopping step 7: f 4.67735e+08 trial_f 1.95904e+09 accepted 0  lowest_f 4.67735e+08
# (pid=6115) basinhopping step 2: f 6.72515e+07 trial_f 5.21626e+11 accepted 0  lowest_f 6.72515e+07
# (pid=5830) basinhopping step 10: f -1.38826e+12 trial_f -1.38826e+12 accepted 1  lowest_f -1.38826e+12
# (pid=5830) found new global minimum on step 10 with function value -1.38826e+12
# (pid=5888) basinhopping step 7: f -3.07869e+11 trial_f 6.21932e+08 accepted 0  lowest_f -3.07869e+11
# (pid=5931) basinhopping step 8: f -6.16079e+11 trial_f 1.40142e+10 accepted 0  lowest_f -6.16079e+11
# (pid=5936) basinhopping step 10: f 3.18571e+07 trial_f 9.84317e+09 accepted 0  lowest_f 3.18571e+07
# (pid=5931) basinhopping step 9: f -6.16079e+11 trial_f 1.00207e+09 accepted 0  lowest_f -6.16079e+11
# (pid=5896) basinhopping step 8: f -2.22445e+11 trial_f 8.70527e+08 accepted 0  lowest_f -2.22445e+11
# (pid=5931) basinhopping step 10: f -6.16079e+11 trial_f -5.28795e+11 accepted 0  lowest_f -6.16079e+11
# (pid=6116) basinhopping step 0: f -7.05807e+11
# (pid=6141) basinhopping step 0: f 1.0244e+09
# (pid=6116) basinhopping step 1: f -7.05807e+11 trial_f 3.00837e+08 accepted 0  lowest_f -7.05807e+11
# (pid=6115) basinhopping step 3: f 6.72515e+07 trial_f 7.83619e+07 accepted 0  lowest_f 6.72515e+07
# (pid=5891) basinhopping step 5: f -1.85279e+11 trial_f 2.23225e+08 accepted 0  lowest_f -1.85279e+11
# (pid=5937) basinhopping step 8: f 4.67735e+08 trial_f 6.46737e+09 accepted 0  lowest_f 4.67735e+08
# (pid=5888) basinhopping step 8: f -3.07869e+11 trial_f 7.87044e+08 accepted 0  lowest_f -3.07869e+11
# (pid=5937) basinhopping step 9: f 4.67735e+08 trial_f 3.15285e+10 accepted 0  lowest_f 4.67735e+08
# (pid=5891) basinhopping step 6: f -1.85279e+11 trial_f 1.89643e+08 accepted 0  lowest_f -1.85279e+11
# (pid=5896) basinhopping step 9: f -2.22445e+11 trial_f 3.77936e+09 accepted 0  lowest_f -2.22445e+11
# (pid=6141) basinhopping step 1: f 3.38497e+07 trial_f 3.38497e+07 accepted 1  lowest_f 3.38497e+07
# (pid=6141) found new global minimum on step 1 with function value 3.38497e+07
# (pid=5896) basinhopping step 10: f -2.22445e+11 trial_f 1.26914e+11 accepted 0  lowest_f -2.22445e+11
# (pid=5888) basinhopping step 9: f -3.07869e+11 trial_f 7.82433e+08 accepted 0  lowest_f -3.07869e+11
# (pid=6167) basinhopping step 0: f 8.77085e+07
# (pid=5937) basinhopping step 10: f 4.67735e+08 trial_f 1.57644e+10 accepted 0  lowest_f 4.67735e+08
# (pid=6116) basinhopping step 2: f -7.05807e+11 trial_f -1.62043e+09 accepted 0  lowest_f -7.05807e+11
# (pid=6142) basinhopping step 0: f 1.24398e+08
# (pid=6141) basinhopping step 2: f 3.38497e+07 trial_f 6.14821e+09 accepted 0  lowest_f 3.38497e+07
# (pid=6142) basinhopping step 1: f 1.24398e+08 trial_f 5.2511e+09 accepted 0  lowest_f 1.24398e+08
# (pid=6167) basinhopping step 1: f 8.08131e+07 trial_f 8.08131e+07 accepted 1  lowest_f 8.08131e+07
# (pid=6167) found new global minimum on step 1 with function value 8.08131e+07
# (pid=5888) basinhopping step 10: f -3.07869e+11 trial_f 7.72573e+08 accepted 0  lowest_f -3.07869e+11
# (pid=5894) basinhopping step 7: f -7.04051e+13 trial_f -3.50671e+13 accepted 0  lowest_f -7.04051e+13
# (pid=5891) basinhopping step 7: f -1.85279e+11 trial_f 2.31173e+08 accepted 0  lowest_f -1.85279e+11
# (pid=6102) basinhopping step 5: f -3.96999e+11 trial_f -3.96999e+11 accepted 1  lowest_f -3.96999e+11
# (pid=6102) found new global minimum on step 5 with function value -3.96999e+11
# (pid=6141) basinhopping step 3: f 3.38497e+07 trial_f 4.50543e+08 accepted 0  lowest_f 3.38497e+07
# (pid=6102) basinhopping step 6: f -3.96999e+11 trial_f 1.41386e+11 accepted 0  lowest_f -3.96999e+11
# (pid=6089) basinhopping step 6: f -4.7209e+11 trial_f -4.7209e+11 accepted 1  lowest_f -4.7209e+11
# (pid=6089) found new global minimum on step 6 with function value -4.7209e+11
# (pid=6142) basinhopping step 2: f 1.24398e+08 trial_f 2.21487e+08 accepted 0  lowest_f 1.24398e+08
# (pid=5891) basinhopping step 8: f -1.85279e+11 trial_f -8.93278e+10 accepted 0  lowest_f -1.85279e+11
# (pid=6141) basinhopping step 4: f 3.38497e+07 trial_f 6.10044e+09 accepted 0  lowest_f 3.38497e+07
# (pid=5891) basinhopping step 9: f -1.85279e+11 trial_f 1.38474e+09 accepted 0  lowest_f -1.85279e+11
# (pid=6141) basinhopping step 5: f 3.38497e+07 trial_f 1.16855e+09 accepted 0  lowest_f 3.38497e+07
# (pid=6168) basinhopping step 0: f 1.41689e+08
# (pid=6089) basinhopping step 7: f -4.7209e+11 trial_f 3.8229e+07 accepted 0  lowest_f -4.7209e+11
# (pid=6102) basinhopping step 7: f -3.96999e+11 trial_f 4.99717e+09 accepted 0  lowest_f -3.96999e+11
# (pid=6168) basinhopping step 1: f 1.41689e+08 trial_f 1.46845e+09 accepted 0  lowest_f 1.41689e+08
# (pid=6141) basinhopping step 6: f 3.38497e+07 trial_f 1.02148e+09 accepted 0  lowest_f 3.38497e+07
# (pid=6089) warning: basinhopping: local minimization failure
# (pid=6089) basinhopping step 8: f -4.7209e+11 trial_f 4.34317e+11 accepted 0  lowest_f -4.7209e+11
# (pid=6168) basinhopping step 2: f 1.41689e+08 trial_f 2.07076e+11 accepted 0  lowest_f 1.41689e+08
# (pid=5891) basinhopping step 10: f -1.85279e+11 trial_f 2.3228e+08 accepted 0  lowest_f -1.85279e+11
# (pid=6102) basinhopping step 8: f -3.96999e+11 trial_f 4.83403e+09 accepted 0  lowest_f -3.96999e+11
# (pid=6141) basinhopping step 7: f 3.38497e+07 trial_f 1.16275e+09 accepted 0  lowest_f 3.38497e+07
# (pid=6115) basinhopping step 4: f 6.13947e+07 trial_f 6.13947e+07 accepted 1  lowest_f 6.13947e+07
# (pid=6115) found new global minimum on step 4 with function value 6.13947e+07
# (pid=6142) basinhopping step 3: f 1.24398e+08 trial_f 1.00633e+09 accepted 0  lowest_f 1.24398e+08
# (pid=6115) basinhopping step 5: f 6.13947e+07 trial_f 6.73115e+07 accepted 0  lowest_f 6.13947e+07
# (pid=6193) basinhopping step 0: f -4.34893e+11
# (pid=6102) basinhopping step 9: f -3.96999e+11 trial_f 2.41935e+10 accepted 0  lowest_f -3.96999e+11
# (pid=6115) basinhopping step 6: f 6.13947e+07 trial_f 5.2163e+11 accepted 0  lowest_f 6.13947e+07
# (pid=6142) basinhopping step 4: f 1.24398e+08 trial_f 5.38577e+09 accepted 0  lowest_f 1.24398e+08
# (pid=6167) /home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
# (pid=6167)   warnings.warn(warning_msg, ODEintWarning)
# (pid=6116) basinhopping step 3: f -2.27388e+12 trial_f -2.27388e+12 accepted 1  lowest_f -2.27388e+12
# (pid=6116) found new global minimum on step 3 with function value -2.27388e+12
# (pid=6089) basinhopping step 9: f -4.7209e+11 trial_f 8.81145e+09 accepted 0  lowest_f -4.7209e+11
# (pid=6207) basinhopping step 0: f 1.86767e+07
# (pid=6193) basinhopping step 1: f -1.16584e+12 trial_f -1.16584e+12 accepted 1  lowest_f -1.16584e+12
# (pid=6193) found new global minimum on step 1 with function value -1.16584e+12
# (pid=6142) basinhopping step 5: f 1.24398e+08 trial_f 4.91954e+09 accepted 0  lowest_f 1.24398e+08
# (pid=6115) basinhopping step 7: f 6.13947e+07 trial_f 2.09829e+09 accepted 0  lowest_f 6.13947e+07
# (pid=6115) basinhopping step 8: f 6.13947e+07 trial_f 7.8362e+07 accepted 0  lowest_f 6.13947e+07
# (pid=6089) basinhopping step 10: f -4.7209e+11 trial_f 4.03616e+11 accepted 0  lowest_f -4.7209e+11
# (pid=6167) basinhopping step 2: f 8.08131e+07 trial_f 8.14812e+07 accepted 0  lowest_f 8.08131e+07
# (pid=5894) basinhopping step 8: f -7.04051e+13 trial_f -3.53051e+12 accepted 0  lowest_f -7.04051e+13
# (pid=6142) basinhopping step 6: f 1.24398e+08 trial_f 1.11666e+09 accepted 0  lowest_f 1.24398e+08
# (pid=6208) basinhopping step 0: f 2.44752e+07
# (pid=6193) basinhopping step 2: f -1.16584e+12 trial_f 8.17879e+09 accepted 0  lowest_f -1.16584e+12
# (pid=5894) basinhopping step 9: f -1.04306e+14 trial_f -1.04306e+14 accepted 1  lowest_f -1.04306e+14
# (pid=5894) found new global minimum on step 9 with function value -1.04306e+14
# (pid=6142) basinhopping step 7: f 1.24398e+08 trial_f 9.66177e+08 accepted 0  lowest_f 1.24398e+08
# (pid=6167) basinhopping step 3: f 8.08131e+07 trial_f 4.86789e+09 accepted 0  lowest_f 8.08131e+07
# (pid=6207) basinhopping step 1: f 1.86767e+07 trial_f 1.07899e+10 accepted 0  lowest_f 1.86767e+07
# (pid=6167) basinhopping step 4: f 8.08131e+07 trial_f 4.44824e+11 accepted 0  lowest_f 8.08131e+07
# (pid=6208) basinhopping step 1: f 2.48229e+06 trial_f 2.48229e+06 accepted 1  lowest_f 2.48229e+06
# (pid=6208) found new global minimum on step 1 with function value 2.48229e+06
# (pid=6167) basinhopping step 5: f 8.08131e+07 trial_f 8.77085e+07 accepted 0  lowest_f 8.08131e+07
# (pid=6168) warning: basinhopping: local minimization failure
# (pid=6168) basinhopping step 3: f 1.41689e+08 trial_f 6.22206e+08 accepted 0  lowest_f 1.41689e+08
# (pid=6116) basinhopping step 4: f -2.27388e+12 trial_f -6.62754e+09 accepted 0  lowest_f -2.27388e+12
# (pid=6208) basinhopping step 2: f -1.39676e+12 trial_f -1.39676e+12 accepted 1  lowest_f -1.39676e+12
# (pid=6208) found new global minimum on step 2 with function value -1.39676e+12
# (pid=6193) basinhopping step 3: f -1.16584e+12 trial_f 2.47089e+09 accepted 0  lowest_f -1.16584e+12
# (pid=6141) basinhopping step 8: f -1.02092e+10 trial_f -1.02092e+10 accepted 1  lowest_f -1.02092e+10
# (pid=6141) found new global minimum on step 8 with function value -1.02092e+10
# (pid=6102) basinhopping step 10: f -3.96999e+11 trial_f 1.66924e+09 accepted 0  lowest_f -3.96999e+11
# (pid=6168) basinhopping step 4: f 1.41689e+08 trial_f 1.52709e+09 accepted 0  lowest_f 1.41689e+08
# (pid=6167) basinhopping step 6: f 8.08131e+07 trial_f 4.07455e+08 accepted 0  lowest_f 8.08131e+07
# (pid=6193) basinhopping step 4: f -1.16584e+12 trial_f 8.26933e+09 accepted 0  lowest_f -1.16584e+12
# (pid=6167) basinhopping step 7: f 8.08131e+07 trial_f 4.44815e+11 accepted 0  lowest_f 8.08131e+07
# (pid=6115) basinhopping step 9: f 6.13947e+07 trial_f 6.44352e+07 accepted 0  lowest_f 6.13947e+07
# (pid=5894) basinhopping step 10: f -1.04306e+14 trial_f 1.59506e+11 accepted 0  lowest_f -1.04306e+14
# (pid=6141) basinhopping step 9: f -1.02092e+10 trial_f 4.55019e+08 accepted 0  lowest_f -1.02092e+10
# (pid=6193) basinhopping step 5: f -1.16584e+12 trial_f 7.84888e+09 accepted 0  lowest_f -1.16584e+12
# (pid=6168) basinhopping step 5: f 1.41689e+08 trial_f 1.64782e+09 accepted 0  lowest_f 1.41689e+08
# (pid=6237) basinhopping step 0: f -3.18103e+11
# (pid=6208) basinhopping step 3: f -1.39676e+12 trial_f 3.42821e+09 accepted 0  lowest_f -1.39676e+12
# (pid=6251) basinhopping step 0: f -4.20084e+13
# (pid=6167) basinhopping step 8: f 8.08131e+07 trial_f 2.86085e+08 accepted 0  lowest_f 8.08131e+07
# (pid=6115) basinhopping step 10: f 6.13947e+07 trial_f 2.76212e+09 accepted 0  lowest_f 6.13947e+07
# (pid=6207) basinhopping step 2: f -9.41942e+10 trial_f -9.41942e+10 accepted 1  lowest_f -9.41942e+10
# (pid=6207) found new global minimum on step 2 with function value -9.41942e+10
# (pid=6116) basinhopping step 5: f -2.27388e+12 trial_f 7.56444e+08 accepted 0  lowest_f -2.27388e+12
# (pid=6167) basinhopping step 9: f 8.08131e+07 trial_f 2.56583e+10 accepted 0  lowest_f 8.08131e+07
# (pid=6168) basinhopping step 6: f 1.41689e+08 trial_f 2.94692e+10 accepted 0  lowest_f 1.41689e+08
# (pid=6193) basinhopping step 6: f -1.16584e+12 trial_f 5.04968e+08 accepted 0  lowest_f -1.16584e+12
# (pid=6207) basinhopping step 3: f -9.41942e+10 trial_f 1.64498e+09 accepted 0  lowest_f -9.41942e+10
# (pid=6168) basinhopping step 7: f 1.41689e+08 trial_f 2.07076e+11 accepted 0  lowest_f 1.41689e+08
# (pid=6251) basinhopping step 1: f -4.20084e+13 trial_f 1.25013e+10 accepted 0  lowest_f -4.20084e+13
# (pid=6142) basinhopping step 8: f 6.40774e+07 trial_f 6.40774e+07 accepted 1  lowest_f 6.40774e+07
# (pid=6142) found new global minimum on step 8 with function value 6.40774e+07
# (pid=6207) basinhopping step 4: f -9.41942e+10 trial_f 4.63625e+08 accepted 0  lowest_f -9.41942e+10
# (pid=6168) basinhopping step 8: f 1.41689e+08 trial_f 1.58281e+09 accepted 0  lowest_f 1.41689e+08
# (pid=6141) basinhopping step 10: f -1.02092e+10 trial_f 1.01866e+09 accepted 0  lowest_f -1.02092e+10
# (pid=6237) basinhopping step 1: f -3.18103e+11 trial_f 5.46373e+08 accepted 0  lowest_f -3.18103e+11
# (pid=6193) basinhopping step 7: f -1.16584e+12 trial_f 3.82065e+08 accepted 0  lowest_f -1.16584e+12
# (pid=6207) basinhopping step 5: f -9.41942e+10 trial_f 4.65385e+08 accepted 0  lowest_f -9.41942e+10
# (pid=6237) basinhopping step 2: f -3.28902e+11 trial_f -3.28902e+11 accepted 1  lowest_f -3.28902e+11
# (pid=6237) found new global minimum on step 2 with function value -3.28902e+11
# (pid=6207) basinhopping step 6: f -9.41942e+10 trial_f -9.25677e+10 accepted 0  lowest_f -9.41942e+10
# (pid=6237) basinhopping step 3: f -8.02125e+11 trial_f -8.02125e+11 accepted 1  lowest_f -8.02125e+11
# (pid=6237) found new global minimum on step 3 with function value -8.02125e+11
# (pid=6142) basinhopping step 9: f 6.40774e+07 trial_f 1.08916e+09 accepted 0  lowest_f 6.40774e+07
# (pid=6193) basinhopping step 8: f -1.16584e+12 trial_f 8.49289e+09 accepted 0  lowest_f -1.16584e+12
# (pid=6167) basinhopping step 10: f 8.08131e+07 trial_f 2.62631e+08 accepted 0  lowest_f 8.08131e+07
# (pid=6278) basinhopping step 0: f 4.52907e+08
# (pid=6279) basinhopping step 0: f 1.48377e+08
# (pid=6208) basinhopping step 4: f -1.39676e+12 trial_f 2.03637e+07 accepted 0  lowest_f -1.39676e+12
# (pid=6279) basinhopping step 1: f 1.48377e+08 trial_f 2.26079e+11 accepted 0  lowest_f 1.48377e+08
# (pid=6279) basinhopping step 2: f 1.48377e+08 trial_f 2.26079e+11 accepted 0  lowest_f 1.48377e+08
# (pid=6208) basinhopping step 5: f -1.39676e+12 trial_f 2.44751e+07 accepted 0  lowest_f -1.39676e+12
# (pid=6193) basinhopping step 9: f -1.16584e+12 trial_f -1.15689e+12 accepted 0  lowest_f -1.16584e+12
# (pid=6208) basinhopping step 6: f -1.39676e+12 trial_f 7.34266e+11 accepted 0  lowest_f -1.39676e+12
# (pid=6193) basinhopping step 10: f -1.16584e+12 trial_f 5.10996e+08 accepted 0  lowest_f -1.16584e+12
# (pid=6279) basinhopping step 3: f 1.48377e+08 trial_f 1.48532e+08 accepted 0  lowest_f 1.48377e+08
# (pid=6142) basinhopping step 10: f 6.40774e+07 trial_f 3.15976e+08 accepted 0  lowest_f 6.40774e+07
# (pid=6116) basinhopping step 6: f -2.27388e+12 trial_f -1.68514e+12 accepted 0  lowest_f -2.27388e+12
# (pid=6237) basinhopping step 4: f -8.02125e+11 trial_f 8.08959e+09 accepted 0  lowest_f -8.02125e+11
# (pid=6207) basinhopping step 7: f -9.41942e+10 trial_f 1.6745e+09 accepted 0  lowest_f -9.41942e+10
# (pid=6305) basinhopping step 0: f -2.62751e+11
# (pid=6168) basinhopping step 9: f -2.13043e+11 trial_f -2.13043e+11 accepted 1  lowest_f -2.13043e+11
# (pid=6168) found new global minimum on step 9 with function value -2.13043e+11
# (pid=6168) basinhopping step 10: f -2.13043e+11 trial_f 7.383e+09 accepted 0  lowest_f -2.13043e+11
# (pid=6279) basinhopping step 4: f 1.48377e+08 trial_f 3.85793e+10 accepted 0  lowest_f 1.48377e+08
# (pid=6278) basinhopping step 1: f -4.20423e+11 trial_f -4.20423e+11 accepted 1  lowest_f -4.20423e+11
# (pid=6278) found new global minimum on step 1 with function value -4.20423e+11
# (pid=6116) basinhopping step 7: f -2.27388e+12 trial_f 8.45895e+10 accepted 0  lowest_f -2.27388e+12
# (pid=6330) basinhopping step 0: f -3.54576e+11
# (pid=6237) basinhopping step 5: f -8.02125e+11 trial_f 1.54645e+09 accepted 0  lowest_f -8.02125e+11
# (pid=6251) basinhopping step 2: f -4.20084e+13 trial_f 2.56512e+10 accepted 0  lowest_f -4.20084e+13
# (pid=6251) basinhopping step 3: f -4.20084e+13 trial_f 1.24564e+10 accepted 0  lowest_f -4.20084e+13
# (pid=6330) basinhopping step 1: f -3.54576e+11 trial_f 5.63337e+09 accepted 0  lowest_f -3.54576e+11
# (pid=6278) basinhopping step 2: f -4.20423e+11 trial_f 1.84339e+09 accepted 0  lowest_f -4.20423e+11
# (pid=6251) basinhopping step 4: f -4.20084e+13 trial_f 5.09593e+11 accepted 0  lowest_f -4.20084e+13
# (pid=6237) basinhopping step 6: f -8.02125e+11 trial_f 9.53078e+10 accepted 0  lowest_f -8.02125e+11
# (pid=6279) basinhopping step 5: f -4.44427e+11 trial_f -4.44427e+11 accepted 1  lowest_f -4.44427e+11
# (pid=6279) found new global minimum on step 5 with function value -4.44427e+11
# (pid=6208) basinhopping step 7: f -1.39676e+12 trial_f 5.95854e+08 accepted 0  lowest_f -1.39676e+12
# (pid=6116) basinhopping step 8: f -2.27388e+12 trial_f 5.8987e+10 accepted 0  lowest_f -2.27388e+12
# (pid=6278) basinhopping step 3: f -4.20423e+11 trial_f 1.63712e+11 accepted 0  lowest_f -4.20423e+11
# (pid=6279) basinhopping step 6: f -4.44427e+11 trial_f 2.26079e+11 accepted 0  lowest_f -4.44427e+11
# (pid=6251) basinhopping step 5: f -4.20084e+13 trial_f 1.24563e+10 accepted 0  lowest_f -4.20084e+13
# (pid=6116) basinhopping step 9: f -2.27388e+12 trial_f 3.0224e+08 accepted 0  lowest_f -2.27388e+12
# (pid=6304) basinhopping step 0: f 6.27518e+07
# (pid=6278) basinhopping step 4: f -4.20423e+11 trial_f 1.7081e+11 accepted 0  lowest_f -4.20423e+11
# (pid=6208) basinhopping step 8: f -1.39676e+12 trial_f 7.20343e+08 accepted 0  lowest_f -1.39676e+12
# (pid=6252) basinhopping step 0: f -1.88516e+11
# (pid=6251) basinhopping step 6: f -4.20084e+13 trial_f 2.79872e+12 accepted 0  lowest_f -4.20084e+13
# (pid=6116) basinhopping step 10: f -2.27388e+12 trial_f 8.05869e+08 accepted 0  lowest_f -2.27388e+12
# (pid=6278) basinhopping step 5: f -4.20423e+11 trial_f 5.80087e+09 accepted 0  lowest_f -4.20423e+11
# (pid=6252) basinhopping step 1: f -1.88516e+11 trial_f 9.01683e+08 accepted 0  lowest_f -1.88516e+11
# (pid=6330) basinhopping step 2: f -3.54576e+11 trial_f 5.58644e+09 accepted 0  lowest_f -3.54576e+11
# (pid=6252) basinhopping step 2: f -1.88516e+11 trial_f 1.01702e+11 accepted 0  lowest_f -1.88516e+11
# (pid=6237) basinhopping step 7: f -8.02125e+11 trial_f 8.07172e+09 accepted 0  lowest_f -8.02125e+11
# (pid=6251) basinhopping step 7: f -4.20084e+13 trial_f 5.05957e+11 accepted 0  lowest_f -4.20084e+13
# (pid=6278) basinhopping step 6: f -4.20423e+11 trial_f 1.75077e+09 accepted 0  lowest_f -4.20423e+11
# (pid=6208) basinhopping step 9: f -1.39676e+12 trial_f 7.41532e+08 accepted 0  lowest_f -1.39676e+12
# (pid=6208) basinhopping step 10: f -1.39676e+12 trial_f 2.44752e+07 accepted 0  lowest_f -1.39676e+12
# (pid=6304) basinhopping step 1: f -2.49265e+11 trial_f -2.49265e+11 accepted 1  lowest_f -2.49265e+11
# (pid=6304) found new global minimum on step 1 with function value -2.49265e+11
# (pid=6207) basinhopping step 8: f -1.98556e+11 trial_f -1.98556e+11 accepted 1  lowest_f -1.98556e+11
# (pid=6207) found new global minimum on step 8 with function value -1.98556e+11
# (pid=6356) basinhopping step 0: f 4.11224e+07
# (pid=6279) basinhopping step 7: f -4.44427e+11 trial_f 5.29024e+08 accepted 0  lowest_f -4.44427e+11
# (pid=6330) basinhopping step 3: f -3.54576e+11 trial_f 1.16231e+09 accepted 0  lowest_f -3.54576e+11
# (pid=6279) basinhopping step 8: f -4.44427e+11 trial_f 1.48377e+08 accepted 0  lowest_f -4.44427e+11
# (pid=6279) basinhopping step 9: f -4.44427e+11 trial_f 1.48748e+08 accepted 0  lowest_f -4.44427e+11
# (pid=6304) basinhopping step 2: f -2.49265e+11 trial_f 4.56013e+09 accepted 0  lowest_f -2.49265e+11
# (pid=6237) basinhopping step 8: f -8.02125e+11 trial_f 1.594e+09 accepted 0  lowest_f -8.02125e+11
# (pid=6331) basinhopping step 0: f -1.12558e+12
# (pid=6252) basinhopping step 3: f -1.88516e+11 trial_f 2.09471e+08 accepted 0  lowest_f -1.88516e+11
# (pid=6207) basinhopping step 9: f -1.98556e+11 trial_f -9.71877e+10 accepted 0  lowest_f -1.98556e+11
# (pid=6356) basinhopping step 1: f 4.11224e+07 trial_f 5.79531e+09 accepted 0  lowest_f 4.11224e+07
# (pid=6237) basinhopping step 9: f -8.02125e+11 trial_f -3.28564e+11 accepted 0  lowest_f -8.02125e+11
# (pid=6252) basinhopping step 4: f -1.88516e+11 trial_f 6.93269e+08 accepted 0  lowest_f -1.88516e+11
# (pid=6279) basinhopping step 10: f -4.44427e+11 trial_f 9.44061e+09 accepted 0  lowest_f -4.44427e+11
# (pid=6330) basinhopping step 4: f -3.54576e+11 trial_f 5.50795e+09 accepted 0  lowest_f -3.54576e+11
# (pid=6251) basinhopping step 8: f -4.20084e+13 trial_f 3.18651e+10 accepted 0  lowest_f -4.20084e+13
# (pid=6356) basinhopping step 2: f 4.11224e+07 trial_f 5.81363e+09 accepted 0  lowest_f 4.11224e+07
# (pid=6369) basinhopping step 0: f 7.73354e+07
# (pid=6356) basinhopping step 3: f 4.09034e+07 trial_f 4.09034e+07 accepted 1  lowest_f 4.09034e+07
# (pid=6356) found new global minimum on step 3 with function value 4.09034e+07
# (pid=6304) basinhopping step 3: f -3.02042e+11 trial_f -3.02042e+11 accepted 1  lowest_f -3.02042e+11
# (pid=6304) found new global minimum on step 3 with function value -3.02042e+11
# (pid=6331) basinhopping step 1: f -1.12558e+12 trial_f 5.96011e+08 accepted 0  lowest_f -1.12558e+12
# (pid=6331) basinhopping step 2: f -1.12558e+12 trial_f 3.84219e+08 accepted 0  lowest_f -1.12558e+12
# (pid=6252) basinhopping step 5: f -1.88516e+11 trial_f 9.01491e+08 accepted 0  lowest_f -1.88516e+11
# (pid=6237) basinhopping step 10: f -8.02125e+11 trial_f -3.22991e+11 accepted 0  lowest_f -8.02125e+11
# (pid=6304) basinhopping step 4: f -3.02042e+11 trial_f 4.60612e+09 accepted 0  lowest_f -3.02042e+11
# (pid=6369) basinhopping step 1: f 7.73354e+07 trial_f 5.11169e+09 accepted 0  lowest_f 7.73354e+07
# (pid=6370) basinhopping step 0: f 1.04445e+09
# (pid=6207) basinhopping step 10: f -1.98556e+11 trial_f 1.65232e+09 accepted 0  lowest_f -1.98556e+11
# (pid=6251) basinhopping step 9: f -4.20084e+13 trial_f 3.08894e+10 accepted 0  lowest_f -4.20084e+13
# (pid=6330) basinhopping step 5: f -3.54576e+11 trial_f -1.76911e+08 accepted 0  lowest_f -3.54576e+11
# (pid=6369) basinhopping step 2: f 7.73354e+07 trial_f 5.30673e+09 accepted 0  lowest_f 7.73354e+07
# (pid=6356) basinhopping step 4: f 4.09034e+07 trial_f 2.74268e+08 accepted 0  lowest_f 4.09034e+07
# (pid=6395) basinhopping step 0: f -1.5515e+11
# (pid=6369) warning: basinhopping: local minimization failure
# (pid=6369) basinhopping step 3: f 7.73354e+07 trial_f 1.20018e+10 accepted 0  lowest_f 7.73354e+07
# (pid=6278) basinhopping step 7: f -4.20423e+11 trial_f -2.78078e+11 accepted 0  lowest_f -4.20423e+11
# (pid=6369) basinhopping step 4: f 7.73354e+07 trial_f 8.38033e+09 accepted 0  lowest_f 7.73354e+07
# (pid=6395) basinhopping step 1: f -1.5515e+11 trial_f 4.86521e+08 accepted 0  lowest_f -1.5515e+11
# (pid=6369) basinhopping step 5: f 7.73354e+07 trial_f 7.79973e+07 accepted 0  lowest_f 7.73354e+07
# (pid=6356) basinhopping step 5: f 4.09034e+07 trial_f 5.8207e+09 accepted 0  lowest_f 4.09034e+07
# (pid=6305) basinhopping step 1: f -2.62751e+11 trial_f -2.58805e+11 accepted 0  lowest_f -2.62751e+11
# (pid=6305) basinhopping step 2: f -2.62751e+11 trial_f 1.37492e+11 accepted 0  lowest_f -2.62751e+11
# (pid=6252) basinhopping step 6: f -1.88516e+11 trial_f 2.4761e+08 accepted 0  lowest_f -1.88516e+11
# (pid=6278) basinhopping step 8: f -4.20423e+11 trial_f 1.8284e+09 accepted 0  lowest_f -4.20423e+11
# (pid=6356) basinhopping step 6: f 4.09034e+07 trial_f 2.4968e+10 accepted 0  lowest_f 4.09034e+07
# (pid=6370) basinhopping step 1: f 1.04445e+09 trial_f 1.0843e+09 accepted 0  lowest_f 1.04445e+09
# (pid=6305) /home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
# (pid=6305)   warnings.warn(warning_msg, ODEintWarning)
# (pid=6395) basinhopping step 2: f -1.5515e+11 trial_f 1.18164e+10 accepted 0  lowest_f -1.5515e+11
# (pid=6251) basinhopping step 10: f -4.20084e+13 trial_f 2.97414e+10 accepted 0  lowest_f -4.20084e+13
# (pid=6369) basinhopping step 6: f 7.73354e+07 trial_f 2.82307e+08 accepted 0  lowest_f 7.73354e+07
# (pid=6395) basinhopping step 3: f -1.5515e+11 trial_f 3.9987e+08 accepted 0  lowest_f -1.5515e+11
# (pid=6252) basinhopping step 7: f -1.88516e+11 trial_f 9.01726e+08 accepted 0  lowest_f -1.88516e+11
# (pid=6409) basinhopping step 0: f 1.01929e+10
# (pid=6370) basinhopping step 2: f 1.04267e+09 trial_f 1.04267e+09 accepted 1  lowest_f 1.04267e+09
# (pid=6370) found new global minimum on step 2 with function value 1.04267e+09
# (pid=6356) basinhopping step 7: f 4.09034e+07 trial_f 5.71694e+09 accepted 0  lowest_f 4.09034e+07
# (pid=6395) basinhopping step 4: f -1.5515e+11 trial_f 4.91724e+08 accepted 0  lowest_f -1.5515e+11
# (pid=6409) warning: basinhopping: local minimization failure
# (pid=6409) basinhopping step 1: f 1.01929e+10 trial_f 1.02285e+10 accepted 0  lowest_f 1.01929e+10
# (pid=6369) /home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
# (pid=6369)   warnings.warn(warning_msg, ODEintWarning)
# (pid=6305) basinhopping step 3: f -2.62751e+11 trial_f 1.78323e+09 accepted 0  lowest_f -2.62751e+11
# (pid=6304) warning: basinhopping: local minimization failure
# (pid=6304) basinhopping step 5: f -3.02042e+11 trial_f 1.81913e+08 accepted 0  lowest_f -3.02042e+11
# (pid=6305) basinhopping step 4: f -2.62751e+11 trial_f 1.37492e+11 accepted 0  lowest_f -2.62751e+11
# (pid=6278) basinhopping step 9: f -6.83645e+11 trial_f -6.83645e+11 accepted 1  lowest_f -6.83645e+11
# (pid=6278) found new global minimum on step 9 with function value -6.83645e+11
# (pid=6395) basinhopping step 5: f -6.72068e+11 trial_f -6.72068e+11 accepted 1  lowest_f -6.72068e+11
# (pid=6395) found new global minimum on step 5 with function value -6.72068e+11
# (pid=6409) warning: basinhopping: local minimization failure
# (pid=6409) basinhopping step 2: f 1.01929e+10 trial_f 1.02284e+10 accepted 0  lowest_f 1.01929e+10
# (pid=6330) basinhopping step 6: f -3.54576e+11 trial_f -3.49752e+11 accepted 0  lowest_f -3.54576e+11
# ...
# (pid=29055) basinhopping step 4: f -4.63465e+11 trial_f -4.63465e+11 accepted 1  lowest_f -4.63465e+11
# (pid=29055) found new global minimum on step 4 with function value -4.63465e+11
# (pid=29108) basinhopping step 7: f 1.06777e+08 trial_f 1.0689e+08 accepted 0  lowest_f 1.06777e+08
# (pid=29127) basinhopping step 1: f -3.88938e+11 trial_f 1.44516e+09 accepted 0  lowest_f -3.88938e+11
# (pid=29108) basinhopping step 8: f 1.06777e+08 trial_f 1.23834e+08 accepted 0  lowest_f 1.06777e+08
# (pid=28964) basinhopping step 9: f -8.70752e+11 trial_f 3.99745e+08 accepted 0  lowest_f -8.70752e+11
# (pid=29127) basinhopping step 2: f -8.54225e+11 trial_f -8.54225e+11 accepted 1  lowest_f -8.54225e+11
# (pid=29127) found new global minimum on step 2 with function value -8.54225e+11
# (pid=28991) basinhopping step 9: f -1.66789e+11 trial_f 1.64229e+10 accepted 0  lowest_f -1.66789e+11
# (pid=29029) basinhopping step 10: f -1.29968e+12 trial_f -1.29968e+12 accepted 1  lowest_f -1.29968e+12
# (pid=29029) found new global minimum on step 10 with function value -1.29968e+12
# (pid=29114) basinhopping step 0: f 1.34222e+09
# (pid=29082) basinhopping step 1: f -5.22164e+11 trial_f -4.18649e+09 accepted 0  lowest_f -5.22164e+11
# (pid=28964) basinhopping step 10: f -8.70752e+11 trial_f 3.67756e+09 accepted 0  lowest_f -8.70752e+11
# (pid=29113) basinhopping step 6: f 9.28235e+07 trial_f 1.29549e+08 accepted 0  lowest_f 9.28235e+07
# (pid=29107) basinhopping step 2: f -4.35657e+13 trial_f 3.67567e+08 accepted 0  lowest_f -4.35657e+13
# (pid=29056) basinhopping step 7: f -3.37795e+11 trial_f 3.42992e+09 accepted 0  lowest_f -3.37795e+11
# (pid=29127) warning: basinhopping: local minimization failure
# (pid=29127) basinhopping step 3: f -8.54225e+11 trial_f 5.86819e+08 accepted 0  lowest_f -8.54225e+11
# (pid=29056) warning: basinhopping: local minimization failure
# (pid=29056) basinhopping step 8: f -3.37795e+11 trial_f 2.11899e+07 accepted 0  lowest_f -3.37795e+11
# (pid=29081) basinhopping step 5: f -9.62559e+11 trial_f 2.06977e+10 accepted 0  lowest_f -9.62559e+11
# (pid=29081) basinhopping step 6: f -9.62559e+11 trial_f 3.41937e+08 accepted 0  lowest_f -9.62559e+11
# (pid=29055) basinhopping step 5: f -4.63465e+11 trial_f 4.69332e+08 accepted 0  lowest_f -4.63465e+11
# (pid=29114) basinhopping step 1: f 1.34222e+09 trial_f 5.83103e+09 accepted 0  lowest_f 1.34222e+09
# (pid=29114) basinhopping step 2: f 1.33591e+09 trial_f 1.33591e+09 accepted 1  lowest_f 1.33591e+09
# (pid=29114) found new global minimum on step 2 with function value 1.33591e+09
# (pid=29056) basinhopping step 9: f -3.37795e+11 trial_f 3.38792e+09 accepted 0  lowest_f -3.37795e+11
# (pid=29127) basinhopping step 4: f -8.54225e+11 trial_f -3.83945e+11 accepted 0  lowest_f -8.54225e+11
# (pid=29055) basinhopping step 6: f -4.63465e+11 trial_f 1.51604e+09 accepted 0  lowest_f -4.63465e+11
# (pid=29082) basinhopping step 2: f -5.22164e+11 trial_f 2.78163e+09 accepted 0  lowest_f -5.22164e+11
# (pid=29107) basinhopping step 3: f -4.35657e+13 trial_f 3.70567e+08 accepted 0  lowest_f -4.35657e+13
# (pid=28991) basinhopping step 10: f -1.66789e+11 trial_f 5.91853e+08 accepted 0  lowest_f -1.66789e+11
# (pid=29081) basinhopping step 7: f -9.62559e+11 trial_f 1.118e+09 accepted 0  lowest_f -9.62559e+11
# (pid=29114) basinhopping step 3: f 1.33591e+09 trial_f 2.39338e+09 accepted 0  lowest_f 1.33591e+09
# (pid=29056) basinhopping step 10: f -3.37795e+11 trial_f 3.44627e+09 accepted 0  lowest_f -3.37795e+11
# (pid=29108) basinhopping step 9: f 1.06777e+08 trial_f 1.09666e+10 accepted 0  lowest_f 1.06777e+08
# (pid=29107) basinhopping step 4: f -1.02858e+14 trial_f -1.02858e+14 accepted 1  lowest_f -1.02858e+14
# (pid=29107) found new global minimum on step 4 with function value -1.02858e+14
# (pid=29081) basinhopping step 8: f -9.62559e+11 trial_f -9.62559e+11 accepted 0  lowest_f -9.62559e+11
# (pid=29082) basinhopping step 3: f -5.22164e+11 trial_f 5.88788e+08 accepted 0  lowest_f -5.22164e+11
# (pid=29111) basinhopping step 0: f -3.19724e+11
# (pid=29107) basinhopping step 5: f -1.02858e+14 trial_f 2.79524e+10 accepted 0  lowest_f -1.02858e+14
# (pid=29113) basinhopping step 7: f 9.28235e+07 trial_f 1.46162e+08 accepted 0  lowest_f 9.28235e+07
# (pid=29112) basinhopping step 0: f -2.38941e+11
# (pid=29114) basinhopping step 4: f 1.33591e+09 trial_f 1.48037e+09 accepted 0  lowest_f 1.33591e+09
# (pid=29217) /home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
# (pid=29217)   warnings.warn(warning_msg, ODEintWarning)
# (pid=29055) basinhopping step 7: f -4.63465e+11 trial_f 1.51769e+09 accepted 0  lowest_f -4.63465e+11
# (pid=29111) basinhopping step 1: f -3.19724e+11 trial_f 5.65524e+08 accepted 0  lowest_f -3.19724e+11
# (pid=29082) basinhopping step 4: f -5.22164e+11 trial_f 1.05148e+10 accepted 0  lowest_f -5.22164e+11
# (pid=29107) basinhopping step 6: f -1.02858e+14 trial_f 3.49513e+11 accepted 0  lowest_f -1.02858e+14
# (pid=29112) basinhopping step 1: f -2.38941e+11 trial_f 4.35233e+08 accepted 0  lowest_f -2.38941e+11
# (pid=29055) basinhopping step 8: f -4.63465e+11 trial_f -2.20363e+11 accepted 0  lowest_f -4.63465e+11
# (pid=29114) basinhopping step 5: f 1.33591e+09 trial_f 6.03691e+09 accepted 0  lowest_f 1.33591e+09
# (pid=29108) basinhopping step 10: f 1.06777e+08 trial_f 1.23834e+08 accepted 0  lowest_f 1.06777e+08
# (pid=29113) basinhopping step 8: f 9.28235e+07 trial_f 4.78568e+09 accepted 0  lowest_f 9.28235e+07
# (pid=29127) basinhopping step 5: f -8.54225e+11 trial_f 5.86819e+08 accepted 0  lowest_f -8.54225e+11
# (pid=29055) basinhopping step 9: f -4.63465e+11 trial_f 1.54316e+09 accepted 0  lowest_f -4.63465e+11
# (pid=29082) basinhopping step 5: f -5.22164e+11 trial_f 9.82948e+08 accepted 0  lowest_f -5.22164e+11
# (pid=29111) basinhopping step 2: f -3.19724e+11 trial_f 5.93155e+09 accepted 0  lowest_f -3.19724e+11
# (pid=29217) basinhopping step 0: f -3.99408e+11
# (pid=29230) basinhopping step 0: f 9.7393e+07
# (pid=29230) basinhopping step 1: f 9.7393e+07 trial_f 1.01069e+08 accepted 0  lowest_f 9.7393e+07
# (pid=29230) basinhopping step 2: f 9.7393e+07 trial_f 4.12424e+11 accepted 0  lowest_f 9.7393e+07
# (pid=29082) basinhopping step 6: f -5.22164e+11 trial_f 1.36218e+10 accepted 0  lowest_f -5.22164e+11
# (pid=29111) basinhopping step 3: f -3.19724e+11 trial_f 1.63062e+09 accepted 0  lowest_f -3.19724e+11
# (pid=29114) warning: basinhopping: local minimization failure
# (pid=29114) basinhopping step 6: f 1.33591e+09 trial_f 2.82279e+09 accepted 0  lowest_f 1.33591e+09
# (pid=29217) basinhopping step 1: f -3.99408e+11 trial_f 1.83571e+08 accepted 0  lowest_f -3.99408e+11
# (pid=29113) basinhopping step 9: f 9.28235e+07 trial_f 2.30537e+10 accepted 0  lowest_f 9.28235e+07
# (pid=29082) basinhopping step 7: f -5.22164e+11 trial_f 9.28022e+08 accepted 0  lowest_f -5.22164e+11
# (pid=29127) basinhopping step 6: f -8.54225e+11 trial_f 1.70758e+09 accepted 0  lowest_f -8.54225e+11
# (pid=29217) basinhopping step 2: f -3.99408e+11 trial_f 4.88041e+09 accepted 0  lowest_f -3.99408e+11
# (pid=29082) warning: basinhopping: local minimization failure
# (pid=29082) basinhopping step 8: f -5.22164e+11 trial_f 5.85582e+08 accepted 0  lowest_f -5.22164e+11
# (pid=29230) basinhopping step 3: f 9.7393e+07 trial_f 5.40246e+08 accepted 0  lowest_f 9.7393e+07
# (pid=29230) basinhopping step 4: f -2.78652e+09 trial_f -2.78652e+09 accepted 1  lowest_f -2.78652e+09
# (pid=29230) found new global minimum on step 4 with function value -2.78652e+09
# (pid=29113) /home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
# (pid=29113)   warnings.warn(warning_msg, ODEintWarning)
# (pid=29217) basinhopping step 3: f -3.99408e+11 trial_f 3.0856e+09 accepted 0  lowest_f -3.99408e+11
# (pid=29113) basinhopping step 10: f 9.28235e+07 trial_f 2.30537e+10 accepted 0  lowest_f 9.28235e+07
# (pid=29111) basinhopping step 4: f -3.19724e+11 trial_f 1.51179e+09 accepted 0  lowest_f -3.19724e+11
# (pid=29082) basinhopping step 9: f -5.22164e+11 trial_f 9.84135e+08 accepted 0  lowest_f -5.22164e+11
# (pid=29245) basinhopping step 0: f 1.32525e+08
# (pid=29127) basinhopping step 7: f -8.54225e+11 trial_f 6.92714e+09 accepted 0  lowest_f -8.54225e+11
# (pid=29114) basinhopping step 7: f 1.33591e+09 trial_f 1.56909e+09 accepted 0  lowest_f 1.33591e+09
# (pid=29217) basinhopping step 4: f -3.99408e+11 trial_f -9.95862e+09 accepted 0  lowest_f -3.99408e+11
# (pid=29114) basinhopping step 8: f 1.33591e+09 trial_f 1.34344e+09 accepted 0  lowest_f 1.33591e+09
# (pid=29217) basinhopping step 5: f -3.99408e+11 trial_f 4.90086e+07 accepted 0  lowest_f -3.99408e+11
# (pid=29111) basinhopping step 5: f -3.26327e+11 trial_f -3.26327e+11 accepted 1  lowest_f -3.26327e+11
# (pid=29111) found new global minimum on step 5 with function value -3.26327e+11
# (pid=29107) warning: basinhopping: local minimization failure
# (pid=29107) basinhopping step 7: f -1.02858e+14 trial_f -6.38556e+13 accepted 0  lowest_f -1.02858e+14
# (pid=29081) basinhopping step 9: f -9.62559e+11 trial_f 8.28788e+08 accepted 0  lowest_f -9.62559e+11
# (pid=29055) basinhopping step 10: f -4.63465e+11 trial_f 4.67332e+08 accepted 0  lowest_f -4.63465e+11
# (pid=29081) basinhopping step 10: f -9.62559e+11 trial_f 3.41937e+08 accepted 0  lowest_f -9.62559e+11
# (pid=29107) basinhopping step 8: f -1.02858e+14 trial_f 1.18668e+10 accepted 0  lowest_f -1.02858e+14
# (pid=29127) basinhopping step 8: f -8.54225e+11 trial_f 1.64043e+09 accepted 0  lowest_f -8.54225e+11
# (pid=29245) basinhopping step 1: f 1.32525e+08 trial_f 2.42749e+08 accepted 0  lowest_f 1.32525e+08
# (pid=29230) basinhopping step 5: f -5.25551e+11 trial_f -5.25551e+11 accepted 1  lowest_f -5.25551e+11
# (pid=29230) found new global minimum on step 5 with function value -5.25551e+11
# (pid=29217) basinhopping step 6: f -3.99408e+11 trial_f 2.85368e+09 accepted 0  lowest_f -3.99408e+11
# (pid=29114) basinhopping step 9: f 1.33591e+09 trial_f 6.02919e+09 accepted 0  lowest_f 1.33591e+09
# (pid=29114) basinhopping step 10: f 1.33591e+09 trial_f 1.34321e+09 accepted 0  lowest_f 1.33591e+09
# (pid=29271) basinhopping step 0: f -7.2587e+11
# (pid=29230) basinhopping step 6: f -5.25551e+11 trial_f 2.08595e+10 accepted 0  lowest_f -5.25551e+11
# (pid=29111) basinhopping step 6: f -3.26327e+11 trial_f 1.58567e+09 accepted 0  lowest_f -3.26327e+11
# (pid=29286) basinhopping step 0: f 1.55615e+09
# (pid=29127) basinhopping step 9: f -8.54225e+11 trial_f 1.45533e+09 accepted 0  lowest_f -8.54225e+11
# (pid=29217) basinhopping step 7: f -3.99408e+11 trial_f 3.03563e+09 accepted 0  lowest_f -3.99408e+11
# (pid=29245) basinhopping step 2: f 1.32525e+08 trial_f 1.13164e+09 accepted 0  lowest_f 1.32525e+08
# (pid=29082) basinhopping step 10: f -5.22164e+11 trial_f 5.87203e+08 accepted 0  lowest_f -5.22164e+11
# (pid=29107) basinhopping step 9: f -1.02858e+14 trial_f 3.46101e+12 accepted 0  lowest_f -1.02858e+14
# (pid=29107) basinhopping step 10: f -1.02858e+14 trial_f 1.85731e+13 accepted 0  lowest_f -1.02858e+14
# (pid=29230) basinhopping step 7: f -1.35342e+12 trial_f -1.35342e+12 accepted 1  lowest_f -1.35342e+12
# (pid=29230) found new global minimum on step 7 with function value -1.35342e+12
# (pid=29217) basinhopping step 8: f -3.99408e+11 trial_f 1.75949e+11 accepted 0  lowest_f -3.99408e+11
# (pid=29127) basinhopping step 10: f -8.54225e+11 trial_f 7.19767e+09 accepted 0  lowest_f -8.54225e+11
# (pid=29271) basinhopping step 1: f -7.2587e+11 trial_f 1.36431e+10 accepted 0  lowest_f -7.2587e+11
# (pid=29112) basinhopping step 2: f -3.09938e+11 trial_f -3.09938e+11 accepted 1  lowest_f -3.09938e+11
# (pid=29112) found new global minimum on step 2 with function value -3.09938e+11
# (pid=29230) basinhopping step 8: f -1.35342e+12 trial_f 2.72775e+11 accepted 0  lowest_f -1.35342e+12
# (pid=29285) basinhopping step 0: f -4.8339e+11
# (pid=29286) basinhopping step 1: f 1.55511e+09 trial_f 1.55511e+09 accepted 1  lowest_f 1.55511e+09
# (pid=29286) found new global minimum on step 1 with function value 1.55511e+09
# (pid=29245) basinhopping step 3: f 1.32525e+08 trial_f 5.02525e+09 accepted 0  lowest_f 1.32525e+08
# (pid=29271) basinhopping step 2: f -7.2587e+11 trial_f 1.32422e+10 accepted 0  lowest_f -7.2587e+11
# (pid=29112) basinhopping step 3: f -3.09938e+11 trial_f 3.42622e+09 accepted 0  lowest_f -3.09938e+11
# (pid=29311) basinhopping step 0: f 1.68224e+09
# (pid=29217) basinhopping step 9: f -9.31925e+11 trial_f -9.31925e+11 accepted 1  lowest_f -9.31925e+11
# (pid=29217) found new global minimum on step 9 with function value -9.31925e+11
# (pid=29217) basinhopping step 10: f -9.31925e+11 trial_f 5.45143e+07 accepted 0  lowest_f -9.31925e+11
# (pid=29246) basinhopping step 0: f -1.55597e+11
# (pid=29285) basinhopping step 1: f -4.8339e+11 trial_f 1.08692e+10 accepted 0  lowest_f -4.8339e+11
# (pid=29111) basinhopping step 7: f -3.26327e+11 trial_f 3.85811e+08 accepted 0  lowest_f -3.26327e+11
# (pid=29286) basinhopping step 2: f 1.55511e+09 trial_f 2.12467e+10 accepted 0  lowest_f 1.55511e+09
# (pid=29230) basinhopping step 9: f -1.35342e+12 trial_f -5.3343e+11 accepted 0  lowest_f -1.35342e+12
# (pid=29230) basinhopping step 10: f -1.35342e+12 trial_f 9.65843e+07 accepted 0  lowest_f -1.35342e+12
# (pid=29245) basinhopping step 4: f 1.32525e+08 trial_f 4.87355e+09 accepted 0  lowest_f 1.32525e+08
# (pid=29271) basinhopping step 3: f -7.2587e+11 trial_f 3.62489e+08 accepted 0  lowest_f -7.2587e+11
# (pid=29350) basinhopping step 0: f 8.06451e+07
# (pid=29285) basinhopping step 2: f -4.8339e+11 trial_f 3.35045e+08 accepted 0  lowest_f -4.8339e+11
# (pid=29337) basinhopping step 0: f -4.78654e+11
# (pid=29285) /home/ats4i/anaconda3/envs/geo_env/lib/python3.6/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
# (pid=29285)   warnings.warn(warning_msg, ODEintWarning)
# (pid=29271) basinhopping step 4: f -7.2587e+11 trial_f 9.67707e+08 accepted 0  lowest_f -7.2587e+11
# (pid=29246) basinhopping step 1: f -1.55597e+11 trial_f 3.94628e+08 accepted 0  lowest_f -1.55597e+11
# (pid=29285) basinhopping step 3: f -4.8339e+11 trial_f 1.49228e+10 accepted 0  lowest_f -4.8339e+11
# (pid=29337) basinhopping step 1: f -4.78654e+11 trial_f 8.97274e+09 accepted 0  lowest_f -4.78654e+11
# (pid=29311) basinhopping step 1: f -9.11717e+12 trial_f -9.11717e+12 accepted 1  lowest_f -9.11717e+12
# (pid=29311) found new global minimum on step 1 with function value -9.11717e+12
# (pid=29111) basinhopping step 8: f -3.26327e+11 trial_f 1.44441e+09 accepted 0  lowest_f -3.26327e+11
# (pid=29286) basinhopping step 3: f 6.30015e+08 trial_f 6.30015e+08 accepted 1  lowest_f 6.30015e+08
# (pid=29286) found new global minimum on step 3 with function value 6.30015e+08
# (pid=29111) basinhopping step 9: f -3.26327e+11 trial_f 5.80622e+09 accepted 0  lowest_f -3.26327e+11
# (pid=29285) basinhopping step 4: f -4.8339e+11 trial_f 7.52972e+08 accepted 0  lowest_f -4.8339e+11
# (pid=29286) basinhopping step 4: f 6.30015e+08 trial_f 4.79716e+09 accepted 0  lowest_f 6.30015e+08
# (pid=29246) basinhopping step 2: f -1.55597e+11 trial_f 2.26334e+09 accepted 0  lowest_f -1.55597e+11
# (pid=29286) basinhopping step 5: f 6.30015e+08 trial_f 1.5441e+09 accepted 0  lowest_f 6.30015e+08
# (pid=29337) basinhopping step 2: f -4.78654e+11 trial_f 2.10022e+10 accepted 0  lowest_f -4.78654e+11
# (pid=29286) basinhopping step 6: f -2.4183e+11 trial_f -2.4183e+11 accepted 1  lowest_f -2.4183e+11
# (pid=29286) found new global minimum on step 6 with function value -2.4183e+11
# (pid=29350) basinhopping step 1: f 8.06451e+07 trial_f 2.96792e+08 accepted 0  lowest_f 8.06451e+07
# (pid=29286) basinhopping step 7: f -2.4183e+11 trial_f 1.55954e+09 accepted 0  lowest_f -2.4183e+11
# (pid=29350) basinhopping step 2: f 8.06451e+07 trial_f 8.09739e+07 accepted 0  lowest_f 8.06451e+07

# %%
for i in range(0,len(states)):    

    state=states[i]
    query = dfparam.query('state == "{}"'.format(state)).reset_index()
    parameters = np.array(query.iloc[:, 2:])[0]
    startdate,predict_range,s0,e0,a0,i0,r0,d0,startNCases,ratio,wcases,wrec = parameters
    Date = datetime.strptime(startdate, "%Y-%m-%d")
    end_date = Date + timedelta(days=+int(optimal[i][1]))
    dateStr=end_date.strftime("%Y-%m-%d")

    j = query['index'].values[0]
    dfparam.at[j, "s0"] = optimal[i][0]
    dfparam.at[j, "start-date"] = dateStr
    dfparam.at[j, "i0"] = optimal[i][2]
    dfparam.at[j, "WCASES"] = optimal[i][3]
    dfparam.at[j, "WREC"] = optimal[i][4]

    dfparam.to_csv("data/param_optimized_Yabox.csv", sep=",", index=False)
    dfparam
